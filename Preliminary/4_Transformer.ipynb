# %% [markdown]
# ## Imports & Setup

# %%
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Compose, Resize, RandomHorizontalFlip
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, precision_score, recall_score
from helpers import *
from architecture.Transformer import *

# %% [markdown]
# from torchsampler import ImbalancedDatasetSampler

# %%
torch.manual_seed(109)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ## Prepare Dataset

# %%
size = 36
batch_size = 64
transformation = Compose([RandomHorizontalFlip(), Resize((size, size)), ToTensor()])

# %%
root = 'real_and_fake_face/train'
train_data = create_dataset(root, transformation)
train_loader = produce_loader(train_data, batch_size, shuffle=True)

# %%
root = 'real_and_fake_face/test'
test_data = create_dataset(root, transformation)
test_loader = produce_loader(test_data, batch_size)

# %%
root = 'real_and_fake_face/val'
val_data = create_dataset(root, transformation)
val_loader = produce_loader(val_data, batch_size)

# %%
visualize_data(train_data)
# Out:
# [2488, 1309, 2906, 401, 448, 990, 107, 3005, 1505]

# %%
visualize_data(test_data)
# Out:
# [20, 153, 116, 22, 78, 16, 71, 52, 129]

# %% [markdown]
# ## Initialize Model

# %%
def create_adam_optimizer(model, lr = 0.1, betas=(0.9, 0.999), amsgrad=False):
    return optim.Adam(model.parameters(), lr = lr, amsgrad=amsgrad, betas=betas)

# %%
from math import floor
# number of convolutional 'embedding' layers and their sizes
hidden = [3, 256, 64, 32]

# kernel size of convolution layers
kernel_size = 5

# window size of maxpooling layer
window = 2

# calculate final size of image
channels = hidden[-1]
changed_img = floor( (size-(kernel_size-1)*(len(hidden)-1)) / window )

# calculate dimension of flattened image
flattened = channels*changed_img*changed_img
blocks = [flattened, 512, 64]

# %%
model = Transformer(hidden, kernel_size, window, blocks).to(device)
print(model)
# Out:
# Transformer(
#   (conv_combined): Sequential(
#     (0): ConvEmbed(
#       (conv): Conv2d(3, 256, kernel_size=(5, 5), stride=(1, 1))
#       (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (1): ConvEmbed(
#       (conv): Conv2d(256, 64, kernel_size=(5, 5), stride=(1, 1))
#       (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (2): ConvEmbed(
#       (conv): Conv2d(64, 32, kernel_size=(5, 5), stride=(1, 1))
#       (batch_norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (blocks_combined): Sequential(
#     (0): TransformerBlock(
#       (attention): AttentionLayer(
#         (query): Linear(in_features=4608, out_features=4608, bias=True)
#         (key): Linear(in_features=4608, out_features=4608, bias=True)
#         (value): Linear(in_features=4608, out_features=4608, bias=True)
#       )
#       (linear): Linear(in_features=4608, out_features=4608, bias=True)
#       (batch_norm1): BatchNorm1d(4608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (highway): Linear(in_features=4608, out_features=4608, bias=True)
#       (transform): Linear(in_features=4608, out_features=4608, bias=True)
#       (batch_norm2): BatchNorm1d(4608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (output): DeepSearchLinear(
#         (linear): Linear(in_features=4608, out_features=512, bias=True)
#         (batch_norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): TransformerBlock(
#       (attention): AttentionLayer(
#         (query): Linear(in_features=512, out_features=512, bias=True)
#         (key): Linear(in_features=512, out_features=512, bias=True)
#         (value): Linear(in_features=512, out_features=512, bias=True)
#       )
#       (linear): Linear(in_features=512, out_features=512, bias=True)
#       (batch_norm1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (highway): Linear(in_features=512, out_features=512, bias=True)
#       (transform): Linear(in_features=512, out_features=512, bias=True)
#       (batch_norm2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (output): DeepSearchLinear(
#         (linear): Linear(in_features=512, out_features=64, bias=True)
#         (batch_norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout): Dropout(p=0.5, inplace=False)
#       )
#     )
#   )
#   (output): DeepSearchLinear(
#     (linear): Linear(in_features=64, out_features=2, bias=True)
#     (batch_norm): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
# )

# %% [markdown]
# ## Training Model

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
optimizer = create_adam_optimizer(model, lr = 0.001)

# %%
tl, ta, vl, va = train(device, model,
                       train_loader, val_loader, 
                       optimizer, epochs = 20)
train_losses+=tl
train_accuracies+=ta
val_losses+=vl
val_accuracies+=va
# Out:
# Epoch 1/20, Batch number: 0, Cumulated accuracy: 0.484375
# Epoch 1/20, Batch number: 5, Cumulated accuracy: 0.5182291666666666
# Epoch 1/20, Batch number: 10, Cumulated accuracy: 0.5071022727272727
# --- Epoch 4/20: Val loss: 0.6947, Val accuracy: 0.5490
# Epoch 5/20, Batch number: 0, Cumulated accuracy: 0.453125
# Epoch 5/20, Batch number: 5, Cumulated accuracy: 0.484375
# Epoch 5/20, Batch number: 10, Cumulated accuracy: 0.4815340909090909
# Epoch 5/20, Batch number: 15, Cumulated accuracy: 0.4873046875
# Epoch 5/20, Batch number: 20, Cumulated accuracy: 0.4799107142857143
# Epoch 5/20, Batch number: 25, Cumulated accuracy: 0.4885817307692308
# Epoch 5/20, Batch number: 30, Cumulated accuracy: 0.4879032258064516
# Epoch 5/20, Batch number: 35, Cumulated accuracy: 0.4895833333333333
# Epoch 5/20, Batch number: 40, Cumulated accuracy: 0.4923780487804878
# Epoch 5/20, Batch number: 45, Cumulated accuracy: 0.49626358695652173
# Epoch 5/20, Batch number: 50, Cumulated accuracy: 0.4960171568627451
# --- Epoch 5/20: Train loss: 0.6941, Train accuracy: 0.4963
# --- Epoch 5/20: Val loss: 0.6907, Val accuracy: 0.5049
# Epoch 6/20, Batch number: 0, Cumulated accuracy: 0.453125
# Epoch 6/20, Batch number: 5, Cumulated accuracy: 0.4921875
# Epoch 6/20, Batch number: 10, Cumulated accuracy: 0.5113636363636364
# Epoch 6/20, Batch number: 15, Cumulated accuracy: 0.5126953125
# Epoch 6/20, Batch number: 20, Cumulated accuracy: 0.5141369047619048
# Epoch 6/20, Batch number: 25, Cumulated accuracy: 0.5048076923076923
# Epoch 6/20, Batch number: 30, Cumulated accuracy: 0.5030241935483871
# Epoch 6/20, Batch number: 35, Cumulated accuracy: 0.5043402777777778
# Epoch 6/20, Batch number: 40, Cumulated accuracy: 0.5019054878048781
# Epoch 6/20, Batch number: 45, Cumulated accuracy: 0.5023777173913043
# Epoch 6/20, Batch number: 50, Cumulated accuracy: 0.5018382352941176
# --- Epoch 6/20: Train loss: 0.6988, Train accuracy: 0.5015
# --- Epoch 6/20: Val loss: 0.6911, Val accuracy: 0.5441
# Stopped early due to increasing validation loss.

# %% [markdown]
# ## Testing Model & Performance Curves

# %%
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
# Out:
# Test loss: 0.6911, Test accuracy: 0.5343

# %%
show_metrics(true_labels, model_preds)
# Out:
# Precision: 0.5585585585585585
# Recall: 0.5740740740740741
# F1 score: 0.5662100456621004

# %%
plt.plot(train_accuracies, "r--", label='Train accuracy')
plt.plot(val_accuracies, "b--", label='Validation accuracy')
plt.title("Final Test Accuracy: {}".format(test_accuracy))
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(train_losses, "r--", label='Training loss')
plt.plot(val_losses, "b--", label='Validation loss')
plt.title("Final Test Loss: {}".format(test_loss))
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Viewing Model Predictions

# %%
test_loader2 = produce_loader(test_data, 1)

# %%
correct_list, wrong_list, true_labels2, model_preds2 = get_pictures_test(device, model, test_loader2)

# %%
show_metrics(true_labels2, model_preds2)
# Out:
# Precision: 0.5652173913043478
# Recall: 0.6018518518518519
# F1 score: 0.5829596412556053

# %%
visualize_data(correct_list, (12,12), 5)
# Out:
# [94, 98, 18, 37, 89, 80, 97, 70, 73, 99, 59, 46, 42, 76, 49, 104, 57, 78, 50, 44, 26, 41, 100, 62, 77]

# %%
visualize_data(wrong_list, (12,12), 5)
# Out:
# [4, 74, 67, 7, 51, 41, 76, 55, 26, 13, 51, 22, 80, 12, 69, 20, 66, 76, 39, 67, 26, 71, 71, 32, 30]

# %% [markdown]
# ## Saving Model

# %% [markdown]
# torch.save({'model_state_dict': model.state_dict(),
#             'optimizer_state_dict': optimizer.state_dict()},
#             './transformer_6epochs')
