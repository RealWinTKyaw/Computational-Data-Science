# %%
import pandas as pd
import shutil
import numpy as np
import os
import cv2
from random import seed, shuffle
seed(42)

# %%
def save_frame(read_path):
    
    path = os.path.join(read_path)
    print(path)
    filename = os.path.basename(path)
    print(filename)
    write_path = os.path.join('/'.join(read_path.split('/')[:-3]),'frames',read_path.split('/')[-2],filename.replace('.','_').replace('-','_'))
    print(write_path)
    os.makedirs(write_path, exist_ok=True)
    
    video = cv2.VideoCapture(path)
    counter=0
    if not video.isOpened():
        print("Not working; move notebook to same folder as videos or do 'pip install opencv-contrib-python'")
    while(video.isOpened()):
        ret, frame = video.read()
        if ret==True:
            
            cv2.imwrite(os.path.join(write_path,"frame_%d.jpg" % counter), frame)  
            counter+=1
            ret, frame = video.read()
            if cv2.waitKey(20) & 0xFF == ord('q'):
                break
        else:
            break   
    
    print(f'Total Frames written for video {filename} are {counter} in folder {write_path}')
    video.release()

# %% [markdown]
# ## Create Lists of Fake/Real Video Names

# %% [markdown]
# Put dataset in the same folder as this notebook, or modify the path accordingly.

# %%
df = pd.read_json("./dataset/metadata.json").T
fakes = df.loc[df['label'] == "FAKE"]
fakes = fakes.index.tolist()

# %%
real = df.loc[df['label'] == "REAL"]
real = real.index.tolist()

# %% [markdown]
# ## Sort into Separate Folders

# %%
destination_fake = "./fake"
os.mkdir(destination_fake)
for file in fakes:
    src_path = f'./dataset/{file}'
    dst_path = destination_fake
    shutil.move(src_path, dst_path)

# %%
destination_real = "./real"
os.mkdir(destination_real)
for file in real:
    src_path = f'./dataset/{file}'
    dst_path = destination_real
    shutil.move(src_path, dst_path)

# %% [markdown]
# ## Extract Frames

# %%
"""
Note: this takes a while
"""
for file in fakes:
    src_path = f'{destination_fake}/{file}'
    save_frame(src_path)
# Out:
# ./fake/aagfhgtpmv.mp4
# aagfhgtpmv.mp4
# frames\fake\aagfhgtpmv_mp4
# Total Frames written for video aagfhgtpmv.mp4 are 150 in folder frames\fake\aagfhgtpmv_mp4
# ./fake/aapnvogymq.mp4
# aapnvogymq.mp4
# frames\fake\aapnvogymq_mp4
# Total Frames written for video aapnvogymq.mp4 are 150 in folder frames\fake\aapnvogymq_mp4
# ./fake/abofeumbvv.mp4
# abofeumbvv.mp4
# frames\fake\abofeumbvv_mp4
# Total Frames written for video abofeumbvv.mp4 are 150 in folder frames\fake\abofeumbvv_mp4
# ./fake/abqwwspghj.mp4
# abqwwspghj.mp4
# frames\fake\abqwwspghj_mp4
# Total Frames written for video abqwwspghj.mp4 are 150 in folder frames\fake\abqwwspghj_mp4
# ./fake/acifjvzvpm.mp4
# acifjvzvpm.mp4
# frames\fake\acifjvzvpm_mp4
# Total Frames written for video acifjvzvpm.mp4 are 150 in folder frames\fake\acifjvzvpm_mp4
# ./fake/acqfdwsrhi.mp4
# acqfdwsrhi.mp4
# frames\fake\acqfdwsrhi_mp4
# Total Frames written for video acqfdwsrhi.mp4 are 150 in folder frames\fake\acqfdwsrhi_mp4
# ./fake/acxnxvbsxk.mp4
# acxnxvbsxk.mp4
# frames\fake\acxnxvbsxk_mp4
# Total Frames written for video acxnxvbsxk.mp4 are 150 in folder frames\fake\acxnxvbsxk_mp4
# ./fake/acxwigylke.mp4
# acxwigylke.mp4
# frames\fake\acxwigylke_mp4
# Total Frames written for video acxwigylke.mp4 are 149 in folder frames\fake\acxwigylke_mp4
# ./fake/aczrgyricp.mp4
# aczrgyricp.mp4
# frames\fake\aczrgyricp_mp4
# Total Frames written for video aczrgyricp.mp4 are 150 in folder frames\fake\aczrgyricp_mp4
# ./fake/adhsbajydo.mp4
# adhsbajydo.mp4
# frames\fake\adhsbajydo_mp4
# Total Frames written for video adhsbajydo.mp4 are 150 in folder frames\fake\adhsbajydo_mp4
# ./fake/adohikbdaz.mp4
# adohikbdaz.mp4
# frames\fake\adohikbdaz_mp4
# Total Frames written for video adohikbdaz.mp4 are 150 in folder frames\fake\adohikbdaz_mp4
# ./fake/adylbeequz.mp4
# adylbeequz.mp4
# frames\fake\adylbeequz_mp4
# Total Frames written for video adylbeequz.mp4 are 150 in folder frames\fake\adylbeequz_mp4
# ./fake/aelzhcnwgf.mp4
# aelzhcnwgf.mp4
# frames\fake\aelzhcnwgf_mp4
# Total Frames written for video aelzhcnwgf.mp4 are 150 in folder frames\fake\aelzhcnwgf_mp4
# ./fake/aettqgevhz.mp4
# aettqgevhz.mp4
# frames\fake\aettqgevhz_mp4
# Total Frames written for video aettqgevhz.mp4 are 150 in folder frames\fake\aettqgevhz_mp4
# ./fake/aevrfsexku.mp4
# aevrfsexku.mp4
# frames\fake\aevrfsexku_mp4
# Total Frames written for video aevrfsexku.mp4 are 150 in folder frames\fake\aevrfsexku_mp4
# ./fake/agdkmztvby.mp4
# agdkmztvby.mp4
# frames\fake\agdkmztvby_mp4
# Total Frames written for video agdkmztvby.mp4 are 150 in folder frames\fake\agdkmztvby_mp4
# ./fake/agqphdxmwt.mp4
# agqphdxmwt.mp4
# frames\fake\agqphdxmwt_mp4
# Total Frames written for video agqphdxmwt.mp4 are 150 in folder frames\fake\agqphdxmwt_mp4
# ./fake/ahbweevwpv.mp4
# ahbweevwpv.mp4
# frames\fake\ahbweevwpv_mp4
# Total Frames written for video ahbweevwpv.mp4 are 150 in folder frames\fake\ahbweevwpv_mp4
# ./fake/ahdbuwqxit.mp4
# ahdbuwqxit.mp4
# frames\fake\ahdbuwqxit_mp4
# Total Frames written for video ahdbuwqxit.mp4 are 150 in folder frames\fake\ahdbuwqxit_mp4
# ./fake/ahfazfbntc.mp4
# ahfazfbntc.mp4
# frames\fake\ahfazfbntc_mp4
# Total Frames written for video ahfazfbntc.mp4 are 150 in folder frames\fake\ahfazfbntc_mp4
# ./fake/aipfdnwpoo.mp4
# aipfdnwpoo.mp4
# frames\fake\aipfdnwpoo_mp4
# Total Frames written for video aipfdnwpoo.mp4 are 150 in folder frames\fake\aipfdnwpoo_mp4
# ./fake/ajwpjhrbcv.mp4
# ajwpjhrbcv.mp4
# frames\fake\ajwpjhrbcv_mp4
# Total Frames written for video ajwpjhrbcv.mp4 are 150 in folder frames\fake\ajwpjhrbcv_mp4
# ./fake/aklqzsddfl.mp4
# aklqzsddfl.mp4
# frames\fake\aklqzsddfl_mp4
# Total Frames written for video aklqzsddfl.mp4 are 150 in folder frames\fake\aklqzsddfl_mp4
# ./fake/aknbdpmgua.mp4
# aknbdpmgua.mp4
# frames\fake\aknbdpmgua_mp4
# Total Frames written for video aknbdpmgua.mp4 are 150 in folder frames\fake\aknbdpmgua_mp4
# ./fake/aknmpoonls.mp4
# aknmpoonls.mp4
# frames\fake\aknmpoonls_mp4
# Total Frames written for video aknmpoonls.mp4 are 150 in folder frames\fake\aknmpoonls_mp4
# ./fake/akvmwkdyuv.mp4
# akvmwkdyuv.mp4
# frames\fake\akvmwkdyuv_mp4
# Total Frames written for video akvmwkdyuv.mp4 are 150 in folder frames\fake\akvmwkdyuv_mp4
# ./fake/akxoopqjqz.mp4
# akxoopqjqz.mp4
# frames\fake\akxoopqjqz_mp4
# Total Frames written for video akxoopqjqz.mp4 are 150 in folder frames\fake\akxoopqjqz_mp4
# ./fake/akzbnazxtz.mp4
# akzbnazxtz.mp4
# frames\fake\akzbnazxtz_mp4
# Total Frames written for video akzbnazxtz.mp4 are 150 in folder frames\fake\akzbnazxtz_mp4
# ./fake/aladcziidp.mp4
# aladcziidp.mp4
# frames\fake\aladcziidp_mp4
# Total Frames written for video aladcziidp.mp4 are 149 in folder frames\fake\aladcziidp_mp4
# ./fake/alaijyygdv.mp4
# alaijyygdv.mp4
# frames\fake\alaijyygdv_mp4
# Total Frames written for video alaijyygdv.mp4 are 149 in folder frames\fake\alaijyygdv_mp4
# ./fake/alninxcyhg.mp4
# alninxcyhg.mp4
# frames\fake\alninxcyhg_mp4
# Total Frames written for video alninxcyhg.mp4 are 150 in folder frames\fake\alninxcyhg_mp4
# ./fake/altziddtxi.mp4
# altziddtxi.mp4
# frames\fake\altziddtxi_mp4
# Total Frames written for video altziddtxi.mp4 are 150 in folder frames\fake\altziddtxi_mp4
# ./fake/alvgwypubw.mp4
# alvgwypubw.mp4
# frames\fake\alvgwypubw_mp4
# Total Frames written for video alvgwypubw.mp4 are 150 in folder frames\fake\alvgwypubw_mp4
# ./fake/amaivqofda.mp4
# amaivqofda.mp4
# frames\fake\amaivqofda_mp4
# Total Frames written for video amaivqofda.mp4 are 150 in folder frames\fake\amaivqofda_mp4
# ./fake/amowujxmzc.mp4
# amowujxmzc.mp4
# frames\fake\amowujxmzc_mp4
# Total Frames written for video amowujxmzc.mp4 are 150 in folder frames\fake\amowujxmzc_mp4
# ./fake/andaxzscny.mp4
# andaxzscny.mp4
# frames\fake\andaxzscny_mp4
# Total Frames written for video andaxzscny.mp4 are 150 in folder frames\fake\andaxzscny_mp4
# ./fake/aneclqfpbt.mp4
# aneclqfpbt.mp4
# frames\fake\aneclqfpbt_mp4
# Total Frames written for video aneclqfpbt.mp4 are 150 in folder frames\fake\aneclqfpbt_mp4
# ./fake/aorjvbyxhw.mp4
# aorjvbyxhw.mp4
# frames\fake\aorjvbyxhw_mp4
# Total Frames written for video aorjvbyxhw.mp4 are 150 in folder frames\fake\aorjvbyxhw_mp4
# ./fake/apatcsqejh.mp4
# apatcsqejh.mp4
# frames\fake\apatcsqejh_mp4
# Total Frames written for video apatcsqejh.mp4 are 150 in folder frames\fake\apatcsqejh_mp4
# ./fake/apgjqzkoma.mp4
# apgjqzkoma.mp4
# frames\fake\apgjqzkoma_mp4
# Total Frames written for video apgjqzkoma.mp4 are 150 in folder frames\fake\apgjqzkoma_mp4
# ./fake/apogckdfrz.mp4
# apogckdfrz.mp4
# frames\fake\apogckdfrz_mp4
# Total Frames written for video apogckdfrz.mp4 are 150 in folder frames\fake\apogckdfrz_mp4
# ./fake/aqpnvjhuzw.mp4
# aqpnvjhuzw.mp4
# frames\fake\aqpnvjhuzw_mp4
# Total Frames written for video aqpnvjhuzw.mp4 are 150 in folder frames\fake\aqpnvjhuzw_mp4
# ./fake/arkroixhey.mp4
# arkroixhey.mp4
# frames\fake\arkroixhey_mp4
# Total Frames written for video arkroixhey.mp4 are 150 in folder frames\fake\arkroixhey_mp4
# ./fake/arlmiizoob.mp4
# arlmiizoob.mp4
# frames\fake\arlmiizoob_mp4
# Total Frames written for video arlmiizoob.mp4 are 150 in folder frames\fake\arlmiizoob_mp4
# ./fake/arrhsnjqku.mp4
# arrhsnjqku.mp4
# frames\fake\arrhsnjqku_mp4
# Total Frames written for video arrhsnjqku.mp4 are 150 in folder frames\fake\arrhsnjqku_mp4
# ./fake/asdpeebotb.mp4
# asdpeebotb.mp4
# frames\fake\asdpeebotb_mp4
# Total Frames written for video asdpeebotb.mp4 are 150 in folder frames\fake\asdpeebotb_mp4
# ./fake/aslsvlvpth.mp4
# aslsvlvpth.mp4
# frames\fake\aslsvlvpth_mp4
# Total Frames written for video aslsvlvpth.mp4 are 150 in folder frames\fake\aslsvlvpth_mp4
# ./fake/asmpfjfzif.mp4
# asmpfjfzif.mp4
# frames\fake\asmpfjfzif_mp4
# Total Frames written for video asmpfjfzif.mp4 are 150 in folder frames\fake\asmpfjfzif_mp4
# ./fake/asvcrfdpnq.mp4
# asvcrfdpnq.mp4
# frames\fake\asvcrfdpnq_mp4
# Total Frames written for video asvcrfdpnq.mp4 are 150 in folder frames\fake\asvcrfdpnq_mp4
# ./fake/atxvxouljq.mp4
# atxvxouljq.mp4
# frames\fake\atxvxouljq_mp4
# Total Frames written for video atxvxouljq.mp4 are 150 in folder frames\fake\atxvxouljq_mp4
# ./fake/atyntldecu.mp4
# atyntldecu.mp4
# frames\fake\atyntldecu_mp4
# Total Frames written for video atyntldecu.mp4 are 150 in folder frames\fake\atyntldecu_mp4
# ./fake/atzdznmder.mp4
# atzdznmder.mp4
# frames\fake\atzdznmder_mp4
# Total Frames written for video atzdznmder.mp4 are 150 in folder frames\fake\atzdznmder_mp4
# ./fake/aufmsmnoye.mp4
# aufmsmnoye.mp4
# frames\fake\aufmsmnoye_mp4
# Total Frames written for video aufmsmnoye.mp4 are 150 in folder frames\fake\aufmsmnoye_mp4
# ./fake/augtsuxpzc.mp4
# augtsuxpzc.mp4
# frames\fake\augtsuxpzc_mp4
# Total Frames written for video augtsuxpzc.mp4 are 150 in folder frames\fake\augtsuxpzc_mp4
# ./fake/avfitoutyn.mp4
# avfitoutyn.mp4
# frames\fake\avfitoutyn_mp4
# Total Frames written for video avfitoutyn.mp4 are 150 in folder frames\fake\avfitoutyn_mp4
# ./fake/avgiuextiz.mp4
# avgiuextiz.mp4
# frames\fake\avgiuextiz_mp4
# Total Frames written for video avgiuextiz.mp4 are 150 in folder frames\fake\avgiuextiz_mp4
# ./fake/avibnnhwhp.mp4
# avibnnhwhp.mp4
# frames\fake\avibnnhwhp_mp4
# Total Frames written for video avibnnhwhp.mp4 are 150 in folder frames\fake\avibnnhwhp_mp4
# ./fake/avnqydkqjj.mp4
# avnqydkqjj.mp4
# frames\fake\avnqydkqjj_mp4
# Total Frames written for video avnqydkqjj.mp4 are 150 in folder frames\fake\avnqydkqjj_mp4
# ./fake/avssvvsdhz.mp4
# avssvvsdhz.mp4
# frames\fake\avssvvsdhz_mp4
# Total Frames written for video avssvvsdhz.mp4 are 150 in folder frames\fake\avssvvsdhz_mp4
# ./fake/avtycwsgyb.mp4
# avtycwsgyb.mp4
# frames\fake\avtycwsgyb_mp4
# Total Frames written for video avtycwsgyb.mp4 are 150 in folder frames\fake\avtycwsgyb_mp4
# ./fake/avvdgsennp.mp4
# avvdgsennp.mp4
# frames\fake\avvdgsennp_mp4
# Total Frames written for video avvdgsennp.mp4 are 150 in folder frames\fake\avvdgsennp_mp4
# ./fake/avywawptfc.mp4
# avywawptfc.mp4
# frames\fake\avywawptfc_mp4
# Total Frames written for video avywawptfc.mp4 are 150 in folder frames\fake\avywawptfc_mp4
# ./fake/awhmfnnjih.mp4
# awhmfnnjih.mp4
# frames\fake\awhmfnnjih_mp4
# Total Frames written for video awhmfnnjih.mp4 are 150 in folder frames\fake\awhmfnnjih_mp4
# ./fake/awnwkrqibf.mp4
# awnwkrqibf.mp4
# frames\fake\awnwkrqibf_mp4
# Total Frames written for video awnwkrqibf.mp4 are 150 in folder frames\fake\awnwkrqibf_mp4
# ./fake/awukslzjra.mp4
# awukslzjra.mp4
# frames\fake\awukslzjra_mp4
# Total Frames written for video awukslzjra.mp4 are 150 in folder frames\fake\awukslzjra_mp4
# ./fake/axczxisdtb.mp4
# axczxisdtb.mp4
# frames\fake\axczxisdtb_mp4
# Total Frames written for video axczxisdtb.mp4 are 150 in folder frames\fake\axczxisdtb_mp4
# ./fake/axoygtekut.mp4
# axoygtekut.mp4
# frames\fake\axoygtekut_mp4
# Total Frames written for video axoygtekut.mp4 are 149 in folder frames\fake\axoygtekut_mp4
# ./fake/axwgcsyphv.mp4
# axwgcsyphv.mp4
# frames\fake\axwgcsyphv_mp4
# Total Frames written for video axwgcsyphv.mp4 are 150 in folder frames\fake\axwgcsyphv_mp4
# ./fake/axwovszumc.mp4
# axwovszumc.mp4
# frames\fake\axwovszumc_mp4
# Total Frames written for video axwovszumc.mp4 are 150 in folder frames\fake\axwovszumc_mp4
# ./fake/ayqvfdhslr.mp4
# ayqvfdhslr.mp4
# frames\fake\ayqvfdhslr_mp4
# Total Frames written for video ayqvfdhslr.mp4 are 150 in folder frames\fake\ayqvfdhslr_mp4
# ./fake/azpuxunqyo.mp4
# azpuxunqyo.mp4
# frames\fake\azpuxunqyo_mp4
# Total Frames written for video azpuxunqyo.mp4 are 150 in folder frames\fake\azpuxunqyo_mp4
# ./fake/azsmewqghg.mp4
# azsmewqghg.mp4
# frames\fake\azsmewqghg_mp4
# Total Frames written for video azsmewqghg.mp4 are 150 in folder frames\fake\azsmewqghg_mp4
# ./fake/bahdpoesir.mp4
# bahdpoesir.mp4
# frames\fake\bahdpoesir_mp4
# Total Frames written for video bahdpoesir.mp4 are 150 in folder frames\fake\bahdpoesir_mp4
# ./fake/bbhpvrmbse.mp4
# bbhpvrmbse.mp4
# frames\fake\bbhpvrmbse_mp4
# Total Frames written for video bbhpvrmbse.mp4 are 150 in folder frames\fake\bbhpvrmbse_mp4
# ./fake/bbhtdfuqxq.mp4
# bbhtdfuqxq.mp4
# frames\fake\bbhtdfuqxq_mp4
# Total Frames written for video bbhtdfuqxq.mp4 are 150 in folder frames\fake\bbhtdfuqxq_mp4
# ./fake/bbvgxeczei.mp4
# bbvgxeczei.mp4
# frames\fake\bbvgxeczei_mp4
# Total Frames written for video bbvgxeczei.mp4 are 150 in folder frames\fake\bbvgxeczei_mp4
# ./fake/bchnbulevv.mp4
# bchnbulevv.mp4
# frames\fake\bchnbulevv_mp4
# Total Frames written for video bchnbulevv.mp4 are 150 in folder frames\fake\bchnbulevv_mp4
# ./fake/bctvsmddgq.mp4
# bctvsmddgq.mp4
# frames\fake\bctvsmddgq_mp4
# Total Frames written for video bctvsmddgq.mp4 are 150 in folder frames\fake\bctvsmddgq_mp4
# ./fake/bdbhekrrwo.mp4
# bdbhekrrwo.mp4
# frames\fake\bdbhekrrwo_mp4
# Total Frames written for video bdbhekrrwo.mp4 are 150 in folder frames\fake\bdbhekrrwo_mp4
# ./fake/bdgipnyobr.mp4
# bdgipnyobr.mp4
# frames\fake\bdgipnyobr_mp4
# Total Frames written for video bdgipnyobr.mp4 are 150 in folder frames\fake\bdgipnyobr_mp4
# ./fake/bdxuhamuqx.mp4
# bdxuhamuqx.mp4
# frames\fake\bdxuhamuqx_mp4
# Total Frames written for video bdxuhamuqx.mp4 are 150 in folder frames\fake\bdxuhamuqx_mp4
# ./fake/benmsfzfaz.mp4
# benmsfzfaz.mp4
# frames\fake\benmsfzfaz_mp4
# Total Frames written for video benmsfzfaz.mp4 are 150 in folder frames\fake\benmsfzfaz_mp4
# ./fake/bgaogsjehq.mp4
# bgaogsjehq.mp4
# frames\fake\bgaogsjehq_mp4
# Total Frames written for video bgaogsjehq.mp4 are 150 in folder frames\fake\bgaogsjehq_mp4
# ./fake/bggsurpgpr.mp4
# bggsurpgpr.mp4
# frames\fake\bggsurpgpr_mp4
# Total Frames written for video bggsurpgpr.mp4 are 150 in folder frames\fake\bggsurpgpr_mp4
# ./fake/bghphrsfxf.mp4
# bghphrsfxf.mp4
# frames\fake\bghphrsfxf_mp4
# Total Frames written for video bghphrsfxf.mp4 are 150 in folder frames\fake\bghphrsfxf_mp4
# ./fake/bgmlwsoamc.mp4
# bgmlwsoamc.mp4
# frames\fake\bgmlwsoamc_mp4
# Total Frames written for video bgmlwsoamc.mp4 are 150 in folder frames\fake\bgmlwsoamc_mp4
# ./fake/bguwlyazau.mp4
# bguwlyazau.mp4
# frames\fake\bguwlyazau_mp4
# Total Frames written for video bguwlyazau.mp4 are 150 in folder frames\fake\bguwlyazau_mp4
# ./fake/bhaaboftbc.mp4
# bhaaboftbc.mp4
# frames\fake\bhaaboftbc_mp4
# Total Frames written for video bhaaboftbc.mp4 are 150 in folder frames\fake\bhaaboftbc_mp4
# ./fake/bhbdugnurr.mp4
# bhbdugnurr.mp4
# frames\fake\bhbdugnurr_mp4
# Total Frames written for video bhbdugnurr.mp4 are 150 in folder frames\fake\bhbdugnurr_mp4
# ./fake/bhpwpydzpo.mp4
# bhpwpydzpo.mp4
# frames\fake\bhpwpydzpo_mp4
# Total Frames written for video bhpwpydzpo.mp4 are 150 in folder frames\fake\bhpwpydzpo_mp4
# ./fake/bhsluedavd.mp4
# bhsluedavd.mp4
# frames\fake\bhsluedavd_mp4
# Total Frames written for video bhsluedavd.mp4 are 150 in folder frames\fake\bhsluedavd_mp4
# ./fake/bjjbwsqjir.mp4
# bjjbwsqjir.mp4
# frames\fake\bjjbwsqjir_mp4
# Total Frames written for video bjjbwsqjir.mp4 are 150 in folder frames\fake\bjjbwsqjir_mp4
# ./fake/bjkmjilrxp.mp4
# bjkmjilrxp.mp4
# frames\fake\bjkmjilrxp_mp4
# Total Frames written for video bjkmjilrxp.mp4 are 150 in folder frames\fake\bjkmjilrxp_mp4
# ./fake/bjsmaqefoi.mp4
# bjsmaqefoi.mp4
# frames\fake\bjsmaqefoi_mp4
# Total Frames written for video bjsmaqefoi.mp4 are 150 in folder frames\fake\bjsmaqefoi_mp4
# ./fake/bkmdzhfzfh.mp4
# bkmdzhfzfh.mp4
# frames\fake\bkmdzhfzfh_mp4
# Total Frames written for video bkmdzhfzfh.mp4 are 150 in folder frames\fake\bkmdzhfzfh_mp4
# ./fake/bkvetcojbt.mp4
# bkvetcojbt.mp4
# frames\fake\bkvetcojbt_mp4
# Total Frames written for video bkvetcojbt.mp4 are 150 in folder frames\fake\bkvetcojbt_mp4
# ./fake/bkwxhglwct.mp4
# bkwxhglwct.mp4
# frames\fake\bkwxhglwct_mp4
# Total Frames written for video bkwxhglwct.mp4 are 150 in folder frames\fake\bkwxhglwct_mp4
# ./fake/blpchvmhxx.mp4
# blpchvmhxx.mp4
# frames\fake\blpchvmhxx_mp4
# Total Frames written for video blpchvmhxx.mp4 are 150 in folder frames\fake\blpchvmhxx_mp4
# ./fake/blzydqdfem.mp4
# blzydqdfem.mp4
# frames\fake\blzydqdfem_mp4
# Total Frames written for video blzydqdfem.mp4 are 150 in folder frames\fake\blzydqdfem_mp4
# ./fake/bmbbkwmxqj.mp4
# bmbbkwmxqj.mp4
# frames\fake\bmbbkwmxqj_mp4
# Total Frames written for video bmbbkwmxqj.mp4 are 150 in folder frames\fake\bmbbkwmxqj_mp4
# ./fake/bmehkyanbj.mp4
# bmehkyanbj.mp4
# frames\fake\bmehkyanbj_mp4
# Total Frames written for video bmehkyanbj.mp4 are 150 in folder frames\fake\bmehkyanbj_mp4
# ./fake/bmhvktyiwp.mp4
# bmhvktyiwp.mp4
# frames\fake\bmhvktyiwp_mp4
# Total Frames written for video bmhvktyiwp.mp4 are 150 in folder frames\fake\bmhvktyiwp_mp4
# ./fake/bmioepcpsx.mp4
# bmioepcpsx.mp4
# frames\fake\bmioepcpsx_mp4
# Total Frames written for video bmioepcpsx.mp4 are 150 in folder frames\fake\bmioepcpsx_mp4
# ./fake/bmjmjmbglm.mp4
# bmjmjmbglm.mp4
# frames\fake\bmjmjmbglm_mp4
# Total Frames written for video bmjmjmbglm.mp4 are 150 in folder frames\fake\bmjmjmbglm_mp4
# ./fake/bnbuonyoje.mp4
# bnbuonyoje.mp4
# frames\fake\bnbuonyoje_mp4
# Total Frames written for video bnbuonyoje.mp4 are 150 in folder frames\fake\bnbuonyoje_mp4
# ./fake/bndybcqhfr.mp4
# bndybcqhfr.mp4
# frames\fake\bndybcqhfr_mp4
# Total Frames written for video bndybcqhfr.mp4 are 150 in folder frames\fake\bndybcqhfr_mp4
# ./fake/bnjcdrfuov.mp4
# bnjcdrfuov.mp4
# frames\fake\bnjcdrfuov_mp4
# Total Frames written for video bnjcdrfuov.mp4 are 150 in folder frames\fake\bnjcdrfuov_mp4
# ./fake/bntlodcfeg.mp4
# bntlodcfeg.mp4
# frames\fake\bntlodcfeg_mp4
# Total Frames written for video bntlodcfeg.mp4 are 150 in folder frames\fake\bntlodcfeg_mp4
# ./fake/bofqajtwve.mp4
# bofqajtwve.mp4
# frames\fake\bofqajtwve_mp4
# Total Frames written for video bofqajtwve.mp4 are 150 in folder frames\fake\bofqajtwve_mp4
# ./fake/boovltmuwi.mp4
# boovltmuwi.mp4
# frames\fake\boovltmuwi_mp4
# Total Frames written for video boovltmuwi.mp4 are 150 in folder frames\fake\boovltmuwi_mp4
# ./fake/bopqhhalml.mp4
# bopqhhalml.mp4
# frames\fake\bopqhhalml_mp4
# Total Frames written for video bopqhhalml.mp4 are 150 in folder frames\fake\bopqhhalml_mp4
# ./fake/bourlmzsio.mp4
# bourlmzsio.mp4
# frames\fake\bourlmzsio_mp4
# Total Frames written for video bourlmzsio.mp4 are 150 in folder frames\fake\bourlmzsio_mp4
# ./fake/bpwzipqtxf.mp4
# bpwzipqtxf.mp4
# frames\fake\bpwzipqtxf_mp4
# Total Frames written for video bpwzipqtxf.mp4 are 150 in folder frames\fake\bpwzipqtxf_mp4
# ./fake/bpxckdzddv.mp4
# bpxckdzddv.mp4
# frames\fake\bpxckdzddv_mp4
# Total Frames written for video bpxckdzddv.mp4 are 150 in folder frames\fake\bpxckdzddv_mp4
# ./fake/bqdjzqhcft.mp4
# bqdjzqhcft.mp4
# frames\fake\bqdjzqhcft_mp4
# Total Frames written for video bqdjzqhcft.mp4 are 150 in folder frames\fake\bqdjzqhcft_mp4
# ./fake/bqeiblbxtl.mp4
# bqeiblbxtl.mp4
# frames\fake\bqeiblbxtl_mp4
# Total Frames written for video bqeiblbxtl.mp4 are 150 in folder frames\fake\bqeiblbxtl_mp4
# ./fake/bqhtpqmmqp.mp4
# bqhtpqmmqp.mp4
# frames\fake\bqhtpqmmqp_mp4
# Total Frames written for video bqhtpqmmqp.mp4 are 150 in folder frames\fake\bqhtpqmmqp_mp4
# ./fake/bqkdbcqjvb.mp4
# bqkdbcqjvb.mp4
# frames\fake\bqkdbcqjvb_mp4
# Total Frames written for video bqkdbcqjvb.mp4 are 150 in folder frames\fake\bqkdbcqjvb_mp4
# ./fake/bqnymlsayl.mp4
# bqnymlsayl.mp4
# frames\fake\bqnymlsayl_mp4
# Total Frames written for video bqnymlsayl.mp4 are 150 in folder frames\fake\bqnymlsayl_mp4
# ./fake/bqqpbzjgup.mp4
# bqqpbzjgup.mp4
# frames\fake\bqqpbzjgup_mp4
# Total Frames written for video bqqpbzjgup.mp4 are 150 in folder frames\fake\bqqpbzjgup_mp4
# ./fake/bqtuuwzdtr.mp4
# bqtuuwzdtr.mp4
# frames\fake\bqtuuwzdtr_mp4
# Total Frames written for video bqtuuwzdtr.mp4 are 150 in folder frames\fake\bqtuuwzdtr_mp4
# ./fake/brhalypwoo.mp4
# brhalypwoo.mp4
# frames\fake\brhalypwoo_mp4
# Total Frames written for video brhalypwoo.mp4 are 150 in folder frames\fake\brhalypwoo_mp4
# ./fake/brvqtabyxj.mp4
# brvqtabyxj.mp4
# frames\fake\brvqtabyxj_mp4
# Total Frames written for video brvqtabyxj.mp4 are 150 in folder frames\fake\brvqtabyxj_mp4
# ./fake/bseamdrpbj.mp4
# bseamdrpbj.mp4
# frames\fake\bseamdrpbj_mp4
# Total Frames written for video bseamdrpbj.mp4 are 150 in folder frames\fake\bseamdrpbj_mp4
# ./fake/bsfmwclnqy.mp4
# bsfmwclnqy.mp4
# frames\fake\bsfmwclnqy_mp4
# Total Frames written for video bsfmwclnqy.mp4 are 150 in folder frames\fake\bsfmwclnqy_mp4
# ./fake/bsqgziaylx.mp4
# bsqgziaylx.mp4
# frames\fake\bsqgziaylx_mp4
# Total Frames written for video bsqgziaylx.mp4 are 150 in folder frames\fake\bsqgziaylx_mp4
# ./fake/btiysiskpf.mp4
# btiysiskpf.mp4
# frames\fake\btiysiskpf_mp4
# Total Frames written for video btiysiskpf.mp4 are 150 in folder frames\fake\btiysiskpf_mp4
# ./fake/btjlfpzbdu.mp4
# btjlfpzbdu.mp4
# frames\fake\btjlfpzbdu_mp4
# Total Frames written for video btjlfpzbdu.mp4 are 150 in folder frames\fake\btjlfpzbdu_mp4
# ./fake/btjwbtsgln.mp4
# btjwbtsgln.mp4
# frames\fake\btjwbtsgln_mp4
# Total Frames written for video btjwbtsgln.mp4 are 150 in folder frames\fake\btjwbtsgln_mp4
# ./fake/btmsngnqhv.mp4
# btmsngnqhv.mp4
# frames\fake\btmsngnqhv_mp4
# Total Frames written for video btmsngnqhv.mp4 are 150 in folder frames\fake\btmsngnqhv_mp4
# ./fake/btohlidmru.mp4
# btohlidmru.mp4
# frames\fake\btohlidmru_mp4
# Total Frames written for video btohlidmru.mp4 are 150 in folder frames\fake\btohlidmru_mp4
# ./fake/btugrnoton.mp4
# btugrnoton.mp4
# frames\fake\btugrnoton_mp4
# Total Frames written for video btugrnoton.mp4 are 150 in folder frames\fake\btugrnoton_mp4
# ./fake/btunxncpjh.mp4
# btunxncpjh.mp4
# frames\fake\btunxncpjh_mp4
# Total Frames written for video btunxncpjh.mp4 are 150 in folder frames\fake\btunxncpjh_mp4
# ./fake/btxlttbpkj.mp4
# btxlttbpkj.mp4
# frames\fake\btxlttbpkj_mp4
# Total Frames written for video btxlttbpkj.mp4 are 150 in folder frames\fake\btxlttbpkj_mp4
# ./fake/bvgwelbeof.mp4
# bvgwelbeof.mp4
# frames\fake\bvgwelbeof_mp4
# Total Frames written for video bvgwelbeof.mp4 are 150 in folder frames\fake\bvgwelbeof_mp4
# ./fake/bvzjkezkms.mp4
# bvzjkezkms.mp4
# frames\fake\bvzjkezkms_mp4
# Total Frames written for video bvzjkezkms.mp4 are 150 in folder frames\fake\bvzjkezkms_mp4
# ./fake/bweezhfpzp.mp4
# bweezhfpzp.mp4
# frames\fake\bweezhfpzp_mp4
# Total Frames written for video bweezhfpzp.mp4 are 150 in folder frames\fake\bweezhfpzp_mp4
# ./fake/bwuwstvsbw.mp4
# bwuwstvsbw.mp4
# frames\fake\bwuwstvsbw_mp4
# Total Frames written for video bwuwstvsbw.mp4 are 150 in folder frames\fake\bwuwstvsbw_mp4
# ./fake/bydaidkpdp.mp4
# bydaidkpdp.mp4
# frames\fake\bydaidkpdp_mp4
# Total Frames written for video bydaidkpdp.mp4 are 150 in folder frames\fake\bydaidkpdp_mp4
# ./fake/byfenovjnf.mp4
# byfenovjnf.mp4
# frames\fake\byfenovjnf_mp4
# Total Frames written for video byfenovjnf.mp4 are 150 in folder frames\fake\byfenovjnf_mp4
# ./fake/byijojkdba.mp4
# byijojkdba.mp4
# frames\fake\byijojkdba_mp4
# Total Frames written for video byijojkdba.mp4 are 149 in folder frames\fake\byijojkdba_mp4
# ./fake/byofowlkki.mp4
# byofowlkki.mp4
# frames\fake\byofowlkki_mp4
# Total Frames written for video byofowlkki.mp4 are 150 in folder frames\fake\byofowlkki_mp4
# ./fake/byqzyxifza.mp4
# byqzyxifza.mp4
# frames\fake\byqzyxifza_mp4
# Total Frames written for video byqzyxifza.mp4 are 150 in folder frames\fake\byqzyxifza_mp4
# ./fake/byunigvnay.mp4
# byunigvnay.mp4
# frames\fake\byunigvnay_mp4
# Total Frames written for video byunigvnay.mp4 are 150 in folder frames\fake\byunigvnay_mp4
# ./fake/byyqectxqa.mp4
# byyqectxqa.mp4
# frames\fake\byyqectxqa_mp4
# Total Frames written for video byyqectxqa.mp4 are 150 in folder frames\fake\byyqectxqa_mp4
# ./fake/bzmdrafeex.mp4
# bzmdrafeex.mp4
# frames\fake\bzmdrafeex_mp4
# Total Frames written for video bzmdrafeex.mp4 are 150 in folder frames\fake\bzmdrafeex_mp4
# ./fake/caqbrkogkb.mp4
# caqbrkogkb.mp4
# frames\fake\caqbrkogkb_mp4
# Total Frames written for video caqbrkogkb.mp4 are 150 in folder frames\fake\caqbrkogkb_mp4
# ./fake/cbbibzcoih.mp4
# cbbibzcoih.mp4
# frames\fake\cbbibzcoih_mp4
# Total Frames written for video cbbibzcoih.mp4 are 150 in folder frames\fake\cbbibzcoih_mp4
# ./fake/cbltdtxglo.mp4
# cbltdtxglo.mp4
# frames\fake\cbltdtxglo_mp4
# Total Frames written for video cbltdtxglo.mp4 are 150 in folder frames\fake\cbltdtxglo_mp4
# ./fake/ccmonzqfrz.mp4
# ccmonzqfrz.mp4
# frames\fake\ccmonzqfrz_mp4
# Total Frames written for video ccmonzqfrz.mp4 are 150 in folder frames\fake\ccmonzqfrz_mp4
# ./fake/cdaxixbosp.mp4
# cdaxixbosp.mp4
# frames\fake\cdaxixbosp_mp4
# Total Frames written for video cdaxixbosp.mp4 are 150 in folder frames\fake\cdaxixbosp_mp4
# ./fake/cdbsbdymzd.mp4
# cdbsbdymzd.mp4
# frames\fake\cdbsbdymzd_mp4
# Total Frames written for video cdbsbdymzd.mp4 are 150 in folder frames\fake\cdbsbdymzd_mp4
# ./fake/cdphtzqrvp.mp4
# cdphtzqrvp.mp4
# frames\fake\cdphtzqrvp_mp4
# Total Frames written for video cdphtzqrvp.mp4 are 150 in folder frames\fake\cdphtzqrvp_mp4
# ./fake/cdyakrxkia.mp4
# cdyakrxkia.mp4
# frames\fake\cdyakrxkia_mp4
# Total Frames written for video cdyakrxkia.mp4 are 150 in folder frames\fake\cdyakrxkia_mp4
# ./fake/cepxysienc.mp4
# cepxysienc.mp4
# frames\fake\cepxysienc_mp4
# Total Frames written for video cepxysienc.mp4 are 150 in folder frames\fake\cepxysienc_mp4
# ./fake/cettndmvzl.mp4
# cettndmvzl.mp4
# frames\fake\cettndmvzl_mp4
# Total Frames written for video cettndmvzl.mp4 are 150 in folder frames\fake\cettndmvzl_mp4
# ./fake/ceymbecxnj.mp4
# ceymbecxnj.mp4
# frames\fake\ceymbecxnj_mp4
# Total Frames written for video ceymbecxnj.mp4 are 150 in folder frames\fake\ceymbecxnj_mp4
# ./fake/cferslmfwh.mp4
# cferslmfwh.mp4
# frames\fake\cferslmfwh_mp4
# Total Frames written for video cferslmfwh.mp4 are 150 in folder frames\fake\cferslmfwh_mp4
# ./fake/cffffbcywc.mp4
# cffffbcywc.mp4
# frames\fake\cffffbcywc_mp4
# Total Frames written for video cffffbcywc.mp4 are 150 in folder frames\fake\cffffbcywc_mp4
# ./fake/cfyduhpbps.mp4
# cfyduhpbps.mp4
# frames\fake\cfyduhpbps_mp4
# Total Frames written for video cfyduhpbps.mp4 are 150 in folder frames\fake\cfyduhpbps_mp4
# ./fake/cglxirfaey.mp4
# cglxirfaey.mp4
# frames\fake\cglxirfaey_mp4
# Total Frames written for video cglxirfaey.mp4 are 150 in folder frames\fake\cglxirfaey_mp4
# ./fake/cgvrgibpfo.mp4
# cgvrgibpfo.mp4
# frames\fake\cgvrgibpfo_mp4
# Total Frames written for video cgvrgibpfo.mp4 are 150 in folder frames\fake\cgvrgibpfo_mp4
# ./fake/chzieimrwu.mp4
# chzieimrwu.mp4
# frames\fake\chzieimrwu_mp4
# Total Frames written for video chzieimrwu.mp4 are 149 in folder frames\fake\chzieimrwu_mp4
# ./fake/ckbdwedgmc.mp4
# ckbdwedgmc.mp4
# frames\fake\ckbdwedgmc_mp4
# Total Frames written for video ckbdwedgmc.mp4 are 150 in folder frames\fake\ckbdwedgmc_mp4
# ./fake/cknyxaqouy.mp4
# cknyxaqouy.mp4
# frames\fake\cknyxaqouy_mp4
# Total Frames written for video cknyxaqouy.mp4 are 150 in folder frames\fake\cknyxaqouy_mp4
# ./fake/cksanfsjhc.mp4
# cksanfsjhc.mp4
# frames\fake\cksanfsjhc_mp4
# Total Frames written for video cksanfsjhc.mp4 are 150 in folder frames\fake\cksanfsjhc_mp4
# ./fake/clihsshdkq.mp4
# clihsshdkq.mp4
# frames\fake\clihsshdkq_mp4
# Total Frames written for video clihsshdkq.mp4 are 150 in folder frames\fake\clihsshdkq_mp4
# ./fake/cmxcfkrjiv.mp4
# cmxcfkrjiv.mp4
# frames\fake\cmxcfkrjiv_mp4
# Total Frames written for video cmxcfkrjiv.mp4 are 150 in folder frames\fake\cmxcfkrjiv_mp4
# ./fake/cnilkgvfei.mp4
# cnilkgvfei.mp4
# frames\fake\cnilkgvfei_mp4
# Total Frames written for video cnilkgvfei.mp4 are 150 in folder frames\fake\cnilkgvfei_mp4
# ./fake/coadfnerlk.mp4
# coadfnerlk.mp4
# frames\fake\coadfnerlk_mp4
# Total Frames written for video coadfnerlk.mp4 are 150 in folder frames\fake\coadfnerlk_mp4
# ./fake/covdcysmbi.mp4
# covdcysmbi.mp4
# frames\fake\covdcysmbi_mp4
# Total Frames written for video covdcysmbi.mp4 are 150 in folder frames\fake\covdcysmbi_mp4
# ./fake/cqfugiqupm.mp4
# cqfugiqupm.mp4
# frames\fake\cqfugiqupm_mp4
# Total Frames written for video cqfugiqupm.mp4 are 150 in folder frames\fake\cqfugiqupm_mp4
# ./fake/cqhngvpgyi.mp4
# cqhngvpgyi.mp4
# frames\fake\cqhngvpgyi_mp4
# Total Frames written for video cqhngvpgyi.mp4 are 150 in folder frames\fake\cqhngvpgyi_mp4
# ./fake/cqrskwiqng.mp4
# cqrskwiqng.mp4
# frames\fake\cqrskwiqng_mp4
# Total Frames written for video cqrskwiqng.mp4 are 150 in folder frames\fake\cqrskwiqng_mp4
# ./fake/crktehraph.mp4
# crktehraph.mp4
# frames\fake\crktehraph_mp4
# Total Frames written for video crktehraph.mp4 are 150 in folder frames\fake\crktehraph_mp4
# ./fake/crzfebnfgb.mp4
# crzfebnfgb.mp4
# frames\fake\crzfebnfgb_mp4
# Total Frames written for video crzfebnfgb.mp4 are 150 in folder frames\fake\crzfebnfgb_mp4
# ./fake/cthdnahrkh.mp4
# cthdnahrkh.mp4
# frames\fake\cthdnahrkh_mp4
# Total Frames written for video cthdnahrkh.mp4 are 150 in folder frames\fake\cthdnahrkh_mp4
# ./fake/ctpqeykqdp.mp4
# ctpqeykqdp.mp4
# frames\fake\ctpqeykqdp_mp4
# Total Frames written for video ctpqeykqdp.mp4 are 150 in folder frames\fake\ctpqeykqdp_mp4
# ./fake/cttqtsjvgn.mp4
# cttqtsjvgn.mp4
# frames\fake\cttqtsjvgn_mp4
# Total Frames written for video cttqtsjvgn.mp4 are 150 in folder frames\fake\cttqtsjvgn_mp4
# ./fake/ctzmavwror.mp4
# ctzmavwror.mp4
# frames\fake\ctzmavwror_mp4
# Total Frames written for video ctzmavwror.mp4 are 150 in folder frames\fake\ctzmavwror_mp4
# ./fake/curpwogllm.mp4
# curpwogllm.mp4
# frames\fake\curpwogllm_mp4
# Total Frames written for video curpwogllm.mp4 are 150 in folder frames\fake\curpwogllm_mp4
# ./fake/cuzrgrbvil.mp4
# cuzrgrbvil.mp4
# frames\fake\cuzrgrbvil_mp4
# Total Frames written for video cuzrgrbvil.mp4 are 150 in folder frames\fake\cuzrgrbvil_mp4
# ./fake/cvaksbpssm.mp4
# cvaksbpssm.mp4
# frames\fake\cvaksbpssm_mp4
# Total Frames written for video cvaksbpssm.mp4 are 150 in folder frames\fake\cvaksbpssm_mp4
# ./fake/cwbacdwrzo.mp4
# cwbacdwrzo.mp4
# frames\fake\cwbacdwrzo_mp4
# Total Frames written for video cwbacdwrzo.mp4 are 150 in folder frames\fake\cwbacdwrzo_mp4
# ./fake/cwqlvzefpg.mp4
# cwqlvzefpg.mp4
# frames\fake\cwqlvzefpg_mp4
# Total Frames written for video cwqlvzefpg.mp4 are 150 in folder frames\fake\cwqlvzefpg_mp4
# ./fake/cwrtyzndpx.mp4
# cwrtyzndpx.mp4
# frames\fake\cwrtyzndpx_mp4
# Total Frames written for video cwrtyzndpx.mp4 are 150 in folder frames\fake\cwrtyzndpx_mp4
# ./fake/cwsbspfzck.mp4
# cwsbspfzck.mp4
# frames\fake\cwsbspfzck_mp4
# Total Frames written for video cwsbspfzck.mp4 are 150 in folder frames\fake\cwsbspfzck_mp4
# ./fake/cwwandrkus.mp4
# cwwandrkus.mp4
# frames\fake\cwwandrkus_mp4
# Total Frames written for video cwwandrkus.mp4 are 150 in folder frames\fake\cwwandrkus_mp4
# ./fake/cxfujlvsuw.mp4
# cxfujlvsuw.mp4
# frames\fake\cxfujlvsuw_mp4
# Total Frames written for video cxfujlvsuw.mp4 are 150 in folder frames\fake\cxfujlvsuw_mp4
# ./fake/cxrfacemmq.mp4
# cxrfacemmq.mp4
# frames\fake\cxrfacemmq_mp4
# Total Frames written for video cxrfacemmq.mp4 are 150 in folder frames\fake\cxrfacemmq_mp4
# ./fake/cxttmymlbn.mp4
# cxttmymlbn.mp4
# frames\fake\cxttmymlbn_mp4
# Total Frames written for video cxttmymlbn.mp4 are 150 in folder frames\fake\cxttmymlbn_mp4
# ./fake/cyboodqqyr.mp4
# cyboodqqyr.mp4
# frames\fake\cyboodqqyr_mp4
# Total Frames written for video cyboodqqyr.mp4 are 150 in folder frames\fake\cyboodqqyr_mp4
# ./fake/cycacemkmt.mp4
# cycacemkmt.mp4
# frames\fake\cycacemkmt_mp4
# Total Frames written for video cycacemkmt.mp4 are 150 in folder frames\fake\cycacemkmt_mp4
# ./fake/cyclgfjdrv.mp4
# cyclgfjdrv.mp4
# frames\fake\cyclgfjdrv_mp4
# Total Frames written for video cyclgfjdrv.mp4 are 150 in folder frames\fake\cyclgfjdrv_mp4
# ./fake/czfunozvwp.mp4
# czfunozvwp.mp4
# frames\fake\czfunozvwp_mp4
# Total Frames written for video czfunozvwp.mp4 are 150 in folder frames\fake\czfunozvwp_mp4
# ./fake/czkdanyadc.mp4
# czkdanyadc.mp4
# frames\fake\czkdanyadc_mp4
# Total Frames written for video czkdanyadc.mp4 are 150 in folder frames\fake\czkdanyadc_mp4
# ./fake/czmqpxrqoh.mp4
# czmqpxrqoh.mp4
# frames\fake\czmqpxrqoh_mp4
# Total Frames written for video czmqpxrqoh.mp4 are 150 in folder frames\fake\czmqpxrqoh_mp4
# ./fake/dafhtipaml.mp4
# dafhtipaml.mp4
# frames\fake\dafhtipaml_mp4
# Total Frames written for video dafhtipaml.mp4 are 150 in folder frames\fake\dafhtipaml_mp4
# ./fake/dakqwktlbi.mp4
# dakqwktlbi.mp4
# frames\fake\dakqwktlbi_mp4
# Total Frames written for video dakqwktlbi.mp4 are 150 in folder frames\fake\dakqwktlbi_mp4
# ./fake/dbhoxkblzx.mp4
# dbhoxkblzx.mp4
# frames\fake\dbhoxkblzx_mp4
# Total Frames written for video dbhoxkblzx.mp4 are 150 in folder frames\fake\dbhoxkblzx_mp4
# ./fake/dbhrpizyeq.mp4
# dbhrpizyeq.mp4
# frames\fake\dbhrpizyeq_mp4
# Total Frames written for video dbhrpizyeq.mp4 are 149 in folder frames\fake\dbhrpizyeq_mp4
# ./fake/dboxtiehng.mp4
# dboxtiehng.mp4
# frames\fake\dboxtiehng_mp4
# Total Frames written for video dboxtiehng.mp4 are 150 in folder frames\fake\dboxtiehng_mp4
# ./fake/dbzcqmxzaj.mp4
# dbzcqmxzaj.mp4
# frames\fake\dbzcqmxzaj_mp4
# Total Frames written for video dbzcqmxzaj.mp4 are 150 in folder frames\fake\dbzcqmxzaj_mp4
# ./fake/dbzpcjntve.mp4
# dbzpcjntve.mp4
# frames\fake\dbzpcjntve_mp4
# Total Frames written for video dbzpcjntve.mp4 are 150 in folder frames\fake\dbzpcjntve_mp4
# ./fake/dcamvmuors.mp4
# dcamvmuors.mp4
# frames\fake\dcamvmuors_mp4
# Total Frames written for video dcamvmuors.mp4 are 150 in folder frames\fake\dcamvmuors_mp4
# ./fake/dcuiiorugd.mp4
# dcuiiorugd.mp4
# frames\fake\dcuiiorugd_mp4
# Total Frames written for video dcuiiorugd.mp4 are 150 in folder frames\fake\dcuiiorugd_mp4
# ./fake/ddhfabwpuz.mp4
# ddhfabwpuz.mp4
# frames\fake\ddhfabwpuz_mp4
# Total Frames written for video ddhfabwpuz.mp4 are 150 in folder frames\fake\ddhfabwpuz_mp4
# ./fake/ddjggcasdw.mp4
# ddjggcasdw.mp4
# frames\fake\ddjggcasdw_mp4
# Total Frames written for video ddjggcasdw.mp4 are 150 in folder frames\fake\ddjggcasdw_mp4
# ./fake/ddpvuimigj.mp4
# ddpvuimigj.mp4
# frames\fake\ddpvuimigj_mp4
# Total Frames written for video ddpvuimigj.mp4 are 150 in folder frames\fake\ddpvuimigj_mp4
# ./fake/ddqccgmtka.mp4
# ddqccgmtka.mp4
# frames\fake\ddqccgmtka_mp4
# Total Frames written for video ddqccgmtka.mp4 are 150 in folder frames\fake\ddqccgmtka_mp4
# ./fake/degpbqvcay.mp4
# degpbqvcay.mp4
# frames\fake\degpbqvcay_mp4
# Total Frames written for video degpbqvcay.mp4 are 150 in folder frames\fake\degpbqvcay_mp4
# ./fake/deywhkarol.mp4
# deywhkarol.mp4
# frames\fake\deywhkarol_mp4
# Total Frames written for video deywhkarol.mp4 are 150 in folder frames\fake\deywhkarol_mp4
# ./fake/deyyistcrd.mp4
# deyyistcrd.mp4
# frames\fake\deyyistcrd_mp4
# Total Frames written for video deyyistcrd.mp4 are 150 in folder frames\fake\deyyistcrd_mp4
# ./fake/dfbpceeaox.mp4
# dfbpceeaox.mp4
# frames\fake\dfbpceeaox_mp4
# Total Frames written for video dfbpceeaox.mp4 are 150 in folder frames\fake\dfbpceeaox_mp4
# ./fake/dgmevclvzy.mp4
# dgmevclvzy.mp4
# frames\fake\dgmevclvzy_mp4
# Total Frames written for video dgmevclvzy.mp4 are 150 in folder frames\fake\dgmevclvzy_mp4
# ./fake/dgxrqjdomn.mp4
# dgxrqjdomn.mp4
# frames\fake\dgxrqjdomn_mp4
# Total Frames written for video dgxrqjdomn.mp4 are 150 in folder frames\fake\dgxrqjdomn_mp4
# ./fake/dgzklxjmix.mp4
# dgzklxjmix.mp4
# frames\fake\dgzklxjmix_mp4
# Total Frames written for video dgzklxjmix.mp4 are 150 in folder frames\fake\dgzklxjmix_mp4
# ./fake/dhcselezer.mp4
# dhcselezer.mp4
# frames\fake\dhcselezer_mp4
# Total Frames written for video dhcselezer.mp4 are 150 in folder frames\fake\dhcselezer_mp4
# ./fake/dhevettufk.mp4
# dhevettufk.mp4
# frames\fake\dhevettufk_mp4
# Total Frames written for video dhevettufk.mp4 are 149 in folder frames\fake\dhevettufk_mp4
# ./fake/dhjmzhrcav.mp4
# dhjmzhrcav.mp4
# frames\fake\dhjmzhrcav_mp4
# Total Frames written for video dhjmzhrcav.mp4 are 150 in folder frames\fake\dhjmzhrcav_mp4
# ./fake/dhkwmjxwrn.mp4
# dhkwmjxwrn.mp4
# frames\fake\dhkwmjxwrn_mp4
# Total Frames written for video dhkwmjxwrn.mp4 are 150 in folder frames\fake\dhkwmjxwrn_mp4
# ./fake/dhoqofwoxa.mp4
# dhoqofwoxa.mp4
# frames\fake\dhoqofwoxa_mp4
# Total Frames written for video dhoqofwoxa.mp4 are 150 in folder frames\fake\dhoqofwoxa_mp4
# ./fake/diomeixhrg.mp4
# diomeixhrg.mp4
# frames\fake\diomeixhrg_mp4
# Total Frames written for video diomeixhrg.mp4 are 150 in folder frames\fake\diomeixhrg_mp4
# ./fake/diopzaywor.mp4
# diopzaywor.mp4
# frames\fake\diopzaywor_mp4
# Total Frames written for video diopzaywor.mp4 are 150 in folder frames\fake\diopzaywor_mp4
# ./fake/diqraixiov.mp4
# diqraixiov.mp4
# frames\fake\diqraixiov_mp4
# Total Frames written for video diqraixiov.mp4 are 150 in folder frames\fake\diqraixiov_mp4
# ./fake/diuzrpqjli.mp4
# diuzrpqjli.mp4
# frames\fake\diuzrpqjli_mp4
# Total Frames written for video diuzrpqjli.mp4 are 150 in folder frames\fake\diuzrpqjli_mp4
# ./fake/djvtbgwdcc.mp4
# djvtbgwdcc.mp4
# frames\fake\djvtbgwdcc_mp4
# Total Frames written for video djvtbgwdcc.mp4 are 150 in folder frames\fake\djvtbgwdcc_mp4
# ./fake/djvutyvaio.mp4
# djvutyvaio.mp4
# frames\fake\djvutyvaio_mp4
# Total Frames written for video djvutyvaio.mp4 are 150 in folder frames\fake\djvutyvaio_mp4
# ./fake/dkdwxmtpuo.mp4
# dkdwxmtpuo.mp4
# frames\fake\dkdwxmtpuo_mp4
# Total Frames written for video dkdwxmtpuo.mp4 are 150 in folder frames\fake\dkdwxmtpuo_mp4
# ./fake/dkhlttuvmx.mp4
# dkhlttuvmx.mp4
# frames\fake\dkhlttuvmx_mp4
# Total Frames written for video dkhlttuvmx.mp4 are 150 in folder frames\fake\dkhlttuvmx_mp4
# ./fake/dkrvorliqc.mp4
# dkrvorliqc.mp4
# frames\fake\dkrvorliqc_mp4
# Total Frames written for video dkrvorliqc.mp4 are 150 in folder frames\fake\dkrvorliqc_mp4
# ./fake/dkwjwbwgey.mp4
# dkwjwbwgey.mp4
# frames\fake\dkwjwbwgey_mp4
# Total Frames written for video dkwjwbwgey.mp4 are 150 in folder frames\fake\dkwjwbwgey_mp4
# ./fake/dlrsbscitn.mp4
# dlrsbscitn.mp4
# frames\fake\dlrsbscitn_mp4
# Total Frames written for video dlrsbscitn.mp4 are 150 in folder frames\fake\dlrsbscitn_mp4
# ./fake/dnexlwbcxq.mp4
# dnexlwbcxq.mp4
# frames\fake\dnexlwbcxq_mp4
# Total Frames written for video dnexlwbcxq.mp4 are 150 in folder frames\fake\dnexlwbcxq_mp4
# ./fake/dnhvalzvrt.mp4
# dnhvalzvrt.mp4
# frames\fake\dnhvalzvrt_mp4
# Total Frames written for video dnhvalzvrt.mp4 are 150 in folder frames\fake\dnhvalzvrt_mp4
# ./fake/dntkzzzcdh.mp4
# dntkzzzcdh.mp4
# frames\fake\dntkzzzcdh_mp4
# Total Frames written for video dntkzzzcdh.mp4 are 150 in folder frames\fake\dntkzzzcdh_mp4
# ./fake/dnyvfblxpm.mp4
# dnyvfblxpm.mp4
# frames\fake\dnyvfblxpm_mp4
# Total Frames written for video dnyvfblxpm.mp4 are 150 in folder frames\fake\dnyvfblxpm_mp4
# ./fake/doanjploai.mp4
# doanjploai.mp4
# frames\fake\doanjploai_mp4
# Total Frames written for video doanjploai.mp4 are 150 in folder frames\fake\doanjploai_mp4
# ./fake/dofusvhnib.mp4
# dofusvhnib.mp4
# frames\fake\dofusvhnib_mp4
# Total Frames written for video dofusvhnib.mp4 are 150 in folder frames\fake\dofusvhnib_mp4
# ./fake/dozyddhild.mp4
# dozyddhild.mp4
# frames\fake\dozyddhild_mp4
# Total Frames written for video dozyddhild.mp4 are 149 in folder frames\fake\dozyddhild_mp4
# ./fake/dptbnjnkdg.mp4
# dptbnjnkdg.mp4
# frames\fake\dptbnjnkdg_mp4
# Total Frames written for video dptbnjnkdg.mp4 are 150 in folder frames\fake\dptbnjnkdg_mp4
# ./fake/dptrzdvwpg.mp4
# dptrzdvwpg.mp4
# frames\fake\dptrzdvwpg_mp4
# Total Frames written for video dptrzdvwpg.mp4 are 150 in folder frames\fake\dptrzdvwpg_mp4
# ./fake/dqnyszdong.mp4
# dqnyszdong.mp4
# frames\fake\dqnyszdong_mp4
# Total Frames written for video dqnyszdong.mp4 are 150 in folder frames\fake\dqnyszdong_mp4
# ./fake/dqppxmoqdl.mp4
# dqppxmoqdl.mp4
# frames\fake\dqppxmoqdl_mp4
# Total Frames written for video dqppxmoqdl.mp4 are 150 in folder frames\fake\dqppxmoqdl_mp4
# ./fake/dqqtjcryjv.mp4
# dqqtjcryjv.mp4
# frames\fake\dqqtjcryjv_mp4
# Total Frames written for video dqqtjcryjv.mp4 are 150 in folder frames\fake\dqqtjcryjv_mp4
# ./fake/dqswpjoepo.mp4
# dqswpjoepo.mp4
# frames\fake\dqswpjoepo_mp4
# Total Frames written for video dqswpjoepo.mp4 are 150 in folder frames\fake\dqswpjoepo_mp4
# ./fake/dqzreruvje.mp4
# dqzreruvje.mp4
# frames\fake\dqzreruvje_mp4
# Total Frames written for video dqzreruvje.mp4 are 150 in folder frames\fake\dqzreruvje_mp4
# ./fake/drgjzlxzxj.mp4
# drgjzlxzxj.mp4
# frames\fake\drgjzlxzxj_mp4
# Total Frames written for video drgjzlxzxj.mp4 are 150 in folder frames\fake\drgjzlxzxj_mp4
# ./fake/drsakwyvqv.mp4
# drsakwyvqv.mp4
# frames\fake\drsakwyvqv_mp4
# Total Frames written for video drsakwyvqv.mp4 are 150 in folder frames\fake\drsakwyvqv_mp4
# ./fake/drtbksnpol.mp4
# drtbksnpol.mp4
# frames\fake\drtbksnpol_mp4
# Total Frames written for video drtbksnpol.mp4 are 150 in folder frames\fake\drtbksnpol_mp4
# ./fake/dsdoseflas.mp4
# dsdoseflas.mp4
# frames\fake\dsdoseflas_mp4
# Total Frames written for video dsdoseflas.mp4 are 150 in folder frames\fake\dsdoseflas_mp4
# ./fake/dsgpbgsrdm.mp4
# dsgpbgsrdm.mp4
# frames\fake\dsgpbgsrdm_mp4
# Total Frames written for video dsgpbgsrdm.mp4 are 150 in folder frames\fake\dsgpbgsrdm_mp4
# ./fake/dsndhujjjb.mp4
# dsndhujjjb.mp4
# frames\fake\dsndhujjjb_mp4
# Total Frames written for video dsndhujjjb.mp4 are 150 in folder frames\fake\dsndhujjjb_mp4
# ./fake/dtbpmdqvao.mp4
# dtbpmdqvao.mp4
# frames\fake\dtbpmdqvao_mp4
# Total Frames written for video dtbpmdqvao.mp4 are 150 in folder frames\fake\dtbpmdqvao_mp4
# ./fake/dtocdfbwca.mp4
# dtocdfbwca.mp4
# frames\fake\dtocdfbwca_mp4
# Total Frames written for video dtocdfbwca.mp4 are 150 in folder frames\fake\dtocdfbwca_mp4
# ./fake/dubiroskqn.mp4
# dubiroskqn.mp4
# frames\fake\dubiroskqn_mp4
# Total Frames written for video dubiroskqn.mp4 are 150 in folder frames\fake\dubiroskqn_mp4
# ./fake/dulanfulol.mp4
# dulanfulol.mp4
# frames\fake\dulanfulol_mp4
# Total Frames written for video dulanfulol.mp4 are 150 in folder frames\fake\dulanfulol_mp4
# ./fake/duvyaxbzvp.mp4
# duvyaxbzvp.mp4
# frames\fake\duvyaxbzvp_mp4
# Total Frames written for video duvyaxbzvp.mp4 are 150 in folder frames\fake\duvyaxbzvp_mp4
# ./fake/duzuusuajr.mp4
# duzuusuajr.mp4
# frames\fake\duzuusuajr_mp4
# Total Frames written for video duzuusuajr.mp4 are 150 in folder frames\fake\duzuusuajr_mp4
# ./fake/dvakowbgbt.mp4
# dvakowbgbt.mp4
# frames\fake\dvakowbgbt_mp4
# Total Frames written for video dvakowbgbt.mp4 are 150 in folder frames\fake\dvakowbgbt_mp4
# ./fake/dvumqqhoac.mp4
# dvumqqhoac.mp4
# frames\fake\dvumqqhoac_mp4
# Total Frames written for video dvumqqhoac.mp4 are 150 in folder frames\fake\dvumqqhoac_mp4
# ./fake/dwediigjit.mp4
# dwediigjit.mp4
# frames\fake\dwediigjit_mp4
# Total Frames written for video dwediigjit.mp4 are 150 in folder frames\fake\dwediigjit_mp4
# ./fake/dxuliowugt.mp4
# dxuliowugt.mp4
# frames\fake\dxuliowugt_mp4
# Total Frames written for video dxuliowugt.mp4 are 150 in folder frames\fake\dxuliowugt_mp4
# ./fake/dxuplhwvig.mp4
# dxuplhwvig.mp4
# frames\fake\dxuplhwvig_mp4
# Total Frames written for video dxuplhwvig.mp4 are 150 in folder frames\fake\dxuplhwvig_mp4
# ./fake/dzieklokdr.mp4
# dzieklokdr.mp4
# frames\fake\dzieklokdr_mp4
# Total Frames written for video dzieklokdr.mp4 are 150 in folder frames\fake\dzieklokdr_mp4
# ./fake/dzqwgqewhu.mp4
# dzqwgqewhu.mp4
# frames\fake\dzqwgqewhu_mp4
# Total Frames written for video dzqwgqewhu.mp4 are 150 in folder frames\fake\dzqwgqewhu_mp4
# ./fake/dzvyfiarrq.mp4
# dzvyfiarrq.mp4
# frames\fake\dzvyfiarrq_mp4
# Total Frames written for video dzvyfiarrq.mp4 are 150 in folder frames\fake\dzvyfiarrq_mp4
# ./fake/dzwkmcwkwl.mp4
# dzwkmcwkwl.mp4
# frames\fake\dzwkmcwkwl_mp4
# Total Frames written for video dzwkmcwkwl.mp4 are 150 in folder frames\fake\dzwkmcwkwl_mp4
# ./fake/eahlqmfvtj.mp4
# eahlqmfvtj.mp4
# frames\fake\eahlqmfvtj_mp4
# Total Frames written for video eahlqmfvtj.mp4 are 150 in folder frames\fake\eahlqmfvtj_mp4
# ./fake/eajlrktemq.mp4
# eajlrktemq.mp4
# frames\fake\eajlrktemq_mp4
# Total Frames written for video eajlrktemq.mp4 are 150 in folder frames\fake\eajlrktemq_mp4
# ./fake/ebchwmwayp.mp4
# ebchwmwayp.mp4
# frames\fake\ebchwmwayp_mp4
# Total Frames written for video ebchwmwayp.mp4 are 150 in folder frames\fake\ebchwmwayp_mp4
# ./fake/ebebgmtlcu.mp4
# ebebgmtlcu.mp4
# frames\fake\ebebgmtlcu_mp4
# Total Frames written for video ebebgmtlcu.mp4 are 150 in folder frames\fake\ebebgmtlcu_mp4
# ./fake/ebeknhudxq.mp4
# ebeknhudxq.mp4
# frames\fake\ebeknhudxq_mp4
# Total Frames written for video ebeknhudxq.mp4 are 150 in folder frames\fake\ebeknhudxq_mp4
# ./fake/ebkzwjgjhq.mp4
# ebkzwjgjhq.mp4
# frames\fake\ebkzwjgjhq_mp4
# Total Frames written for video ebkzwjgjhq.mp4 are 150 in folder frames\fake\ebkzwjgjhq_mp4
# ./fake/ebywfrmhtd.mp4
# ebywfrmhtd.mp4
# frames\fake\ebywfrmhtd_mp4
# Total Frames written for video ebywfrmhtd.mp4 are 150 in folder frames\fake\ebywfrmhtd_mp4
# ./fake/ecnihjlfyt.mp4
# ecnihjlfyt.mp4
# frames\fake\ecnihjlfyt_mp4
# Total Frames written for video ecnihjlfyt.mp4 are 150 in folder frames\fake\ecnihjlfyt_mp4
# ./fake/ecuvtoltue.mp4
# ecuvtoltue.mp4
# frames\fake\ecuvtoltue_mp4
# Total Frames written for video ecuvtoltue.mp4 are 150 in folder frames\fake\ecuvtoltue_mp4
# ./fake/ecwaxgutkc.mp4
# ecwaxgutkc.mp4
# frames\fake\ecwaxgutkc_mp4
# Total Frames written for video ecwaxgutkc.mp4 are 150 in folder frames\fake\ecwaxgutkc_mp4
# ./fake/eczrseixwq.mp4
# eczrseixwq.mp4
# frames\fake\eczrseixwq_mp4
# Total Frames written for video eczrseixwq.mp4 are 150 in folder frames\fake\eczrseixwq_mp4
# ./fake/eebrkicpry.mp4
# eebrkicpry.mp4
# frames\fake\eebrkicpry_mp4
# Total Frames written for video eebrkicpry.mp4 are 150 in folder frames\fake\eebrkicpry_mp4
# ./fake/eebserckhh.mp4
# eebserckhh.mp4
# frames\fake\eebserckhh_mp4
# Total Frames written for video eebserckhh.mp4 are 150 in folder frames\fake\eebserckhh_mp4
# ./fake/eejswgycjc.mp4
# eejswgycjc.mp4
# frames\fake\eejswgycjc_mp4
# Total Frames written for video eejswgycjc.mp4 are 150 in folder frames\fake\eejswgycjc_mp4
# ./fake/eekozbeafq.mp4
# eekozbeafq.mp4
# frames\fake\eekozbeafq_mp4
# Total Frames written for video eekozbeafq.mp4 are 150 in folder frames\fake\eekozbeafq_mp4
# ./fake/eepezmygaq.mp4
# eepezmygaq.mp4
# frames\fake\eepezmygaq_mp4
# Total Frames written for video eepezmygaq.mp4 are 150 in folder frames\fake\eepezmygaq_mp4
# ./fake/eeyhxisdfh.mp4
# eeyhxisdfh.mp4
# frames\fake\eeyhxisdfh_mp4
# Total Frames written for video eeyhxisdfh.mp4 are 150 in folder frames\fake\eeyhxisdfh_mp4
# ./fake/efdyrflcpg.mp4
# efdyrflcpg.mp4
# frames\fake\efdyrflcpg_mp4
# Total Frames written for video efdyrflcpg.mp4 are 150 in folder frames\fake\efdyrflcpg_mp4
# ./fake/egbbcxcuqy.mp4
# egbbcxcuqy.mp4
# frames\fake\egbbcxcuqy_mp4
# Total Frames written for video egbbcxcuqy.mp4 are 150 in folder frames\fake\egbbcxcuqy_mp4
# ./fake/ehbnclaukr.mp4
# ehbnclaukr.mp4
# frames\fake\ehbnclaukr_mp4
# Total Frames written for video ehbnclaukr.mp4 are 150 in folder frames\fake\ehbnclaukr_mp4
# ./fake/ehdkmxgtxh.mp4
# ehdkmxgtxh.mp4
# frames\fake\ehdkmxgtxh_mp4
# Total Frames written for video ehdkmxgtxh.mp4 are 150 in folder frames\fake\ehdkmxgtxh_mp4
# ./fake/ehevsxtecd.mp4
# ehevsxtecd.mp4
# frames\fake\ehevsxtecd_mp4
# Total Frames written for video ehevsxtecd.mp4 are 150 in folder frames\fake\ehevsxtecd_mp4
# ./fake/ehfiekigla.mp4
# ehfiekigla.mp4
# frames\fake\ehfiekigla_mp4
# Total Frames written for video ehfiekigla.mp4 are 150 in folder frames\fake\ehfiekigla_mp4
# ./fake/ehieahnhte.mp4
# ehieahnhte.mp4
# frames\fake\ehieahnhte_mp4
# Total Frames written for video ehieahnhte.mp4 are 150 in folder frames\fake\ehieahnhte_mp4
# ./fake/eiriyukqqy.mp4
# eiriyukqqy.mp4
# frames\fake\eiriyukqqy_mp4
# Total Frames written for video eiriyukqqy.mp4 are 150 in folder frames\fake\eiriyukqqy_mp4
# ./fake/eivxffliio.mp4
# eivxffliio.mp4
# frames\fake\eivxffliio_mp4
# Total Frames written for video eivxffliio.mp4 are 150 in folder frames\fake\eivxffliio_mp4
# ./fake/eiwopxzjfn.mp4
# eiwopxzjfn.mp4
# frames\fake\eiwopxzjfn_mp4
# Total Frames written for video eiwopxzjfn.mp4 are 150 in folder frames\fake\eiwopxzjfn_mp4
# ./fake/eixwxvxbbn.mp4
# eixwxvxbbn.mp4
# frames\fake\eixwxvxbbn_mp4
# Total Frames written for video eixwxvxbbn.mp4 are 150 in folder frames\fake\eixwxvxbbn_mp4
# ./fake/ejkqesyvam.mp4
# ejkqesyvam.mp4
# frames\fake\ejkqesyvam_mp4
# Total Frames written for video ejkqesyvam.mp4 are 150 in folder frames\fake\ejkqesyvam_mp4
# ./fake/ekhacizpah.mp4
# ekhacizpah.mp4
# frames\fake\ekhacizpah_mp4
# Total Frames written for video ekhacizpah.mp4 are 150 in folder frames\fake\ekhacizpah_mp4
# ./fake/ekkdjkirzq.mp4
# ekkdjkirzq.mp4
# frames\fake\ekkdjkirzq_mp4
# Total Frames written for video ekkdjkirzq.mp4 are 150 in folder frames\fake\ekkdjkirzq_mp4
# ./fake/elginszwtk.mp4
# elginszwtk.mp4
# frames\fake\elginszwtk_mp4
# Total Frames written for video elginszwtk.mp4 are 150 in folder frames\fake\elginszwtk_mp4
# ./fake/elvvackpjh.mp4
# elvvackpjh.mp4
# frames\fake\elvvackpjh_mp4
# Total Frames written for video elvvackpjh.mp4 are 150 in folder frames\fake\elvvackpjh_mp4
# ./fake/emaalmsonj.mp4
# emaalmsonj.mp4
# frames\fake\emaalmsonj_mp4
# Total Frames written for video emaalmsonj.mp4 are 150 in folder frames\fake\emaalmsonj_mp4
# ./fake/emfbhytfhc.mp4
# emfbhytfhc.mp4
# frames\fake\emfbhytfhc_mp4
# Total Frames written for video emfbhytfhc.mp4 are 150 in folder frames\fake\emfbhytfhc_mp4
# ./fake/emgjphonqb.mp4
# emgjphonqb.mp4
# frames\fake\emgjphonqb_mp4
# Total Frames written for video emgjphonqb.mp4 are 150 in folder frames\fake\emgjphonqb_mp4
# ./fake/ensyyivobf.mp4
# ensyyivobf.mp4
# frames\fake\ensyyivobf_mp4
# Total Frames written for video ensyyivobf.mp4 are 150 in folder frames\fake\ensyyivobf_mp4
# ./fake/eoewqcpbgt.mp4
# eoewqcpbgt.mp4
# frames\fake\eoewqcpbgt_mp4
# Total Frames written for video eoewqcpbgt.mp4 are 150 in folder frames\fake\eoewqcpbgt_mp4
# ./fake/eprybmbpba.mp4
# eprybmbpba.mp4
# frames\fake\eprybmbpba_mp4
# Total Frames written for video eprybmbpba.mp4 are 150 in folder frames\fake\eprybmbpba_mp4
# ./fake/epymyyiblu.mp4
# epymyyiblu.mp4
# frames\fake\epymyyiblu_mp4
# Total Frames written for video epymyyiblu.mp4 are 150 in folder frames\fake\epymyyiblu_mp4
# ./fake/eqjscdagiv.mp4
# eqjscdagiv.mp4
# frames\fake\eqjscdagiv_mp4
# Total Frames written for video eqjscdagiv.mp4 are 150 in folder frames\fake\eqjscdagiv_mp4
# ./fake/eqvuznuwsa.mp4
# eqvuznuwsa.mp4
# frames\fake\eqvuznuwsa_mp4
# Total Frames written for video eqvuznuwsa.mp4 are 150 in folder frames\fake\eqvuznuwsa_mp4
# ./fake/erqgqacbqe.mp4
# erqgqacbqe.mp4
# frames\fake\erqgqacbqe_mp4
# Total Frames written for video erqgqacbqe.mp4 are 150 in folder frames\fake\erqgqacbqe_mp4
# ./fake/errocgcham.mp4
# errocgcham.mp4
# frames\fake\errocgcham_mp4
# Total Frames written for video errocgcham.mp4 are 150 in folder frames\fake\errocgcham_mp4
# ./fake/esckbnkkvb.mp4
# esckbnkkvb.mp4
# frames\fake\esckbnkkvb_mp4
# Total Frames written for video esckbnkkvb.mp4 are 150 in folder frames\fake\esckbnkkvb_mp4
# ./fake/esgftaficx.mp4
# esgftaficx.mp4
# frames\fake\esgftaficx_mp4
# Total Frames written for video esgftaficx.mp4 are 150 in folder frames\fake\esgftaficx_mp4
# ./fake/esnntzzajv.mp4
# esnntzzajv.mp4
# frames\fake\esnntzzajv_mp4
# Total Frames written for video esnntzzajv.mp4 are 149 in folder frames\fake\esnntzzajv_mp4
# ./fake/esxrvsgpvb.mp4
# esxrvsgpvb.mp4
# frames\fake\esxrvsgpvb_mp4
# Total Frames written for video esxrvsgpvb.mp4 are 150 in folder frames\fake\esxrvsgpvb_mp4
# ./fake/esyhwdfnxs.mp4
# esyhwdfnxs.mp4
# frames\fake\esyhwdfnxs_mp4
# Total Frames written for video esyhwdfnxs.mp4 are 150 in folder frames\fake\esyhwdfnxs_mp4
# ./fake/esyrimvzsa.mp4
# esyrimvzsa.mp4
# frames\fake\esyrimvzsa_mp4
# Total Frames written for video esyrimvzsa.mp4 are 150 in folder frames\fake\esyrimvzsa_mp4
# ./fake/etdcqxabww.mp4
# etdcqxabww.mp4
# frames\fake\etdcqxabww_mp4
# Total Frames written for video etdcqxabww.mp4 are 150 in folder frames\fake\etdcqxabww_mp4
# ./fake/etejaapnxh.mp4
# etejaapnxh.mp4
# frames\fake\etejaapnxh_mp4
# Total Frames written for video etejaapnxh.mp4 are 150 in folder frames\fake\etejaapnxh_mp4
# ./fake/etmcruaihe.mp4
# etmcruaihe.mp4
# frames\fake\etmcruaihe_mp4
# Total Frames written for video etmcruaihe.mp4 are 150 in folder frames\fake\etmcruaihe_mp4
# ./fake/etohcvnzbj.mp4
# etohcvnzbj.mp4
# frames\fake\etohcvnzbj_mp4
# Total Frames written for video etohcvnzbj.mp4 are 150 in folder frames\fake\etohcvnzbj_mp4
# ./fake/eukvucdetx.mp4
# eukvucdetx.mp4
# frames\fake\eukvucdetx_mp4
# Total Frames written for video eukvucdetx.mp4 are 150 in folder frames\fake\eukvucdetx_mp4

# %%
"""
Note: this takes a while
"""
for file in real:
    src_path = f'{destination_real}/{file}'
    save_frame(src_path)
# Out:
# ./real/abarnvbtwb.mp4
# abarnvbtwb.mp4
# frames\real\abarnvbtwb_mp4
# Total Frames written for video abarnvbtwb.mp4 are 150 in folder frames\real\abarnvbtwb_mp4
# ./real/aelfnikyqj.mp4
# aelfnikyqj.mp4
# frames\real\aelfnikyqj_mp4
# Total Frames written for video aelfnikyqj.mp4 are 150 in folder frames\real\aelfnikyqj_mp4
# ./real/afoovlsmtx.mp4
# afoovlsmtx.mp4
# frames\real\afoovlsmtx_mp4
# Total Frames written for video afoovlsmtx.mp4 are 150 in folder frames\real\afoovlsmtx_mp4
# ./real/agrmhtjdlk.mp4
# agrmhtjdlk.mp4
# frames\real\agrmhtjdlk_mp4
# Total Frames written for video agrmhtjdlk.mp4 are 150 in folder frames\real\agrmhtjdlk_mp4
# ./real/ahqqqilsxt.mp4
# ahqqqilsxt.mp4
# frames\real\ahqqqilsxt_mp4
# Total Frames written for video ahqqqilsxt.mp4 are 150 in folder frames\real\ahqqqilsxt_mp4
# ./real/ajqslcypsw.mp4
# ajqslcypsw.mp4
# frames\real\ajqslcypsw_mp4
# Total Frames written for video ajqslcypsw.mp4 are 150 in folder frames\real\ajqslcypsw_mp4
# ./real/anpuvshzoo.mp4
# anpuvshzoo.mp4
# frames\real\anpuvshzoo_mp4
# Total Frames written for video anpuvshzoo.mp4 are 150 in folder frames\real\anpuvshzoo_mp4
# ./real/asaxgevnnp.mp4
# asaxgevnnp.mp4
# frames\real\asaxgevnnp_mp4
# Total Frames written for video asaxgevnnp.mp4 are 150 in folder frames\real\asaxgevnnp_mp4
# ./real/atkdltyyen.mp4
# atkdltyyen.mp4
# frames\real\atkdltyyen_mp4
# Total Frames written for video atkdltyyen.mp4 are 150 in folder frames\real\atkdltyyen_mp4
# ./real/atvmxvwyns.mp4
# atvmxvwyns.mp4
# frames\real\atvmxvwyns_mp4
# Total Frames written for video atvmxvwyns.mp4 are 150 in folder frames\real\atvmxvwyns_mp4
# ./real/avmjormvsx.mp4
# avmjormvsx.mp4
# frames\real\avmjormvsx_mp4
# Total Frames written for video avmjormvsx.mp4 are 150 in folder frames\real\avmjormvsx_mp4
# ./real/axntxmycwd.mp4
# axntxmycwd.mp4
# frames\real\axntxmycwd_mp4
# Total Frames written for video axntxmycwd.mp4 are 150 in folder frames\real\axntxmycwd_mp4
# ./real/aybgughjxh.mp4
# aybgughjxh.mp4
# frames\real\aybgughjxh_mp4
# Total Frames written for video aybgughjxh.mp4 are 150 in folder frames\real\aybgughjxh_mp4
# ./real/aybumesmpk.mp4
# aybumesmpk.mp4
# frames\real\aybumesmpk_mp4
# Total Frames written for video aybumesmpk.mp4 are 150 in folder frames\real\aybumesmpk_mp4
# ./real/aytzyidmgs.mp4
# aytzyidmgs.mp4
# frames\real\aytzyidmgs_mp4
# Total Frames written for video aytzyidmgs.mp4 are 150 in folder frames\real\aytzyidmgs_mp4
# ./real/bddjdhzfze.mp4
# bddjdhzfze.mp4
# frames\real\bddjdhzfze_mp4
# Total Frames written for video bddjdhzfze.mp4 are 150 in folder frames\real\bddjdhzfze_mp4
# ./real/bdnaqemxmr.mp4
# bdnaqemxmr.mp4
# frames\real\bdnaqemxmr_mp4
# Total Frames written for video bdnaqemxmr.mp4 are 150 in folder frames\real\bdnaqemxmr_mp4
# ./real/beboztfcme.mp4
# beboztfcme.mp4
# frames\real\beboztfcme_mp4
# Total Frames written for video beboztfcme.mp4 are 149 in folder frames\real\beboztfcme_mp4
# ./real/bejhvclboh.mp4
# bejhvclboh.mp4
# frames\real\bejhvclboh_mp4
# Total Frames written for video bejhvclboh.mp4 are 150 in folder frames\real\bejhvclboh_mp4
# ./real/beyebyhrph.mp4
# beyebyhrph.mp4
# frames\real\beyebyhrph_mp4
# Total Frames written for video beyebyhrph.mp4 are 150 in folder frames\real\beyebyhrph_mp4
# ./real/bffwsjxghk.mp4
# bffwsjxghk.mp4
# frames\real\bffwsjxghk_mp4
# Total Frames written for video bffwsjxghk.mp4 are 150 in folder frames\real\bffwsjxghk_mp4
# ./real/bgvhtpzknn.mp4
# bgvhtpzknn.mp4
# frames\real\bgvhtpzknn_mp4
# Total Frames written for video bgvhtpzknn.mp4 are 150 in folder frames\real\bgvhtpzknn_mp4
# ./real/bgwmmujlmc.mp4
# bgwmmujlmc.mp4
# frames\real\bgwmmujlmc_mp4
# Total Frames written for video bgwmmujlmc.mp4 are 150 in folder frames\real\bgwmmujlmc_mp4
# ./real/bilnggbxgu.mp4
# bilnggbxgu.mp4
# frames\real\bilnggbxgu_mp4
# Total Frames written for video bilnggbxgu.mp4 are 150 in folder frames\real\bilnggbxgu_mp4
# ./real/bmjzrlszhi.mp4
# bmjzrlszhi.mp4
# frames\real\bmjzrlszhi_mp4
# Total Frames written for video bmjzrlszhi.mp4 are 150 in folder frames\real\bmjzrlszhi_mp4
# ./real/bpapbctoao.mp4
# bpapbctoao.mp4
# frames\real\bpapbctoao_mp4
# Total Frames written for video bpapbctoao.mp4 are 150 in folder frames\real\bpapbctoao_mp4
# ./real/brwrlczjvi.mp4
# brwrlczjvi.mp4
# frames\real\brwrlczjvi_mp4
# Total Frames written for video brwrlczjvi.mp4 are 150 in folder frames\real\brwrlczjvi_mp4
# ./real/bulkxhhknf.mp4
# bulkxhhknf.mp4
# frames\real\bulkxhhknf_mp4
# Total Frames written for video bulkxhhknf.mp4 are 150 in folder frames\real\bulkxhhknf_mp4
# ./real/bwhlgysghg.mp4
# bwhlgysghg.mp4
# frames\real\bwhlgysghg_mp4
# Total Frames written for video bwhlgysghg.mp4 are 150 in folder frames\real\bwhlgysghg_mp4
# ./real/bwipwzzxxu.mp4
# bwipwzzxxu.mp4
# frames\real\bwipwzzxxu_mp4
# Total Frames written for video bwipwzzxxu.mp4 are 150 in folder frames\real\bwipwzzxxu_mp4
# ./real/bxzakyopjf.mp4
# bxzakyopjf.mp4
# frames\real\bxzakyopjf_mp4
# Total Frames written for video bxzakyopjf.mp4 are 150 in folder frames\real\bxzakyopjf_mp4
# ./real/bzythlfnhq.mp4
# bzythlfnhq.mp4
# frames\real\bzythlfnhq_mp4
# Total Frames written for video bzythlfnhq.mp4 are 150 in folder frames\real\bzythlfnhq_mp4
# ./real/caifxvsozs.mp4
# caifxvsozs.mp4
# frames\real\caifxvsozs_mp4
# Total Frames written for video caifxvsozs.mp4 are 150 in folder frames\real\caifxvsozs_mp4
# ./real/ccfoszqabv.mp4
# ccfoszqabv.mp4
# frames\real\ccfoszqabv_mp4
# Total Frames written for video ccfoszqabv.mp4 are 150 in folder frames\real\ccfoszqabv_mp4
# ./real/cfxkpiweqt.mp4
# cfxkpiweqt.mp4
# frames\real\cfxkpiweqt_mp4
# Total Frames written for video cfxkpiweqt.mp4 are 150 in folder frames\real\cfxkpiweqt_mp4
# ./real/chtapglbcj.mp4
# chtapglbcj.mp4
# frames\real\chtapglbcj_mp4
# Total Frames written for video chtapglbcj.mp4 are 150 in folder frames\real\chtapglbcj_mp4
# ./real/chviwxsfhg.mp4
# chviwxsfhg.mp4
# frames\real\chviwxsfhg_mp4
# Total Frames written for video chviwxsfhg.mp4 are 150 in folder frames\real\chviwxsfhg_mp4
# ./real/ciyoudyhly.mp4
# ciyoudyhly.mp4
# frames\real\ciyoudyhly_mp4
# Total Frames written for video ciyoudyhly.mp4 are 150 in folder frames\real\ciyoudyhly_mp4
# ./real/cizlkenljw.mp4
# cizlkenljw.mp4
# frames\real\cizlkenljw_mp4
# Total Frames written for video cizlkenljw.mp4 are 150 in folder frames\real\cizlkenljw_mp4
# ./real/ckjaibzfxa.mp4
# ckjaibzfxa.mp4
# frames\real\ckjaibzfxa_mp4
# Total Frames written for video ckjaibzfxa.mp4 are 150 in folder frames\real\ckjaibzfxa_mp4
# ./real/ckkuyewywx.mp4
# ckkuyewywx.mp4
# frames\real\ckkuyewywx_mp4
# Total Frames written for video ckkuyewywx.mp4 are 150 in folder frames\real\ckkuyewywx_mp4
# ./real/clrycekyst.mp4
# clrycekyst.mp4
# frames\real\clrycekyst_mp4
# Total Frames written for video clrycekyst.mp4 are 150 in folder frames\real\clrycekyst_mp4
# ./real/cmbzllswnl.mp4
# cmbzllswnl.mp4
# frames\real\cmbzllswnl_mp4
# Total Frames written for video cmbzllswnl.mp4 are 150 in folder frames\real\cmbzllswnl_mp4
# ./real/cobjrlugvp.mp4
# cobjrlugvp.mp4
# frames\real\cobjrlugvp_mp4
# Total Frames written for video cobjrlugvp.mp4 are 150 in folder frames\real\cobjrlugvp_mp4
# ./real/cpjxareypw.mp4
# cpjxareypw.mp4
# frames\real\cpjxareypw_mp4
# Total Frames written for video cpjxareypw.mp4 are 150 in folder frames\real\cpjxareypw_mp4
# ./real/cppdvdejkc.mp4
# cppdvdejkc.mp4
# frames\real\cppdvdejkc_mp4
# Total Frames written for video cppdvdejkc.mp4 are 149 in folder frames\real\cppdvdejkc_mp4
# ./real/cprhtltsjp.mp4
# cprhtltsjp.mp4
# frames\real\cprhtltsjp_mp4
# Total Frames written for video cprhtltsjp.mp4 are 150 in folder frames\real\cprhtltsjp_mp4
# ./real/crezycjqyk.mp4
# crezycjqyk.mp4
# frames\real\crezycjqyk_mp4
# Total Frames written for video crezycjqyk.mp4 are 150 in folder frames\real\crezycjqyk_mp4
# ./real/cyxlcuyznd.mp4
# cyxlcuyznd.mp4
# frames\real\cyxlcuyznd_mp4
# Total Frames written for video cyxlcuyznd.mp4 are 150 in folder frames\real\cyxlcuyznd_mp4
# ./real/dakiztgtnw.mp4
# dakiztgtnw.mp4
# frames\real\dakiztgtnw_mp4
# Total Frames written for video dakiztgtnw.mp4 are 150 in folder frames\real\dakiztgtnw_mp4
# ./real/dbnygxtwek.mp4
# dbnygxtwek.mp4
# frames\real\dbnygxtwek_mp4
# Total Frames written for video dbnygxtwek.mp4 are 150 in folder frames\real\dbnygxtwek_mp4
# ./real/dbtbbhakdv.mp4
# dbtbbhakdv.mp4
# frames\real\dbtbbhakdv_mp4
# Total Frames written for video dbtbbhakdv.mp4 are 150 in folder frames\real\dbtbbhakdv_mp4
# ./real/ddepeddixj.mp4
# ddepeddixj.mp4
# frames\real\ddepeddixj_mp4
# Total Frames written for video ddepeddixj.mp4 are 149 in folder frames\real\ddepeddixj_mp4
# ./real/dhcndnuwta.mp4
# dhcndnuwta.mp4
# frames\real\dhcndnuwta_mp4
# Total Frames written for video dhcndnuwta.mp4 are 150 in folder frames\real\dhcndnuwta_mp4
# ./real/dhxctgyoqj.mp4
# dhxctgyoqj.mp4
# frames\real\dhxctgyoqj_mp4
# Total Frames written for video dhxctgyoqj.mp4 are 150 in folder frames\real\dhxctgyoqj_mp4
# ./real/djxdyjopjd.mp4
# djxdyjopjd.mp4
# frames\real\djxdyjopjd_mp4
# Total Frames written for video djxdyjopjd.mp4 are 150 in folder frames\real\djxdyjopjd_mp4
# ./real/dkuayagnmc.mp4
# dkuayagnmc.mp4
# frames\real\dkuayagnmc_mp4
# Total Frames written for video dkuayagnmc.mp4 are 150 in folder frames\real\dkuayagnmc_mp4
# ./real/dkzvdrzcnr.mp4
# dkzvdrzcnr.mp4
# frames\real\dkzvdrzcnr_mp4
# Total Frames written for video dkzvdrzcnr.mp4 are 150 in folder frames\real\dkzvdrzcnr_mp4
# ./real/dlpoieqvfb.mp4
# dlpoieqvfb.mp4
# frames\real\dlpoieqvfb_mp4
# Total Frames written for video dlpoieqvfb.mp4 are 150 in folder frames\real\dlpoieqvfb_mp4
# ./real/drcyabprvt.mp4
# drcyabprvt.mp4
# frames\real\drcyabprvt_mp4
# Total Frames written for video drcyabprvt.mp4 are 150 in folder frames\real\drcyabprvt_mp4
# ./real/dsjbknkujw.mp4
# dsjbknkujw.mp4
# frames\real\dsjbknkujw_mp4
# Total Frames written for video dsjbknkujw.mp4 are 150 in folder frames\real\dsjbknkujw_mp4
# ./real/duycddgtrl.mp4
# duycddgtrl.mp4
# frames\real\duycddgtrl_mp4
# Total Frames written for video duycddgtrl.mp4 are 150 in folder frames\real\duycddgtrl_mp4
# ./real/dxbqjxrhin.mp4
# dxbqjxrhin.mp4
# frames\real\dxbqjxrhin_mp4
# Total Frames written for video dxbqjxrhin.mp4 are 150 in folder frames\real\dxbqjxrhin_mp4
# ./real/dzyuwjkjui.mp4
# dzyuwjkjui.mp4
# frames\real\dzyuwjkjui_mp4
# Total Frames written for video dzyuwjkjui.mp4 are 150 in folder frames\real\dzyuwjkjui_mp4
# ./real/eckvhdusax.mp4
# eckvhdusax.mp4
# frames\real\eckvhdusax_mp4
# Total Frames written for video eckvhdusax.mp4 are 150 in folder frames\real\eckvhdusax_mp4
# ./real/ecujsjhscd.mp4
# ecujsjhscd.mp4
# frames\real\ecujsjhscd_mp4
# Total Frames written for video ecujsjhscd.mp4 are 150 in folder frames\real\ecujsjhscd_mp4
# ./real/edyncaijwx.mp4
# edyncaijwx.mp4
# frames\real\edyncaijwx_mp4
# Total Frames written for video edyncaijwx.mp4 are 150 in folder frames\real\edyncaijwx_mp4
# ./real/efwfxwwlbw.mp4
# efwfxwwlbw.mp4
# frames\real\efwfxwwlbw_mp4
# Total Frames written for video efwfxwwlbw.mp4 are 150 in folder frames\real\efwfxwwlbw_mp4
# ./real/eggbjzxnmg.mp4
# eggbjzxnmg.mp4
# frames\real\eggbjzxnmg_mp4
# Total Frames written for video eggbjzxnmg.mp4 are 150 in folder frames\real\eggbjzxnmg_mp4
# ./real/egghxjjmfg.mp4
# egghxjjmfg.mp4
# frames\real\egghxjjmfg_mp4
# Total Frames written for video egghxjjmfg.mp4 are 150 in folder frames\real\egghxjjmfg_mp4
# ./real/ehccixxzoe.mp4
# ehccixxzoe.mp4
# frames\real\ehccixxzoe_mp4
# Total Frames written for video ehccixxzoe.mp4 are 150 in folder frames\real\ehccixxzoe_mp4
# ./real/ehtdtkmmli.mp4
# ehtdtkmmli.mp4
# frames\real\ehtdtkmmli_mp4
# Total Frames written for video ehtdtkmmli.mp4 are 150 in folder frames\real\ehtdtkmmli_mp4
# ./real/ekcrtigpab.mp4
# ekcrtigpab.mp4
# frames\real\ekcrtigpab_mp4
# Total Frames written for video ekcrtigpab.mp4 are 150 in folder frames\real\ekcrtigpab_mp4
# ./real/ellavthztb.mp4
# ellavthztb.mp4
# frames\real\ellavthztb_mp4
# Total Frames written for video ellavthztb.mp4 are 150 in folder frames\real\ellavthztb_mp4
# ./real/eqnoqyfquo.mp4
# eqnoqyfquo.mp4
# frames\real\eqnoqyfquo_mp4
# Total Frames written for video eqnoqyfquo.mp4 are 150 in folder frames\real\eqnoqyfquo_mp4
# ./real/erlvuvjsjf.mp4
# erlvuvjsjf.mp4
# frames\real\erlvuvjsjf_mp4
# Total Frames written for video erlvuvjsjf.mp4 are 150 in folder frames\real\erlvuvjsjf_mp4
# ./real/eudeqjhdfd.mp4
# eudeqjhdfd.mp4
# frames\real\eudeqjhdfd_mp4
# Total Frames written for video eudeqjhdfd.mp4 are 150 in folder frames\real\eudeqjhdfd_mp4

# %% [markdown]
# ## Train-Test-Val Split

# %%
fake_folders = os.listdir('frames/fake')
print(len(fake_folders))
real_folders = os.listdir('frames/real')
print(len(real_folders))
# Out:
# 323
# 77

# %%
shuffle(fake_folders)
shuffle(real_folders)

# %%
train_fake = fake_folders[:259]
test_fake = fake_folders[259:291]
val_fake = fake_folders[291:]

# %%
train_real = real_folders[:61]
test_real = real_folders[61:69]
val_real = real_folders[69:]

# %%
os.mkdir('frames/train')
os.mkdir('frames/test')
os.mkdir('frames/val')

# %%
os.mkdir('frames/train/fake')
os.mkdir('frames/train/real')
os.mkdir('frames/test/fake')
os.mkdir('frames/test/real')
os.mkdir('frames/val/fake')
os.mkdir('frames/val/real')

# %%
root = 'frames/real'
destination_train = 'frames/train/real'
for file in train_real:
    src_path = f'{root}/{file}'
    shutil.move(src_path, destination_train)
    
destination_test = 'frames/test/real'
for file in test_real:
    src_path = f'{root}/{file}'
    shutil.move(src_path, destination_test)
    
destination_val = 'frames/val/real'
for file in val_real:
    src_path = f'{root}/{file}'
    shutil.move(src_path, destination_val)

# %%
root = 'frames/fake'
destination_train = 'frames/train/fake'
for file in train_fake:
    src_path = f'{root}/{file}'
    shutil.move(src_path, destination_train)
    
destination_test = 'frames/test/fake'
for file in test_fake:
    src_path = f'{root}/{file}'
    shutil.move(src_path, destination_test)
    
destination_val = 'frames/val/fake'
for file in val_fake:
    src_path = f'{root}/{file}'
    shutil.move(src_path, destination_val)

# %%
os.rmdir('frames/fake')
os.rmdir('frames/real')
