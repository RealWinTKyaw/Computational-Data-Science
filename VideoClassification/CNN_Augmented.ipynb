# %% [markdown]
# ## Imports & Setup

# %%
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Compose, Resize, RandomHorizontalFlip
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, precision_score, recall_score
from helpers import *
from architecture.CNN import *

# %% [markdown]
# from torchsampler import ImbalancedDatasetSampler

# %%
torch.manual_seed(809)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# RandomAffine(degrees=(-30,30),translate=(0.1,0.1),shear=(-10,10)),
#                           RandomResizedCrop((size,size),scale=(0.8,1),ratio=(0.9,1.1)),

# %% [markdown]
# ## Prepare Dataset

# %%
def create_subsets(root, transformation):
    dataset = ImageFolder(root, transformation)
    train, test, val = torch.utils.data.random_split(dataset, [0.8, 0.1, 0.1])
    return train, test, val

# %%
def produce_loaders(train, test, val):
    train_loader = torch.utils.data.DataLoader(train, batch_size = batch_size, shuffle = True)
    test_loader = torch.utils.data.DataLoader(test, batch_size = batch_size, shuffle = False)
    valid_loader = torch.utils.data.DataLoader(val, batch_size = batch_size, shuffle = False)
    return train_loader, test_loader, valid_loader

# %%
size = 44
batch_size = 256
transformation = Compose([RandomHorizontalFlip(), 
                          Resize((size, size)), ToTensor()])

# %%
root = 'expanded_dataset/cropped_aug'
train_data, test_data, val_data = create_subsets(root, transformation)
train_loader, test_loader, val_loader = produce_loaders(train_data, test_data, val_data)

# %%
visualize_data(train_data)
# Out:
# [4572, 6343, 983, 7087, 7318, 7226, 1162, 4492, 8043]

# %%
visualize_data(test_data)
# Out:
# [797, 545, 271, 673, 21, 467, 757, 401, 755]

# %% [markdown]
# ## Initialize Model

# %%
def create_adam_optimizer(model, lr = 0.1, betas=(0.9, 0.999), amsgrad=False):
    return optim.Adam(model.parameters(), lr = lr, amsgrad=amsgrad, betas=betas)

# %%
from math import floor
# number of hidden layers and their sizes
hidden = [3, 256, 128, 64]

# kernel size of convolution layers
kernel_size = 3

# window size of maxpooling layer
window = 2

# calculate final size of image
channels = hidden[-1]
changed_img = floor( (size-(kernel_size-1)*(len(hidden)-1)) / window )

# calculate dimension of flattened image
flattened = channels*changed_img*changed_img

# final linear layers and their sizes
hidden_linear = [flattened, 512, 64]

# %%
model = DeepSearch(hidden=hidden, kernel_size=kernel_size,
                   window=window, hidden_linear=hidden_linear).to(device)
#model.load_state_dict(torch.load("./DeepSearch2_15epochs")["model_state_dict"])
print(model)
# Out:
# DeepSearch(
#   (conv_combined): Sequential(
#     (0): DeepSearchConv(
#       (conv): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (1): DeepSearchConv(
#       (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (2): DeepSearchConv(
#       (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (linear_combined): Sequential(
#     (0): DeepSearchLinear(
#       (linear): Linear(in_features=23104, out_features=512, bias=True)
#       (batch_norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (1): DeepSearchLinear(
#       (linear): Linear(in_features=512, out_features=64, bias=True)
#       (batch_norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (output): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# ## Training Model

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
optimizer = create_adam_optimizer(model, lr=0.001)
#optimizer.load_state_dict(torch.load("./DeepSearch2_15epochs")["optimizer_state_dict"])

# %%
# repeat this cell with epochs = 1 for safety, but usually epochs = 3 is a good start

"""
train function params:
device
model - model to train
train_loader - training data loader
val_loader - validation data loader
optimizer - optimizer to use (allows for saving and reloading optimizer state to stop and resume training)
epochs
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)

returns lists of the training loss, training accuracy, validation loss and validation accuracy for plotting curves

"""
tl, ta, vl, va = train(device, model,
                       train_loader, val_loader, 
                       optimizer, epochs = 20)
train_losses+=tl
train_accuracies+=ta
val_losses+=vl
val_accuracies+=va
# Out:
# Epoch 1/20, Batch number: 0, Cumulated accuracy: 0.83203125
# Epoch 1/20, Batch number: 5, Cumulated accuracy: 0.873046875
# Epoch 1/20, Batch number: 10, Cumulated accuracy: 0.8696732954545454
# Epoch 1/20, Batch number: 15, Cumulated accuracy: 0.87109375
# Epoch 1/20, Batch number: 20, Cumulated accuracy: 0.8731398809523809
# Epoch 1/20, Batch number: 25, Cumulated accuracy: 0.8765024038461539
# Epoch 1/20, Batch number: 30, Cumulated accuracy: 0.8752520161290323
# --- Epoch 1/20: Train loss: 0.2863, Train accuracy: 0.8760
# --- Epoch 1/20: Val loss: 0.2658, Val accuracy: 0.8870
# Epoch 2/20, Batch number: 0, Cumulated accuracy: 0.875
# Epoch 2/20, Batch number: 5, Cumulated accuracy: 0.8756510416666666
# Epoch 2/20, Batch number: 10, Cumulated accuracy: 0.8757102272727273
# Epoch 2/20, Batch number: 15, Cumulated accuracy: 0.878173828125
# Epoch 2/20, Batch number: 20, Cumulated accuracy: 0.8746279761904762
# Epoch 2/20, Batch number: 25, Cumulated accuracy: 0.8786057692307693
# Epoch 2/20, Batch number: 30, Cumulated accuracy: 0.8802923387096774
# --- Epoch 2/20: Train loss: 0.2850, Train accuracy: 0.8810
# --- Epoch 2/20: Val loss: 0.2864, Val accuracy: 0.8725
# Epoch 3/20, Batch number: 0, Cumulated accuracy: 0.8671875
# Epoch 3/20, Batch number: 5, Cumulated accuracy: 0.8873697916666666
# Epoch 3/20, Batch number: 10, Cumulated accuracy: 0.8849431818181818
# Epoch 3/20, Batch number: 15, Cumulated accuracy: 0.8837890625
# Epoch 3/20, Batch number: 20, Cumulated accuracy: 0.8822544642857143
# Epoch 3/20, Batch number: 25, Cumulated accuracy: 0.8850661057692307
# Epoch 3/20, Batch number: 30, Cumulated accuracy: 0.8849546370967742
# --- Epoch 3/20: Train loss: 0.2773, Train accuracy: 0.8845
# --- Epoch 3/20: Val loss: 0.2382, Val accuracy: 0.9072
# Epoch 4/20, Batch number: 0, Cumulated accuracy: 0.859375
# Epoch 4/20, Batch number: 5, Cumulated accuracy: 0.890625
# Epoch 4/20, Batch number: 10, Cumulated accuracy: 0.8845880681818182
# Epoch 4/20, Batch number: 15, Cumulated accuracy: 0.887451171875
# Epoch 4/20, Batch number: 20, Cumulated accuracy: 0.8882068452380952
# Epoch 4/20, Batch number: 25, Cumulated accuracy: 0.8895733173076923
# Epoch 4/20, Batch number: 30, Cumulated accuracy: 0.8881048387096774
# --- Epoch 4/20: Train loss: 0.2676, Train accuracy: 0.8873
# --- Epoch 4/20: Val loss: 0.2402, Val accuracy: 0.9092
# Epoch 5/20, Batch number: 0, Cumulated accuracy: 0.90234375
# Epoch 5/20, Batch number: 5, Cumulated accuracy: 0.8880208333333334
# Epoch 5/20, Batch number: 10, Cumulated accuracy: 0.8888494318181818
# Epoch 5/20, Batch number: 15, Cumulated accuracy: 0.885498046875
# Epoch 5/20, Batch number: 20, Cumulated accuracy: 0.8891369047619048
# Epoch 5/20, Batch number: 25, Cumulated accuracy: 0.8865685096153846
# Epoch 5/20, Batch number: 30, Cumulated accuracy: 0.8833165322580645
# --- Epoch 5/20: Train loss: 0.2648, Train accuracy: 0.8841
# --- Epoch 5/20: Val loss: 0.2498, Val accuracy: 0.9024
# Epoch 6/20, Batch number: 0, Cumulated accuracy: 0.90234375
# Epoch 6/20, Batch number: 5, Cumulated accuracy: 0.8880208333333334
# Epoch 6/20, Batch number: 10, Cumulated accuracy: 0.8856534090909091
# Epoch 6/20, Batch number: 15, Cumulated accuracy: 0.882080078125
# Epoch 6/20, Batch number: 20, Cumulated accuracy: 0.8844866071428571
# Epoch 6/20, Batch number: 25, Cumulated accuracy: 0.8895733173076923
# Epoch 6/20, Batch number: 30, Cumulated accuracy: 0.887726814516129
# --- Epoch 6/20: Train loss: 0.2640, Train accuracy: 0.8880
# --- Epoch 6/20: Val loss: 0.2462, Val accuracy: 0.9043
# Stopped early due to increasing validation loss.

# %% [markdown]
# ## Testing Model & Performance Curves

# %%
"""
test function params:
device
model - model to train
data_loader - chosen (testing) data loader
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)
get_predictions - if True, returns the list of true labels, the list of predictions made by the model, 
                  and values of the test loss and test accuracy (default is False)

by default, returns values of the test loss and test accuracy

"""
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
# Out:
# Test loss: 0.1581, Test accuracy: 0.9324

# %%
show_metrics(true_labels, model_preds)
# Out:
# Precision: 0.9519230769230769
# Recall: 0.9166666666666666
# F1 score: 0.9339622641509433

# %%
model.load_state_dict(torch.load("./DeepSearch_checkpoint")["model_state_dict"])

# %%
model.load_state_dict(torch.load("./DeepSearch_checkpoint")["model_state_dict"])
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
show_metrics(true_labels, model_preds)
# Out:
# Test loss: 0.1824, Test accuracy: 0.9140
# Precision: 0.9519038076152304
# Recall: 0.8796296296296297
# F1 score: 0.9143407122232915

# %%
plt.plot(train_accuracies, "r--", label='Train accuracy')
plt.plot(val_accuracies, "b--", label='Validation accuracy')
plt.title("Final Test Accuracy: {}".format(test_accuracy))
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(train_losses, "r--", label='Training loss')
plt.plot(val_losses, "b--", label='Validation loss')
plt.title("Final Test Loss: {}".format(test_loss))
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Viewing Model Predictions

# %%
test_loader2 = produce_loader(test_data, 1)

# %%
correct_list, wrong_list, true_labels2, model_preds2 = get_pictures_test(device, model, test_loader2)

# %%
show_metrics(true_labels2, model_preds2)
# Out:
# Precision: 0.959758551307847
# Recall: 0.8833333333333333
# F1 score: 0.9199614271938282

# %%
visualize_data(correct_list, (12,12), 5)
# Out:
# [318, 810, 113, 299, 693, 536, 342, 376, 932, 933, 802, 862, 78, 677, 917, 600, 308, 98, 324, 676, 412, 229, 755, 322, 46]

# %%
visualize_data(wrong_list, (12,12), 5)
# Out:
# [71, 82, 39, 48, 43, 41, 26, 80, 47, 62, 64, 61, 18, 34, 68, 53, 44, 67, 39, 25, 50, 1, 53, 25, 8]

# %% [markdown]
# ## Saving Model

# %%
torch.save({'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict()}, 
            './DeepSearch_20epochs')

# %% [markdown]
# model_test = DeepLearn(kernels=kernels, hidden=hidden, kernel_size=kernel_size, window=window,
#                    hidden_linear=hidden_linear, labels=labels).to(device)
# model_test.load_state_dict(torch.load("./latest_16epochs")["model_state_dict"])
