# %% [markdown]
# ## Imports & Setup

# %%
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Compose, Resize, RandomHorizontalFlip
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, precision_score, recall_score
from helpers import *
from architecture.CNN import *

# %% [markdown]
# from torchsampler import ImbalancedDatasetSampler

# %%
torch.manual_seed(809)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# RandomAffine(degrees=(-30,30),translate=(0.1,0.1),shear=(-10,10)),
#                           RandomResizedCrop((size,size),scale=(0.8,1),ratio=(0.9,1.1)),

# %% [markdown]
# ## Prepare Dataset

# %%
def create_subsets(root, transformation):
    dataset = ImageFolder(root, transformation)
    train, test, val = torch.utils.data.random_split(dataset, [0.8, 0.1, 0.1])
    return train, test, val

# %%
def produce_loaders(train, test, val):
    train_loader = torch.utils.data.DataLoader(train, batch_size = batch_size, shuffle = True)
    test_loader = torch.utils.data.DataLoader(test, batch_size = batch_size, shuffle = False)
    valid_loader = torch.utils.data.DataLoader(val, batch_size = batch_size, shuffle = False)
    return train_loader, test_loader, valid_loader

# %%
size = 44
batch_size = 256
transformation = Compose([RandomHorizontalFlip(), 
                          Resize((size, size)), ToTensor()])

# %%
root = 'expanded_dataset/cropped_aug'
train_data, test_data, val_data = create_subsets(root, transformation)
train_loader, test_loader, val_loader = produce_loaders(train_data, test_data, val_data)

# %%
visualize_data(train_data)
# Out:
# [4572, 6343, 983, 7087, 7318, 7226, 1162, 4492, 8043]

# %%
visualize_data(test_data)
# Out:
# [797, 545, 271, 673, 21, 467, 757, 401, 755]

# %% [markdown]
# ## Initialize Model

# %%
def create_adam_optimizer(model, lr = 0.1, betas=(0.9, 0.999), amsgrad=False):
    return optim.Adam(model.parameters(), lr = lr, amsgrad=amsgrad, betas=betas)

# %%
from math import floor
# number of hidden layers and their sizes
hidden = [3, 256, 128, 64]

# kernel size of convolution layers
kernel_size = 3

# window size of maxpooling layer
window = 2

# calculate final size of image
channels = hidden[-1]
changed_img = floor( (size-(kernel_size-1)*(len(hidden)-1)) / window )

# calculate dimension of flattened image
flattened = channels*changed_img*changed_img

# final linear layers and their sizes
hidden_linear = [flattened, 512, 64]

# %%
model = DeepSearch(hidden=hidden, kernel_size=kernel_size,
                   window=window, hidden_linear=hidden_linear).to(device)
#model.load_state_dict(torch.load("./DeepSearch2_15epochs")["model_state_dict"])
print(model)
# Out:
# DeepSearch(
#   (conv_combined): Sequential(
#     (0): DeepSearchConv(
#       (conv): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (1): DeepSearchConv(
#       (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (2): DeepSearchConv(
#       (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (linear_combined): Sequential(
#     (0): DeepSearchLinear(
#       (linear): Linear(in_features=23104, out_features=512, bias=True)
#       (batch_norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (1): DeepSearchLinear(
#       (linear): Linear(in_features=512, out_features=64, bias=True)
#       (batch_norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (output): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# ## Training Model

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
optimizer = create_adam_optimizer(model, lr=0.001)
#optimizer.load_state_dict(torch.load("./DeepSearch2_15epochs")["optimizer_state_dict"])

# %%
# repeat this cell with epochs = 1 for safety, but usually epochs = 3 is a good start

"""
train function params:
device
model - model to train
train_loader - training data loader
val_loader - validation data loader
optimizer - optimizer to use (allows for saving and reloading optimizer state to stop and resume training)
epochs
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)

returns lists of the training loss, training accuracy, validation loss and validation accuracy for plotting curves

"""
tl, ta, vl, va = train(device, model,
                       train_loader, val_loader, 
                       optimizer, epochs = 20)
train_losses+=tl
train_accuracies+=ta
val_losses+=vl
val_accuracies+=va
# Out:
# Epoch 1/20, Batch number: 0, Cumulated accuracy: 0.4921875
# Epoch 1/20, Batch number: 5, Cumulated accuracy: 0.5598958333333334
# Epoch 1/20, Batch number: 10, Cumulated accuracy: 0.59375
# Epoch 1/20, Batch number: 15, Cumulated accuracy: 0.606689453125
# Epoch 1/20, Batch number: 20, Cumulated accuracy: 0.6229538690476191
# Epoch 1/20, Batch number: 25, Cumulated accuracy: 0.6242487980769231
# Epoch 1/20, Batch number: 30, Cumulated accuracy: 0.6314264112903226
# --- Epoch 1/20: Train loss: 0.6638, Train accuracy: 0.6312
# --- Epoch 1/20: Val loss: 0.6364, Val accuracy: 0.6618
# Epoch 2/20, Batch number: 0, Cumulated accuracy: 0.67578125
# Epoch 2/20, Batch number: 5, Cumulated accuracy: 0.6673177083333334
# Epoch 2/20, Batch number: 10, Cumulated accuracy: 0.6740056818181818
# Epoch 2/20, Batch number: 15, Cumulated accuracy: 0.674072265625
# Epoch 2/20, Batch number: 20, Cumulated accuracy: 0.6731770833333334
# Epoch 2/20, Batch number: 25, Cumulated accuracy: 0.6795372596153846
# Epoch 2/20, Batch number: 30, Cumulated accuracy: 0.6833417338709677
# --- Epoch 2/20: Train loss: 0.6017, Train accuracy: 0.6848
# --- Epoch 2/20: Val loss: 0.5533, Val accuracy: 0.7295
# Epoch 3/20, Batch number: 0, Cumulated accuracy: 0.67578125
# Epoch 3/20, Batch number: 5, Cumulated accuracy: 0.7109375
# Epoch 3/20, Batch number: 10, Cumulated accuracy: 0.7080965909090909
# Epoch 3/20, Batch number: 15, Cumulated accuracy: 0.724609375
# Epoch 3/20, Batch number: 20, Cumulated accuracy: 0.7219122023809523
# Epoch 3/20, Batch number: 25, Cumulated accuracy: 0.7208533653846154
# Epoch 3/20, Batch number: 30, Cumulated accuracy: 0.7166078629032258
# --- Epoch 3/20: Train loss: 0.5642, Train accuracy: 0.7167
# --- Epoch 3/20: Val loss: 0.4985, Val accuracy: 0.7816
# Epoch 4/20, Batch number: 0, Cumulated accuracy: 0.75390625
# Epoch 4/20, Batch number: 5, Cumulated accuracy: 0.744140625
# Epoch 4/20, Batch number: 10, Cumulated accuracy: 0.7397017045454546
# Epoch 4/20, Batch number: 15, Cumulated accuracy: 0.7373046875
# Epoch 4/20, Batch number: 20, Cumulated accuracy: 0.7289806547619048
# Epoch 4/20, Batch number: 25, Cumulated accuracy: 0.7301682692307693
# Epoch 4/20, Batch number: 30, Cumulated accuracy: 0.7297127016129032
# --- Epoch 4/20: Train loss: 0.5321, Train accuracy: 0.7306
# --- Epoch 4/20: Val loss: 0.4464, Val accuracy: 0.7913
# Epoch 5/20, Batch number: 0, Cumulated accuracy: 0.78125
# Epoch 5/20, Batch number: 5, Cumulated accuracy: 0.7467447916666666
# Epoch 5/20, Batch number: 10, Cumulated accuracy: 0.7503551136363636
# Epoch 5/20, Batch number: 15, Cumulated accuracy: 0.753173828125
# Epoch 5/20, Batch number: 20, Cumulated accuracy: 0.7486979166666666
# Epoch 5/20, Batch number: 25, Cumulated accuracy: 0.7496995192307693
# Epoch 5/20, Batch number: 30, Cumulated accuracy: 0.748991935483871
# --- Epoch 5/20: Train loss: 0.4995, Train accuracy: 0.7488
# --- Epoch 5/20: Val loss: 0.4318, Val accuracy: 0.8039
# Epoch 6/20, Batch number: 0, Cumulated accuracy: 0.78125
# Epoch 6/20, Batch number: 5, Cumulated accuracy: 0.7701822916666666
# Epoch 6/20, Batch number: 10, Cumulated accuracy: 0.7652698863636364
# Epoch 6/20, Batch number: 15, Cumulated accuracy: 0.768310546875
# Epoch 6/20, Batch number: 20, Cumulated accuracy: 0.7658110119047619
# Epoch 6/20, Batch number: 25, Cumulated accuracy: 0.7708834134615384
# Epoch 6/20, Batch number: 30, Cumulated accuracy: 0.7709173387096774
# --- Epoch 6/20: Train loss: 0.4780, Train accuracy: 0.7723
# --- Epoch 6/20: Val loss: 0.3923, Val accuracy: 0.8222
# Epoch 7/20, Batch number: 0, Cumulated accuracy: 0.8046875
# Epoch 7/20, Batch number: 5, Cumulated accuracy: 0.78515625
# Epoch 7/20, Batch number: 10, Cumulated accuracy: 0.7879971590909091
# Epoch 7/20, Batch number: 15, Cumulated accuracy: 0.787109375
# Epoch 7/20, Batch number: 20, Cumulated accuracy: 0.7844122023809523
# Epoch 7/20, Batch number: 25, Cumulated accuracy: 0.7826021634615384
# Epoch 7/20, Batch number: 30, Cumulated accuracy: 0.7833921370967742
# --- Epoch 7/20: Train loss: 0.4494, Train accuracy: 0.7833
# --- Epoch 7/20: Val loss: 0.4177, Val accuracy: 0.8077
# Epoch 8/20, Batch number: 0, Cumulated accuracy: 0.80859375
# Epoch 8/20, Batch number: 5, Cumulated accuracy: 0.7975260416666666
# Epoch 8/20, Batch number: 10, Cumulated accuracy: 0.8000710227272727
# Epoch 8/20, Batch number: 15, Cumulated accuracy: 0.79931640625
# Epoch 8/20, Batch number: 20, Cumulated accuracy: 0.8017113095238095
# Epoch 8/20, Batch number: 25, Cumulated accuracy: 0.798828125
# Epoch 8/20, Batch number: 30, Cumulated accuracy: 0.7987651209677419
# --- Epoch 8/20: Train loss: 0.4319, Train accuracy: 0.7990
# --- Epoch 8/20: Val loss: 0.4035, Val accuracy: 0.8280
# Epoch 9/20, Batch number: 0, Cumulated accuracy: 0.765625
# Epoch 9/20, Batch number: 5, Cumulated accuracy: 0.7994791666666666
# Epoch 9/20, Batch number: 10, Cumulated accuracy: 0.8089488636363636
# Epoch 9/20, Batch number: 15, Cumulated accuracy: 0.80859375
# Epoch 9/20, Batch number: 20, Cumulated accuracy: 0.8046875
# Epoch 9/20, Batch number: 25, Cumulated accuracy: 0.8039362980769231
# Epoch 9/20, Batch number: 30, Cumulated accuracy: 0.805695564516129
# --- Epoch 9/20: Train loss: 0.4233, Train accuracy: 0.8053
# --- Epoch 9/20: Val loss: 0.3509, Val accuracy: 0.8657
# Epoch 10/20, Batch number: 0, Cumulated accuracy: 0.8046875
# Epoch 10/20, Batch number: 5, Cumulated accuracy: 0.8196614583333334
# Epoch 10/20, Batch number: 10, Cumulated accuracy: 0.8306107954545454
# Epoch 10/20, Batch number: 15, Cumulated accuracy: 0.82568359375
# Epoch 10/20, Batch number: 20, Cumulated accuracy: 0.8271949404761905
# Epoch 10/20, Batch number: 25, Cumulated accuracy: 0.8231670673076923
# Epoch 10/20, Batch number: 30, Cumulated accuracy: 0.8235887096774194
# --- Epoch 10/20: Train loss: 0.3917, Train accuracy: 0.8221
# --- Epoch 10/20: Val loss: 0.3377, Val accuracy: 0.8551
# Epoch 11/20, Batch number: 0, Cumulated accuracy: 0.83984375
# Epoch 11/20, Batch number: 5, Cumulated accuracy: 0.8268229166666666
# Epoch 11/20, Batch number: 10, Cumulated accuracy: 0.82421875
# Epoch 11/20, Batch number: 15, Cumulated accuracy: 0.8271484375
# Epoch 11/20, Batch number: 20, Cumulated accuracy: 0.8214285714285714
# Epoch 11/20, Batch number: 25, Cumulated accuracy: 0.8216646634615384
# Epoch 11/20, Batch number: 30, Cumulated accuracy: 0.8233366935483871
# --- Epoch 11/20: Train loss: 0.3858, Train accuracy: 0.8243
# --- Epoch 11/20: Val loss: 0.3264, Val accuracy: 0.8850
# Epoch 12/20, Batch number: 0, Cumulated accuracy: 0.8203125
# Epoch 12/20, Batch number: 5, Cumulated accuracy: 0.8404947916666666
# Epoch 12/20, Batch number: 10, Cumulated accuracy: 0.8380681818181818
# Epoch 12/20, Batch number: 15, Cumulated accuracy: 0.839599609375
# Epoch 12/20, Batch number: 20, Cumulated accuracy: 0.8342633928571429
# Epoch 12/20, Batch number: 25, Cumulated accuracy: 0.8329326923076923
# Epoch 12/20, Batch number: 30, Cumulated accuracy: 0.8353074596774194
# --- Epoch 12/20: Train loss: 0.3688, Train accuracy: 0.8349
# --- Epoch 12/20: Val loss: 0.3065, Val accuracy: 0.8676
# Epoch 13/20, Batch number: 0, Cumulated accuracy: 0.8203125
# Epoch 13/20, Batch number: 5, Cumulated accuracy: 0.8229166666666666
# Epoch 13/20, Batch number: 10, Cumulated accuracy: 0.8277698863636364
# Epoch 13/20, Batch number: 15, Cumulated accuracy: 0.8330078125
# Epoch 13/20, Batch number: 20, Cumulated accuracy: 0.8381696428571429
# Epoch 13/20, Batch number: 25, Cumulated accuracy: 0.8393930288461539
# Epoch 13/20, Batch number: 30, Cumulated accuracy: 0.8364415322580645
# --- Epoch 13/20: Train loss: 0.3665, Train accuracy: 0.8355
# --- Epoch 13/20: Val loss: 0.3308, Val accuracy: 0.8531
# Epoch 14/20, Batch number: 0, Cumulated accuracy: 0.7890625
# Epoch 14/20, Batch number: 5, Cumulated accuracy: 0.8450520833333334
# Epoch 14/20, Batch number: 10, Cumulated accuracy: 0.8508522727272727
# Epoch 14/20, Batch number: 15, Cumulated accuracy: 0.8505859375
# Epoch 14/20, Batch number: 20, Cumulated accuracy: 0.8510044642857143
# Epoch 14/20, Batch number: 25, Cumulated accuracy: 0.8454026442307693
# Epoch 14/20, Batch number: 30, Cumulated accuracy: 0.8463961693548387
# --- Epoch 14/20: Train loss: 0.3445, Train accuracy: 0.8466
# --- Epoch 14/20: Val loss: 0.3175, Val accuracy: 0.8570
# Epoch 15/20, Batch number: 0, Cumulated accuracy: 0.83984375
# Epoch 15/20, Batch number: 5, Cumulated accuracy: 0.8665364583333334
# Epoch 15/20, Batch number: 10, Cumulated accuracy: 0.8575994318181818
# Epoch 15/20, Batch number: 15, Cumulated accuracy: 0.861328125
# Epoch 15/20, Batch number: 20, Cumulated accuracy: 0.8617931547619048
# Epoch 15/20, Batch number: 25, Cumulated accuracy: 0.8595252403846154
# Epoch 15/20, Batch number: 30, Cumulated accuracy: 0.8581149193548387
# --- Epoch 15/20: Train loss: 0.3289, Train accuracy: 0.8589
# --- Epoch 15/20: Val loss: 0.2880, Val accuracy: 0.8792
# Epoch 16/20, Batch number: 0, Cumulated accuracy: 0.85546875
# Epoch 16/20, Batch number: 5, Cumulated accuracy: 0.857421875
# Epoch 16/20, Batch number: 10, Cumulated accuracy: 0.8512073863636364
# Epoch 16/20, Batch number: 15, Cumulated accuracy: 0.853759765625
# Epoch 16/20, Batch number: 20, Cumulated accuracy: 0.8560267857142857
# Epoch 16/20, Batch number: 25, Cumulated accuracy: 0.8529146634615384
# Epoch 16/20, Batch number: 30, Cumulated accuracy: 0.8560987903225806
# --- Epoch 16/20: Train loss: 0.3272, Train accuracy: 0.8550
# --- Epoch 16/20: Val loss: 0.2740, Val accuracy: 0.8783
# Epoch 17/20, Batch number: 0, Cumulated accuracy: 0.83984375
# Epoch 17/20, Batch number: 5, Cumulated accuracy: 0.8600260416666666
# Epoch 17/20, Batch number: 10, Cumulated accuracy: 0.8604403409090909
# Epoch 17/20, Batch number: 15, Cumulated accuracy: 0.853271484375
# Epoch 17/20, Batch number: 20, Cumulated accuracy: 0.8582589285714286
# Epoch 17/20, Batch number: 25, Cumulated accuracy: 0.8595252403846154
# Epoch 17/20, Batch number: 30, Cumulated accuracy: 0.8598790322580645
# --- Epoch 17/20: Train loss: 0.3188, Train accuracy: 0.8594
# --- Epoch 17/20: Val loss: 0.2677, Val accuracy: 0.8899
# Epoch 18/20, Batch number: 0, Cumulated accuracy: 0.83984375
# Epoch 18/20, Batch number: 5, Cumulated accuracy: 0.86328125
# Epoch 18/20, Batch number: 10, Cumulated accuracy: 0.8579545454545454
# Epoch 18/20, Batch number: 15, Cumulated accuracy: 0.861083984375
# Epoch 18/20, Batch number: 20, Cumulated accuracy: 0.8621651785714286
# Epoch 18/20, Batch number: 25, Cumulated accuracy: 0.8647836538461539
# Epoch 18/20, Batch number: 30, Cumulated accuracy: 0.8639112903225806
# --- Epoch 18/20: Train loss: 0.3107, Train accuracy: 0.8645
# --- Epoch 18/20: Val loss: 0.2858, Val accuracy: 0.8831
# Epoch 19/20, Batch number: 0, Cumulated accuracy: 0.890625
# Epoch 19/20, Batch number: 5, Cumulated accuracy: 0.8736979166666666
# Epoch 19/20, Batch number: 10, Cumulated accuracy: 0.8703835227272727
# Epoch 19/20, Batch number: 15, Cumulated accuracy: 0.865234375
# Epoch 19/20, Batch number: 20, Cumulated accuracy: 0.8677455357142857
# Epoch 19/20, Batch number: 25, Cumulated accuracy: 0.8668870192307693
# Epoch 19/20, Batch number: 30, Cumulated accuracy: 0.8703377016129032
# --- Epoch 19/20: Train loss: 0.2958, Train accuracy: 0.8711
# --- Epoch 19/20: Val loss: 0.2562, Val accuracy: 0.9101
# Epoch 20/20, Batch number: 0, Cumulated accuracy: 0.8828125
# Epoch 20/20, Batch number: 5, Cumulated accuracy: 0.8736979166666666
# Epoch 20/20, Batch number: 10, Cumulated accuracy: 0.8647017045454546
# Epoch 20/20, Batch number: 15, Cumulated accuracy: 0.866943359375
# Epoch 20/20, Batch number: 20, Cumulated accuracy: 0.8722098214285714
# Epoch 20/20, Batch number: 25, Cumulated accuracy: 0.8754507211538461
# Epoch 20/20, Batch number: 30, Cumulated accuracy: 0.8757560483870968
# --- Epoch 20/20: Train loss: 0.2906, Train accuracy: 0.8762
# --- Epoch 20/20: Val loss: 0.2655, Val accuracy: 0.8957

# %% [markdown]
# ## Testing Model & Performance Curves

# %%
"""
test function params:
device
model - model to train
data_loader - chosen (testing) data loader
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)
get_predictions - if True, returns the list of true labels, the list of predictions made by the model, 
                  and values of the test loss and test accuracy (default is False)

by default, returns values of the test loss and test accuracy

"""
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
# Out:
# Test loss: 0.1596, Test accuracy: 0.9188

# %%
show_metrics(true_labels, model_preds)
# Out:
# Precision: 0.9596774193548387
# Recall: 0.8814814814814815
# F1 score: 0.918918918918919

# %%
model.load_state_dict(torch.load("./DeepSearch_checkpoint")["model_state_dict"])
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
show_metrics(true_labels, model_preds)
# Out:
# Test loss: 0.1722, Test accuracy: 0.9179
# Precision: 0.952286282306163
# Recall: 0.8870370370370371
# F1 score: 0.9185043144774687

# %%
plt.plot(train_accuracies, "r--", label='Train accuracy')
plt.plot(val_accuracies, "b--", label='Validation accuracy')
plt.title("Final Test Accuracy: {}".format(test_accuracy))
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(train_losses, "r--", label='Training loss')
plt.plot(val_losses, "b--", label='Validation loss')
plt.title("Final Test Loss: {}".format(test_loss))
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Viewing Model Predictions

# %%
test_loader2 = produce_loader(test_data, 1)

# %%
correct_list, wrong_list, true_labels2, model_preds2 = get_pictures_test(device, model, test_loader2)

# %%
show_metrics(true_labels2, model_preds2)
# Out:
# Precision: 0.959758551307847
# Recall: 0.8833333333333333
# F1 score: 0.9199614271938282

# %%
visualize_data(correct_list, (12,12), 5)
# Out:
# [318, 810, 113, 299, 693, 536, 342, 376, 932, 933, 802, 862, 78, 677, 917, 600, 308, 98, 324, 676, 412, 229, 755, 322, 46]

# %%
visualize_data(wrong_list, (12,12), 5)
# Out:
# [71, 82, 39, 48, 43, 41, 26, 80, 47, 62, 64, 61, 18, 34, 68, 53, 44, 67, 39, 25, 50, 1, 53, 25, 8]

# %% [markdown]
# ## Saving Model

# %%
torch.save({'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict()}, 
            './DeepSearch_20epochs')

# %% [markdown]
# model_test = DeepLearn(kernels=kernels, hidden=hidden, kernel_size=kernel_size, window=window,
#                    hidden_linear=hidden_linear, labels=labels).to(device)
# model_test.load_state_dict(torch.load("./latest_16epochs")["model_state_dict"])
