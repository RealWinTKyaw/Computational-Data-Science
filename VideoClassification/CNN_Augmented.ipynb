# %% [markdown]
# ## Imports & Setup

# %%
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Compose, Resize, RandomHorizontalFlip
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, precision_score, recall_score
from helpers import *
from architecture.CNN import *

# %% [markdown]
# from torchsampler import ImbalancedDatasetSampler

# %%
torch.manual_seed(809)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# RandomAffine(degrees=(-30,30),translate=(0.1,0.1),shear=(-10,10)),
#                           RandomResizedCrop((size,size),scale=(0.8,1),ratio=(0.9,1.1)),

# %% [markdown]
# ## Prepare Dataset

# %%
def create_subsets(root, transformation):
    dataset = ImageFolder(root, transformation)
    train, test, val = torch.utils.data.random_split(dataset, [0.8, 0.1, 0.1])
    return train, test, val

# %%
def produce_loaders(train, test, val):
    train_loader = torch.utils.data.DataLoader(train, batch_size = batch_size, shuffle = True)
    test_loader = torch.utils.data.DataLoader(test, batch_size = batch_size, shuffle = False)
    valid_loader = torch.utils.data.DataLoader(val, batch_size = batch_size, shuffle = False)
    return train_loader, test_loader, valid_loader

# %%
size = 44
batch_size = 256
transformation = Compose([RandomHorizontalFlip(), 
                          Resize((size, size)), ToTensor()])

# %%
root = 'reduced_dataset/cropped_aug'
train_data, test_data, val_data = create_subsets(root, transformation)
train_loader, test_loader, val_loader = produce_loaders(train_data, test_data, val_data)

# %%
visualize_data(train_data)
# Out:
# [2535, 1551, 1, 3193, 440, 3995, 1668, 2521, 2295]

# %%
visualize_data(test_data)
# Out:
# [96, 331, 13, 43, 14, 366, 67, 71, 20]

# %% [markdown]
# ## Initialize Model

# %%
def create_adam_optimizer(model, lr = 0.1, betas=(0.9, 0.999), amsgrad=False):
    return optim.Adam(model.parameters(), lr = lr, amsgrad=amsgrad, betas=betas)

# %%
from math import floor
# number of hidden layers and their sizes
hidden = [3, 256, 128, 64]

# kernel size of convolution layers
kernel_size = 3

# window size of maxpooling layer
window = 2

# calculate final size of image
channels = hidden[-1]
changed_img = floor( (size-(kernel_size-1)*(len(hidden)-1)) / window )

# calculate dimension of flattened image
flattened = channels*changed_img*changed_img

# final linear layers and their sizes
hidden_linear = [flattened, 512, 64]

# %%
model = DeepSearch(hidden=hidden, kernel_size=kernel_size,
                   window=window, hidden_linear=hidden_linear).to(device)
#model.load_state_dict(torch.load("./DeepSearch2_15epochs")["model_state_dict"])
print(model)
# Out:
# DeepSearch(
#   (conv_combined): Sequential(
#     (0): DeepSearchConv(
#       (conv): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (1): DeepSearchConv(
#       (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (2): DeepSearchConv(
#       (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (linear_combined): Sequential(
#     (0): DeepSearchLinear(
#       (linear): Linear(in_features=23104, out_features=512, bias=True)
#       (batch_norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (1): DeepSearchLinear(
#       (linear): Linear(in_features=512, out_features=64, bias=True)
#       (batch_norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (output): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# ## Training Model

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
optimizer = create_adam_optimizer(model, lr=0.001)
#optimizer.load_state_dict(torch.load("./DeepSearch2_15epochs")["optimizer_state_dict"])

# %%
# repeat this cell with epochs = 1 for safety, but usually epochs = 3 is a good start

"""
train function params:
device
model - model to train
train_loader - training data loader
val_loader - validation data loader
optimizer - optimizer to use (allows for saving and reloading optimizer state to stop and resume training)
epochs
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)

returns lists of the training loss, training accuracy, validation loss and validation accuracy for plotting curves

"""
tl, ta, vl, va = train(device, model,
                       train_loader, val_loader, 
                       optimizer, epochs = 20)
train_losses+=tl
train_accuracies+=ta
val_losses+=vl
val_accuracies+=va
# Out:
# Epoch 1/20, Batch number: 0, Cumulated accuracy: 0.44921875
# Epoch 1/20, Batch number: 5, Cumulated accuracy: 0.623046875
# Epoch 1/20, Batch number: 10, Cumulated accuracy: 0.6548295454545454
# Epoch 1/20, Batch number: 15, Cumulated accuracy: 0.6691176470588235
# --- Epoch 1/20: Train loss: 0.6287, Train accuracy: 0.6691
# --- Epoch 1/20: Val loss: 0.6096, Val accuracy: 0.6843
# Epoch 2/20, Batch number: 0, Cumulated accuracy: 0.65234375
# Epoch 2/20, Batch number: 5, Cumulated accuracy: 0.7063802083333334
# Epoch 2/20, Batch number: 10, Cumulated accuracy: 0.7159090909090909
# Epoch 2/20, Batch number: 15, Cumulated accuracy: 0.725
# --- Epoch 2/20: Train loss: 0.5659, Train accuracy: 0.7250
# --- Epoch 2/20: Val loss: 0.6374, Val accuracy: 0.6216
# Epoch 3/20, Batch number: 0, Cumulated accuracy: 0.77734375
# Epoch 3/20, Batch number: 5, Cumulated accuracy: 0.7428385416666666
# Epoch 3/20, Batch number: 10, Cumulated accuracy: 0.7478693181818182
# Epoch 3/20, Batch number: 15, Cumulated accuracy: 0.7470588235294118
# --- Epoch 3/20: Train loss: 0.5325, Train accuracy: 0.7471
# --- Epoch 3/20: Val loss: 0.5430, Val accuracy: 0.7176
# Epoch 4/20, Batch number: 0, Cumulated accuracy: 0.79296875
# Epoch 4/20, Batch number: 5, Cumulated accuracy: 0.7734375
# Epoch 4/20, Batch number: 10, Cumulated accuracy: 0.7627840909090909
# Epoch 4/20, Batch number: 15, Cumulated accuracy: 0.763235294117647
# --- Epoch 4/20: Train loss: 0.4889, Train accuracy: 0.7632
# --- Epoch 4/20: Val loss: 0.4471, Val accuracy: 0.7922
# Epoch 5/20, Batch number: 0, Cumulated accuracy: 0.75390625
# Epoch 5/20, Batch number: 5, Cumulated accuracy: 0.7610677083333334
# Epoch 5/20, Batch number: 10, Cumulated accuracy: 0.7581676136363636
# Epoch 5/20, Batch number: 15, Cumulated accuracy: 0.7676470588235295
# --- Epoch 5/20: Train loss: 0.4696, Train accuracy: 0.7676
# --- Epoch 5/20: Val loss: 0.4359, Val accuracy: 0.7843
# Epoch 6/20, Batch number: 0, Cumulated accuracy: 0.75390625
# Epoch 6/20, Batch number: 5, Cumulated accuracy: 0.7799479166666666
# Epoch 6/20, Batch number: 10, Cumulated accuracy: 0.7840909090909091
# Epoch 6/20, Batch number: 15, Cumulated accuracy: 0.7825980392156863
# --- Epoch 6/20: Train loss: 0.4416, Train accuracy: 0.7826
# --- Epoch 6/20: Val loss: 0.3904, Val accuracy: 0.8176
# Epoch 7/20, Batch number: 0, Cumulated accuracy: 0.82421875
# Epoch 7/20, Batch number: 5, Cumulated accuracy: 0.7799479166666666
# Epoch 7/20, Batch number: 10, Cumulated accuracy: 0.7872869318181818
# Epoch 7/20, Batch number: 15, Cumulated accuracy: 0.7948529411764705
# --- Epoch 7/20: Train loss: 0.4273, Train accuracy: 0.7949
# --- Epoch 7/20: Val loss: 0.3880, Val accuracy: 0.8196
# Epoch 8/20, Batch number: 0, Cumulated accuracy: 0.79296875
# Epoch 8/20, Batch number: 5, Cumulated accuracy: 0.8177083333333334
# Epoch 8/20, Batch number: 10, Cumulated accuracy: 0.8064630681818182
# Epoch 8/20, Batch number: 15, Cumulated accuracy: 0.8053921568627451
# --- Epoch 8/20: Train loss: 0.4192, Train accuracy: 0.8054
# --- Epoch 8/20: Val loss: 0.3790, Val accuracy: 0.8157
# Epoch 9/20, Batch number: 0, Cumulated accuracy: 0.828125
# Epoch 9/20, Batch number: 5, Cumulated accuracy: 0.82421875
# Epoch 9/20, Batch number: 10, Cumulated accuracy: 0.8206676136363636
# Epoch 9/20, Batch number: 15, Cumulated accuracy: 0.8127450980392157
# --- Epoch 9/20: Train loss: 0.4086, Train accuracy: 0.8127
# --- Epoch 9/20: Val loss: 0.3411, Val accuracy: 0.8471
# Epoch 10/20, Batch number: 0, Cumulated accuracy: 0.82421875
# Epoch 10/20, Batch number: 5, Cumulated accuracy: 0.822265625
# Epoch 10/20, Batch number: 10, Cumulated accuracy: 0.8249289772727273
# Epoch 10/20, Batch number: 15, Cumulated accuracy: 0.8208333333333333
# --- Epoch 10/20: Train loss: 0.3900, Train accuracy: 0.8208
# --- Epoch 10/20: Val loss: 0.3391, Val accuracy: 0.8392
# Epoch 11/20, Batch number: 0, Cumulated accuracy: 0.79296875
# Epoch 11/20, Batch number: 5, Cumulated accuracy: 0.8059895833333334
# Epoch 11/20, Batch number: 10, Cumulated accuracy: 0.8206676136363636
# Epoch 11/20, Batch number: 15, Cumulated accuracy: 0.828921568627451
# --- Epoch 11/20: Train loss: 0.3754, Train accuracy: 0.8289
# --- Epoch 11/20: Val loss: 0.3291, Val accuracy: 0.8529
# Epoch 12/20, Batch number: 0, Cumulated accuracy: 0.81640625
# Epoch 12/20, Batch number: 5, Cumulated accuracy: 0.818359375
# Epoch 12/20, Batch number: 10, Cumulated accuracy: 0.8288352272727273
# Epoch 12/20, Batch number: 15, Cumulated accuracy: 0.8340686274509804
# --- Epoch 12/20: Train loss: 0.3656, Train accuracy: 0.8341
# --- Epoch 12/20: Val loss: 0.3891, Val accuracy: 0.8275
# Epoch 13/20, Batch number: 0, Cumulated accuracy: 0.87109375
# Epoch 13/20, Batch number: 5, Cumulated accuracy: 0.84765625
# Epoch 13/20, Batch number: 10, Cumulated accuracy: 0.8441051136363636
# Epoch 13/20, Batch number: 15, Cumulated accuracy: 0.8384803921568628
# --- Epoch 13/20: Train loss: 0.3494, Train accuracy: 0.8385
# --- Epoch 13/20: Val loss: 0.3028, Val accuracy: 0.8608
# Epoch 14/20, Batch number: 0, Cumulated accuracy: 0.84765625
# Epoch 14/20, Batch number: 5, Cumulated accuracy: 0.8463541666666666
# Epoch 14/20, Batch number: 10, Cumulated accuracy: 0.8419744318181818
# Epoch 14/20, Batch number: 15, Cumulated accuracy: 0.8443627450980392
# --- Epoch 14/20: Train loss: 0.3358, Train accuracy: 0.8444
# --- Epoch 14/20: Val loss: 0.3086, Val accuracy: 0.8569
# Epoch 15/20, Batch number: 0, Cumulated accuracy: 0.8359375
# Epoch 15/20, Batch number: 5, Cumulated accuracy: 0.8411458333333334
# Epoch 15/20, Batch number: 10, Cumulated accuracy: 0.8416193181818182
# Epoch 15/20, Batch number: 15, Cumulated accuracy: 0.8419117647058824
# --- Epoch 15/20: Train loss: 0.3417, Train accuracy: 0.8419
# --- Epoch 15/20: Val loss: 0.3263, Val accuracy: 0.8471
# Epoch 16/20, Batch number: 0, Cumulated accuracy: 0.8515625
# Epoch 16/20, Batch number: 5, Cumulated accuracy: 0.8463541666666666
# Epoch 16/20, Batch number: 10, Cumulated accuracy: 0.8462357954545454
# Epoch 16/20, Batch number: 15, Cumulated accuracy: 0.8487745098039216
# --- Epoch 16/20: Train loss: 0.3350, Train accuracy: 0.8488
# --- Epoch 16/20: Val loss: 0.2634, Val accuracy: 0.8843
# Epoch 17/20, Batch number: 0, Cumulated accuracy: 0.87890625
# Epoch 17/20, Batch number: 5, Cumulated accuracy: 0.8372395833333334
# Epoch 17/20, Batch number: 10, Cumulated accuracy: 0.8462357954545454
# Epoch 17/20, Batch number: 15, Cumulated accuracy: 0.8477941176470588
# --- Epoch 17/20: Train loss: 0.3289, Train accuracy: 0.8478
# --- Epoch 17/20: Val loss: 0.3088, Val accuracy: 0.8510
# Epoch 18/20, Batch number: 0, Cumulated accuracy: 0.87890625
# Epoch 18/20, Batch number: 5, Cumulated accuracy: 0.8678385416666666
# Epoch 18/20, Batch number: 10, Cumulated accuracy: 0.8572443181818182
# Epoch 18/20, Batch number: 15, Cumulated accuracy: 0.8551470588235294
# --- Epoch 18/20: Train loss: 0.3254, Train accuracy: 0.8551
# --- Epoch 18/20: Val loss: 0.2725, Val accuracy: 0.8804
# Epoch 19/20, Batch number: 0, Cumulated accuracy: 0.890625
# Epoch 19/20, Batch number: 5, Cumulated accuracy: 0.8639322916666666
# Epoch 19/20, Batch number: 10, Cumulated accuracy: 0.8654119318181818
# Epoch 19/20, Batch number: 15, Cumulated accuracy: 0.8676470588235294
# --- Epoch 19/20: Train loss: 0.2993, Train accuracy: 0.8676
# --- Epoch 19/20: Val loss: 0.2781, Val accuracy: 0.8765
# Stopped early due to increasing validation loss.

# %% [markdown]
# ## Testing Model & Performance Curves

# %%
"""
test function params:
device
model - model to train
data_loader - chosen (testing) data loader
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)
get_predictions - if True, returns the list of true labels, the list of predictions made by the model, 
                  and values of the test loss and test accuracy (default is False)

by default, returns values of the test loss and test accuracy

"""
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
# Out:
# Test loss: 0.2666, Test accuracy: 0.8784

# %%
show_metrics(true_labels, model_preds)
# Out:
# Precision: 0.8433734939759037
# Recall: 0.9012875536480687
# F1 score: 0.8713692946058091

# %%
plt.plot(train_accuracies, "r--", label='Train accuracy')
plt.plot(val_accuracies, "b--", label='Validation accuracy')
plt.title("Final Test Accuracy: {}".format(test_accuracy))
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(train_losses, "r--", label='Training loss')
plt.plot(val_losses, "b--", label='Validation loss')
plt.title("Final Test Loss: {}".format(test_loss))
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Viewing Model Predictions

# %%
test_loader2 = produce_loader(test_data, 1)

# %%
correct_list, wrong_list, true_labels2, model_preds2 = get_pictures_test(device, model, test_loader2)

# %%
show_metrics(true_labels2, model_preds2)
# Out:
# Precision: 0.8565573770491803
# Recall: 0.8969957081545065
# F1 score: 0.8763102725366876

# %%
visualize_data(correct_list, (12,12), 5)
# Out:
# [266, 158, 273, 124, 107, 266, 140, 174, 307, 275, 170, 413, 219, 122, 179, 245, 176, 108, 158, 273, 269, 150, 354, 195, 443]

# %%
visualize_data(wrong_list, (12,12), 5)
# Out:
# [13, 3, 57, 27, 30, 17, 37, 53, 12, 3, 47, 48, 52, 23, 47, 42, 24, 29, 11, 38, 24, 25, 38, 0, 42]

# %% [markdown]
# ## Saving Model

# %%
torch.save({'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict()}, 
            './DeepSearch_19epochs')

# %% [markdown]
# model_test = DeepLearn(kernels=kernels, hidden=hidden, kernel_size=kernel_size, window=window,
#                    hidden_linear=hidden_linear, labels=labels).to(device)
# model_test.load_state_dict(torch.load("./latest_16epochs")["model_state_dict"])
