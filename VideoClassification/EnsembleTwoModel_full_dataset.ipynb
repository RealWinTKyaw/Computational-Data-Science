# %% [markdown]
# ## Imports & Setup

# %%
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Compose, Resize, RandomHorizontalFlip
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, precision_score, recall_score
from helpers import *
from architecture.CNN import *

# %%
from torchsampler import ImbalancedDatasetSampler

# %%
torch.manual_seed(809)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# RandomAffine(degrees=(-30,30),translate=(0.1,0.1),shear=(-10,10)),
#                           RandomResizedCrop((size,size),scale=(0.8,1),ratio=(0.9,1.1)),

# %% [markdown]
# ## Prepare Dataset

# %%
size = 44
batch_size = 256
transformation = Compose([RandomHorizontalFlip(), 
                          Resize((size, size)), ToTensor()])

# %%
root = '../expanded_dataset/augmented_data/'
train_data = create_dataset(root, transformation)
sampler = ImbalancedDatasetSampler(train_data)
train_loader = produce_loader(train_data, batch_size, sampler=sampler)
#reduced_dataset\cropped_augmented

# %%
root = '../expanded_dataset/augmented_data/'
test_data = create_dataset(root, transformation)
test_loader = produce_loader(test_data, batch_size)

# %%
root = '../expanded_dataset/augmented_data/'
val_data = create_dataset(root, transformation)
val_loader = produce_loader(val_data, batch_size)

# %%
visualize_data(train_data)
# Out:
# [1849, 181, 8539, 6634, 6849, 2428, 7709, 8080, 6076]

# %%
visualize_data(test_data)
# Out:
# [5612, 10055, 4893, 1451, 3353, 8546, 83, 4283, 8645]

# %% [markdown]
# ## Initialize Model

# %%
def create_adam_optimizer(model, lr = 0.1, betas=(0.9, 0.999), amsgrad=False):
    return optim.Adam(model.parameters(), lr = lr, amsgrad=amsgrad, betas=betas)

# %%
from math import floor
# number of hidden layers and their sizes
hidden = [3, 256, 128, 64]

# kernel size of convolution layers
kernel_size = 3

# window size of maxpooling layer
window = 3

# calculate final size of image
channels = hidden[-1]
changed_img = floor( (size-(kernel_size-1)*(len(hidden)-1)) / window )

# calculate dimension of flattened image
flattened = channels*changed_img*changed_img

# final linear layers and their sizes
hidden_linear = [flattened, 512, 64]

# %%
model = DeepSearch(hidden=hidden, kernel_size=kernel_size,
                   window=window, hidden_linear=hidden_linear).to(device)
#model.load_state_dict(torch.load("./DeepSearch2_15epochs")["model_state_dict"])
print(model)
# Out:
# DeepSearch(
#   (conv_combined): Sequential(
#     (0): DeepSearchConv(
#       (conv): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (1): DeepSearchConv(
#       (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (2): DeepSearchConv(
#       (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=3, stride=3, padding=0)
#   (linear_combined): Sequential(
#     (0): DeepSearchLinear(
#       (linear): Linear(in_features=9216, out_features=512, bias=True)
#       (batch_norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (1): DeepSearchLinear(
#       (linear): Linear(in_features=512, out_features=64, bias=True)
#       (batch_norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (output): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# ## Training Model

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
optimizer = create_adam_optimizer(model, lr=0.01)
#optimizer.load_state_dict(torch.load("./DeepSearch2_15epochs")["optimizer_state_dict"])

# %%
"""
train function params:
device
model - model to train
train_loader - training data loader
val_loader - validation data loader
optimizer - optimizer to use (allows for saving and reloading optimizer state to stop and resume training)
epochs
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)

returns lists of the training loss, training accuracy, validation loss and validation accuracy for plotting curves

"""
tl, ta, vl, va = train(device, model,
                       train_loader, val_loader, 
                       optimizer, epochs = 20, patience=5)
train_losses+=tl
train_accuracies+=ta
val_losses+=vl
val_accuracies+=va
# Out:
# Epoch 1/20, Batch number: 0, Cumulated accuracy: 0.484375
# Epoch 1/20, Batch number: 5, Cumulated accuracy: 0.5904947916666666
# Epoch 1/20, Batch number: 10, Cumulated accuracy: 0.6079545454545454
# Epoch 1/20, Batch number: 15, Cumulated accuracy: 0.6171875
# Epoch 1/20, Batch number: 20, Cumulated accuracy: 0.6274181547619048
# Epoch 1/20, Batch number: 25, Cumulated accuracy: 0.6383713942307693
# Epoch 1/20, Batch number: 30, Cumulated accuracy: 0.6481854838709677
# Epoch 1/20, Batch number: 35, Cumulated accuracy: 0.6534288194444444
# Epoch 1/20, Batch number: 40, Cumulated accuracy: 0.657584541062802
# --- Epoch 1/20: Train loss: 0.6409, Train accuracy: 0.6576
# --- Epoch 1/20: Val loss: 0.5784, Val accuracy: 0.7060
# Epoch 2/20, Batch number: 0, Cumulated accuracy: 0.69140625
# Epoch 2/20, Batch number: 5, Cumulated accuracy: 0.681640625
# Epoch 2/20, Batch number: 10, Cumulated accuracy: 0.6786221590909091
# Epoch 2/20, Batch number: 15, Cumulated accuracy: 0.690185546875
# Epoch 2/20, Batch number: 20, Cumulated accuracy: 0.7018229166666666
# Epoch 2/20, Batch number: 25, Cumulated accuracy: 0.7043269230769231
# Epoch 2/20, Batch number: 30, Cumulated accuracy: 0.7075352822580645
# Epoch 2/20, Batch number: 35, Cumulated accuracy: 0.7056206597222222
# Epoch 2/20, Batch number: 40, Cumulated accuracy: 0.703768115942029
# --- Epoch 2/20: Train loss: 0.5840, Train accuracy: 0.7038
# --- Epoch 2/20: Val loss: 0.6019, Val accuracy: 0.6720
# Epoch 3/20, Batch number: 0, Cumulated accuracy: 0.6640625
# Epoch 3/20, Batch number: 5, Cumulated accuracy: 0.7057291666666666
# Epoch 3/20, Batch number: 10, Cumulated accuracy: 0.7212357954545454
# Epoch 3/20, Batch number: 15, Cumulated accuracy: 0.7265625
# Epoch 3/20, Batch number: 20, Cumulated accuracy: 0.7260044642857143
# Epoch 3/20, Batch number: 25, Cumulated accuracy: 0.7271634615384616
# Epoch 3/20, Batch number: 30, Cumulated accuracy: 0.7268145161290323
# Epoch 3/20, Batch number: 35, Cumulated accuracy: 0.7239583333333334
# Epoch 3/20, Batch number: 40, Cumulated accuracy: 0.7248309178743961
# --- Epoch 3/20: Train loss: 0.5506, Train accuracy: 0.7248
# --- Epoch 3/20: Val loss: 0.5547, Val accuracy: 0.7180
# Epoch 4/20, Batch number: 0, Cumulated accuracy: 0.75
# Epoch 4/20, Batch number: 5, Cumulated accuracy: 0.7415364583333334
# Epoch 4/20, Batch number: 10, Cumulated accuracy: 0.7318892045454546
# Epoch 4/20, Batch number: 15, Cumulated accuracy: 0.7265625
# Epoch 4/20, Batch number: 20, Cumulated accuracy: 0.734375
# Epoch 4/20, Batch number: 25, Cumulated accuracy: 0.7360276442307693
# Epoch 4/20, Batch number: 30, Cumulated accuracy: 0.734375
# Epoch 4/20, Batch number: 35, Cumulated accuracy: 0.7330729166666666
# Epoch 4/20, Batch number: 40, Cumulated accuracy: 0.7336231884057971
# --- Epoch 4/20: Train loss: 0.5301, Train accuracy: 0.7336
# --- Epoch 4/20: Val loss: 0.4989, Val accuracy: 0.7443
# Epoch 5/20, Batch number: 0, Cumulated accuracy: 0.7265625
# Epoch 5/20, Batch number: 5, Cumulated accuracy: 0.7291666666666666
# Epoch 5/20, Batch number: 10, Cumulated accuracy: 0.7279829545454546
# Epoch 5/20, Batch number: 15, Cumulated accuracy: 0.7294921875
# Epoch 5/20, Batch number: 20, Cumulated accuracy: 0.7302827380952381
# Epoch 5/20, Batch number: 25, Cumulated accuracy: 0.7298677884615384
# Epoch 5/20, Batch number: 30, Cumulated accuracy: 0.731476814516129
# Epoch 5/20, Batch number: 35, Cumulated accuracy: 0.7320963541666666
# Epoch 5/20, Batch number: 40, Cumulated accuracy: 0.7326570048309179
# --- Epoch 5/20: Train loss: 0.5212, Train accuracy: 0.7327
# --- Epoch 5/20: Val loss: 0.4288, Val accuracy: 0.7930
# Epoch 6/20, Batch number: 0, Cumulated accuracy: 0.72265625
# Epoch 6/20, Batch number: 5, Cumulated accuracy: 0.7434895833333334
# Epoch 6/20, Batch number: 10, Cumulated accuracy: 0.7357954545454546
# Epoch 6/20, Batch number: 15, Cumulated accuracy: 0.73779296875
# Epoch 6/20, Batch number: 20, Cumulated accuracy: 0.7434895833333334
# Epoch 6/20, Batch number: 25, Cumulated accuracy: 0.7472956730769231
# Epoch 6/20, Batch number: 30, Cumulated accuracy: 0.7492439516129032
# Epoch 6/20, Batch number: 35, Cumulated accuracy: 0.7491319444444444
# Epoch 6/20, Batch number: 40, Cumulated accuracy: 0.7497584541062802
# --- Epoch 6/20: Train loss: 0.4908, Train accuracy: 0.7498
# --- Epoch 6/20: Val loss: 0.4833, Val accuracy: 0.7767
# Epoch 7/20, Batch number: 0, Cumulated accuracy: 0.7734375
# Epoch 7/20, Batch number: 5, Cumulated accuracy: 0.767578125
# Epoch 7/20, Batch number: 10, Cumulated accuracy: 0.7595880681818182
# Epoch 7/20, Batch number: 15, Cumulated accuracy: 0.758056640625
# Epoch 7/20, Batch number: 20, Cumulated accuracy: 0.7563244047619048
# Epoch 7/20, Batch number: 25, Cumulated accuracy: 0.7611177884615384
# Epoch 7/20, Batch number: 30, Cumulated accuracy: 0.7632308467741935
# Epoch 7/20, Batch number: 35, Cumulated accuracy: 0.7664930555555556
# Epoch 7/20, Batch number: 40, Cumulated accuracy: 0.767536231884058
# --- Epoch 7/20: Train loss: 0.4658, Train accuracy: 0.7675
# --- Epoch 7/20: Val loss: 0.4838, Val accuracy: 0.7478
# Epoch 8/20, Batch number: 0, Cumulated accuracy: 0.75
# Epoch 8/20, Batch number: 5, Cumulated accuracy: 0.7819010416666666
# Epoch 8/20, Batch number: 10, Cumulated accuracy: 0.7762784090909091
# Epoch 8/20, Batch number: 15, Cumulated accuracy: 0.7734375
# Epoch 8/20, Batch number: 20, Cumulated accuracy: 0.7793898809523809
# Epoch 8/20, Batch number: 25, Cumulated accuracy: 0.7785456730769231
# Epoch 8/20, Batch number: 30, Cumulated accuracy: 0.7788558467741935
# Epoch 8/20, Batch number: 35, Cumulated accuracy: 0.7814670138888888
# Epoch 8/20, Batch number: 40, Cumulated accuracy: 0.7790338164251208
# --- Epoch 8/20: Train loss: 0.4495, Train accuracy: 0.7790
# --- Epoch 8/20: Val loss: 0.3854, Val accuracy: 0.8234
# Epoch 9/20, Batch number: 0, Cumulated accuracy: 0.76171875
# Epoch 9/20, Batch number: 5, Cumulated accuracy: 0.8079427083333334
# Epoch 9/20, Batch number: 10, Cumulated accuracy: 0.7961647727272727
# Epoch 9/20, Batch number: 15, Cumulated accuracy: 0.791259765625
# Epoch 9/20, Batch number: 20, Cumulated accuracy: 0.7963169642857143
# Epoch 9/20, Batch number: 25, Cumulated accuracy: 0.7953725961538461
# Epoch 9/20, Batch number: 30, Cumulated accuracy: 0.7962449596774194
# Epoch 9/20, Batch number: 35, Cumulated accuracy: 0.7952473958333334
# Epoch 9/20, Batch number: 40, Cumulated accuracy: 0.7930434782608695
# --- Epoch 9/20: Train loss: 0.4259, Train accuracy: 0.7930
# --- Epoch 9/20: Val loss: 0.3471, Val accuracy: 0.8408
# Epoch 10/20, Batch number: 0, Cumulated accuracy: 0.78515625
# Epoch 10/20, Batch number: 5, Cumulated accuracy: 0.78125
# Epoch 10/20, Batch number: 10, Cumulated accuracy: 0.7840909090909091
# Epoch 10/20, Batch number: 15, Cumulated accuracy: 0.79248046875
# Epoch 10/20, Batch number: 20, Cumulated accuracy: 0.7938988095238095
# Epoch 10/20, Batch number: 25, Cumulated accuracy: 0.7980769230769231
# Epoch 10/20, Batch number: 30, Cumulated accuracy: 0.7981350806451613
# Epoch 10/20, Batch number: 35, Cumulated accuracy: 0.7976345486111112
# Epoch 10/20, Batch number: 40, Cumulated accuracy: 0.797584541062802
# --- Epoch 10/20: Train loss: 0.4179, Train accuracy: 0.7976
# --- Epoch 10/20: Val loss: 0.3292, Val accuracy: 0.8516
# Epoch 11/20, Batch number: 0, Cumulated accuracy: 0.82421875
# Epoch 11/20, Batch number: 5, Cumulated accuracy: 0.796875
# Epoch 11/20, Batch number: 10, Cumulated accuracy: 0.7990056818181818
# Epoch 11/20, Batch number: 15, Cumulated accuracy: 0.806884765625
# Epoch 11/20, Batch number: 20, Cumulated accuracy: 0.8095238095238095
# Epoch 11/20, Batch number: 25, Cumulated accuracy: 0.8091947115384616
# Epoch 11/20, Batch number: 30, Cumulated accuracy: 0.8092237903225806
# Epoch 11/20, Batch number: 35, Cumulated accuracy: 0.8113064236111112
# Epoch 11/20, Batch number: 40, Cumulated accuracy: 0.8098550724637681
# --- Epoch 11/20: Train loss: 0.4023, Train accuracy: 0.8099
# --- Epoch 11/20: Val loss: 0.3508, Val accuracy: 0.8419
# Epoch 12/20, Batch number: 0, Cumulated accuracy: 0.8046875
# Epoch 12/20, Batch number: 5, Cumulated accuracy: 0.80859375
# Epoch 12/20, Batch number: 10, Cumulated accuracy: 0.8153409090909091
# Epoch 12/20, Batch number: 15, Cumulated accuracy: 0.816162109375
# Epoch 12/20, Batch number: 20, Cumulated accuracy: 0.8177083333333334
# Epoch 12/20, Batch number: 25, Cumulated accuracy: 0.8195612980769231
# Epoch 12/20, Batch number: 30, Cumulated accuracy: 0.8205645161290323
# Epoch 12/20, Batch number: 35, Cumulated accuracy: 0.8180338541666666
# Epoch 12/20, Batch number: 40, Cumulated accuracy: 0.8214492753623188
# --- Epoch 12/20: Train loss: 0.3744, Train accuracy: 0.8214
# --- Epoch 12/20: Val loss: 0.3112, Val accuracy: 0.8574
# Epoch 13/20, Batch number: 0, Cumulated accuracy: 0.828125
# Epoch 13/20, Batch number: 5, Cumulated accuracy: 0.8229166666666666
# Epoch 13/20, Batch number: 10, Cumulated accuracy: 0.8224431818181818
# Epoch 13/20, Batch number: 15, Cumulated accuracy: 0.8203125
# Epoch 13/20, Batch number: 20, Cumulated accuracy: 0.8190104166666666
# Epoch 13/20, Batch number: 25, Cumulated accuracy: 0.8137019230769231
# Epoch 13/20, Batch number: 30, Cumulated accuracy: 0.8128780241935484
# Epoch 13/20, Batch number: 35, Cumulated accuracy: 0.8154296875
# Epoch 13/20, Batch number: 40, Cumulated accuracy: 0.8180676328502415
# --- Epoch 13/20: Train loss: 0.3874, Train accuracy: 0.8181
# --- Epoch 13/20: Val loss: 0.2983, Val accuracy: 0.8695
# Epoch 14/20, Batch number: 0, Cumulated accuracy: 0.796875
# Epoch 14/20, Batch number: 5, Cumulated accuracy: 0.818359375
# Epoch 14/20, Batch number: 10, Cumulated accuracy: 0.8259943181818182
# Epoch 14/20, Batch number: 15, Cumulated accuracy: 0.827392578125
# Epoch 14/20, Batch number: 20, Cumulated accuracy: 0.8271949404761905
# Epoch 14/20, Batch number: 25, Cumulated accuracy: 0.8299278846153846
# Epoch 14/20, Batch number: 30, Cumulated accuracy: 0.8297631048387096
# Epoch 14/20, Batch number: 35, Cumulated accuracy: 0.8311631944444444
# Epoch 14/20, Batch number: 40, Cumulated accuracy: 0.8320772946859903
# --- Epoch 14/20: Train loss: 0.3685, Train accuracy: 0.8321
# --- Epoch 14/20: Val loss: 0.3859, Val accuracy: 0.8195
# Epoch 15/20, Batch number: 0, Cumulated accuracy: 0.83984375
# Epoch 15/20, Batch number: 5, Cumulated accuracy: 0.82421875
# Epoch 15/20, Batch number: 10, Cumulated accuracy: 0.8327414772727273
# Epoch 15/20, Batch number: 15, Cumulated accuracy: 0.84130859375
# Epoch 15/20, Batch number: 20, Cumulated accuracy: 0.8444940476190477
# Epoch 15/20, Batch number: 25, Cumulated accuracy: 0.8425480769230769
# Epoch 15/20, Batch number: 30, Cumulated accuracy: 0.8413558467741935
# Epoch 15/20, Batch number: 35, Cumulated accuracy: 0.8395182291666666
# Epoch 15/20, Batch number: 40, Cumulated accuracy: 0.8404830917874396
# --- Epoch 15/20: Train loss: 0.3492, Train accuracy: 0.8405
# --- Epoch 15/20: Val loss: 0.2897, Val accuracy: 0.8715
# Epoch 16/20, Batch number: 0, Cumulated accuracy: 0.828125
# Epoch 16/20, Batch number: 5, Cumulated accuracy: 0.8346354166666666
# Epoch 16/20, Batch number: 10, Cumulated accuracy: 0.8426846590909091
# Epoch 16/20, Batch number: 15, Cumulated accuracy: 0.84375
# Epoch 16/20, Batch number: 20, Cumulated accuracy: 0.8456101190476191
# Epoch 16/20, Batch number: 25, Cumulated accuracy: 0.8485576923076923
# Epoch 16/20, Batch number: 30, Cumulated accuracy: 0.8508064516129032
# Epoch 16/20, Batch number: 35, Cumulated accuracy: 0.8490668402777778
# Epoch 16/20, Batch number: 40, Cumulated accuracy: 0.849951690821256
# --- Epoch 16/20: Train loss: 0.3319, Train accuracy: 0.8500
# --- Epoch 16/20: Val loss: 0.2689, Val accuracy: 0.8803
# Epoch 17/20, Batch number: 0, Cumulated accuracy: 0.83203125
# Epoch 17/20, Batch number: 5, Cumulated accuracy: 0.8502604166666666
# Epoch 17/20, Batch number: 10, Cumulated accuracy: 0.8526278409090909
# Epoch 17/20, Batch number: 15, Cumulated accuracy: 0.85400390625
# Epoch 17/20, Batch number: 20, Cumulated accuracy: 0.8558407738095238
# Epoch 17/20, Batch number: 25, Cumulated accuracy: 0.8545673076923077
# Epoch 17/20, Batch number: 30, Cumulated accuracy: 0.8555947580645161
# Epoch 17/20, Batch number: 35, Cumulated accuracy: 0.8560112847222222
# Epoch 17/20, Batch number: 40, Cumulated accuracy: 0.8571014492753624
# --- Epoch 17/20: Train loss: 0.3257, Train accuracy: 0.8571
# --- Epoch 17/20: Val loss: 0.2405, Val accuracy: 0.8930
# Epoch 18/20, Batch number: 0, Cumulated accuracy: 0.83984375
# Epoch 18/20, Batch number: 5, Cumulated accuracy: 0.865234375
# Epoch 18/20, Batch number: 10, Cumulated accuracy: 0.8629261363636364
# Epoch 18/20, Batch number: 15, Cumulated accuracy: 0.862548828125
# Epoch 18/20, Batch number: 20, Cumulated accuracy: 0.8621651785714286
# Epoch 18/20, Batch number: 25, Cumulated accuracy: 0.8601262019230769
# Epoch 18/20, Batch number: 30, Cumulated accuracy: 0.8605090725806451
# Epoch 18/20, Batch number: 35, Cumulated accuracy: 0.8599175347222222
# Epoch 18/20, Batch number: 40, Cumulated accuracy: 0.8589371980676328
# --- Epoch 18/20: Train loss: 0.3187, Train accuracy: 0.8589
# --- Epoch 18/20: Val loss: 0.2514, Val accuracy: 0.8852
# Epoch 19/20, Batch number: 0, Cumulated accuracy: 0.84765625
# Epoch 19/20, Batch number: 5, Cumulated accuracy: 0.8483072916666666
# Epoch 19/20, Batch number: 10, Cumulated accuracy: 0.8533380681818182
# Epoch 19/20, Batch number: 15, Cumulated accuracy: 0.854248046875
# Epoch 19/20, Batch number: 20, Cumulated accuracy: 0.8584449404761905
# Epoch 19/20, Batch number: 25, Cumulated accuracy: 0.8623798076923077
# Epoch 19/20, Batch number: 30, Cumulated accuracy: 0.8610131048387096
# Epoch 19/20, Batch number: 35, Cumulated accuracy: 0.8601345486111112
# Epoch 19/20, Batch number: 40, Cumulated accuracy: 0.8607729468599034
# --- Epoch 19/20: Train loss: 0.3140, Train accuracy: 0.8608
# --- Epoch 19/20: Val loss: 0.2540, Val accuracy: 0.8842
# Epoch 20/20, Batch number: 0, Cumulated accuracy: 0.85546875
# Epoch 20/20, Batch number: 5, Cumulated accuracy: 0.8626302083333334
# Epoch 20/20, Batch number: 10, Cumulated accuracy: 0.8678977272727273
# Epoch 20/20, Batch number: 15, Cumulated accuracy: 0.861572265625
# Epoch 20/20, Batch number: 20, Cumulated accuracy: 0.8619791666666666
# Epoch 20/20, Batch number: 25, Cumulated accuracy: 0.8575721153846154
# Epoch 20/20, Batch number: 30, Cumulated accuracy: 0.8558467741935484
# Epoch 20/20, Batch number: 35, Cumulated accuracy: 0.8576388888888888
# Epoch 20/20, Batch number: 40, Cumulated accuracy: 0.8566183574879227
# --- Epoch 20/20: Train loss: 0.3172, Train accuracy: 0.8566
# --- Epoch 20/20: Val loss: 0.2210, Val accuracy: 0.9024

# %% [markdown]
# ## Testing Model & Performance Curves

# %%
"""
test function params:
device
model - model to train
data_loader - chosen (testing) data loader
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)
get_predictions - if True, returns the list of true labels, the list of predictions made by the model, 
                  and values of the test loss and test accuracy (default is False)

by default, returns values of the test loss and test accuracy

"""
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
# Out:
# Test loss: 0.2212, Test accuracy: 0.9016

# %%
show_metrics(true_labels, model_preds)
# Out:
# Precision: 0.9121542656797819
# Recall: 0.892
# F1 score: 0.901964560862866

# %%
model.load_state_dict(torch.load("./DeepSearch_checkpoint")["model_state_dict"])
# Out:
# <All keys matched successfully>

# %%
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
show_metrics(true_labels, model_preds)
# Out:
# Test loss: 0.2219, Test accuracy: 0.9045
# Precision: 0.9152377240841777
# Recall: 0.8946666666666667
# F1 score: 0.904835291851281

# %%
plt.plot(train_accuracies, "r--", label='Train accuracy')
plt.plot(val_accuracies, "b--", label='Validation accuracy')
plt.title("Final Test Accuracy: {}".format(test_accuracy))
plt.legend(loc='upper left')
plt.show()

# %%
print(train_accuracies)
# Out:
# [0.6792156862745098, 0.735686274509804, 0.7496078431372549, 0.7562745098039215, 0.7762745098039215, 0.7858823529411765, 0.8023529411764706, 0.7907843137254902, 0.7811764705882352, 0.8031372549019608, 0.8088235294117647, 0.8145098039215686, 0.823921568627451, 0.8264705882352941, 0.8280392156862745, 0.8358823529411765, 0.8392156862745098, 0.8531372549019608, 0.8433333333333334, 0.8603921568627451]

# %%
print(val_accuracies)
# Out:
# [0.6843137254901961, 0.7505882352941177, 0.7584313725490196, 0.7803921568627451, 0.7847058823529411, 0.8143137254901961, 0.8029411764705883, 0.8235294117647058, 0.8266666666666667, 0.7637254901960784, 0.788235294117647, 0.8205882352941176, 0.8525490196078431, 0.7735294117647059, 0.8488235294117648, 0.8619607843137255, 0.8492156862745098, 0.876078431372549, 0.8866666666666667, 0.8935294117647059]

# %%
plt.plot(train_losses, "r--", label='Training loss')
plt.plot(val_losses, "b--", label='Validation loss')
plt.title("Final Test Loss: {}".format(test_loss))
plt.legend(loc='upper right')
plt.show()

# %%
print(train_losses)
# Out:
# [0.6121687859296798, 0.5548287481069565, 0.5168712064623833, 0.49732318371534345, 0.45924944877624513, 0.4394736811518669, 0.40106487423181536, 0.4201983720064163, 0.4238369777798653, 0.40167558938264847, 0.3964171588420868, 0.37599664330482485, 0.36785963773727415, 0.3505867406725883, 0.355198372900486, 0.34339697659015656, 0.34068685621023176, 0.31183243095874785, 0.3264094844460487, 0.302280380576849]

# %%
print(val_losses)
# Out:
# [0.6437905518338084, 0.5242809846997261, 0.4693418674170971, 0.4328779175877571, 0.43987057358026505, 0.35899151060730217, 0.3745876334607601, 0.35579941011965277, 0.34524933714419603, 0.4738068513572216, 0.4372345039155334, 0.33003874905407427, 0.29823504788801075, 0.5020481951534748, 0.29809956103563306, 0.2729149252176285, 0.31320586800575256, 0.25239802319556476, 0.25155675541609523, 0.24351912373676896]

# %% [markdown]
# ## Old curves, forgot to save values

# %%
plt.plot(train_accuracies, "r--", label='Train accuracy')
plt.plot(val_accuracies, "b--", label='Validation accuracy')
plt.title("Final Test Accuracy: {}".format(test_accuracy))
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(train_losses, "r--", label='Training loss')
plt.plot(val_losses, "b--", label='Validation loss')
plt.title("Final Test Loss: {}".format(test_loss))
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Viewing Model Predictions

# %%
test_loader2 = produce_loader(test_data, 1)

# %%
visualize_data(correct_list, (12,12), 5)
# Out:
# [1823, 1716, 2462, 3971, 3896, 2655, 822, 2305, 1448, 3959, 1739, 4161, 2599, 3418, 76, 120, 959, 1483, 3665, 3797, 357, 4123, 378, 4230, 3044]

# %%
visualize_data(wrong_list, (12,12), 5)
# Out:
# [169, 71, 440, 414, 103, 345, 539, 448, 32, 171, 475, 529, 311, 263, 396, 408, 382, 221, 258, 392, 332, 433, 277, 81, 58]

# %% [markdown]
# ## Saving Model

# %%
torch.save({'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict()}, 
            './DeepSearch2_13epochs')

# %% [markdown]
# model_test = DeepLearn(kernels=kernels, hidden=hidden, kernel_size=kernel_size, window=window,
#                    hidden_linear=hidden_linear, labels=labels).to(device)
# model_test.load_state_dict(torch.load("./latest_16epochs")["model_state_dict"])
