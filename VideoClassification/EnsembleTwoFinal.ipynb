# %% [markdown]
# ## Imports & Setup

# %%
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Compose, Resize, RandomHorizontalFlip
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, precision_score, recall_score
from helpers import *
from architecture.CNN import *

# %% [markdown]
# from torchsampler import ImbalancedDatasetSampler

# %%
torch.manual_seed(809)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# RandomAffine(degrees=(-30,30),translate=(0.1,0.1),shear=(-10,10)),
#                           RandomResizedCrop((size,size),scale=(0.8,1),ratio=(0.9,1.1)),

# %% [markdown]
# ## Prepare Dataset

# %%
def create_subsets(root, transformation):
    dataset = ImageFolder(root, transformation)
    train, test, val = torch.utils.data.random_split(dataset, [0.8, 0.1, 0.1])
    return train, test, val

# %%
def produce_loaders(train, test, val):
    train_loader = torch.utils.data.DataLoader(train, batch_size = batch_size, shuffle = True)
    test_loader = torch.utils.data.DataLoader(test, batch_size = batch_size, shuffle = False)
    valid_loader = torch.utils.data.DataLoader(val, batch_size = batch_size, shuffle = False)
    return train_loader, test_loader, valid_loader

# %%
size = 44
batch_size = 256
transformation = Compose([RandomHorizontalFlip(), 
                          Resize((size, size)), ToTensor()])

# %%
root = '../expanded/'
train_data, test_data, val_data = create_subsets(root, transformation)
train_loader, test_loader, val_loader = produce_loaders(train_data, test_data, val_data)

# %%
visualize_data(train_data)
# Out:
# [4572, 6343, 983, 7087, 7318, 7226, 1162, 4492, 8043]

# %%
visualize_data(test_data)
# Out:
# [797, 545, 271, 673, 21, 467, 757, 401, 755]

# %% [markdown]
# ## Initialize Model

# %%
def create_adam_optimizer(model, lr = 0.1, betas=(0.9, 0.999), amsgrad=False):
    return optim.Adam(model.parameters(), lr = lr, amsgrad=amsgrad, betas=betas)

# %%
from math import floor
# number of hidden layers and their sizes
hidden = [3, 256, 128, 64]

# kernel size of convolution layers
kernel_size = 3

# window size of maxpooling layer
window = 2

# calculate final size of image
channels = hidden[-1]
changed_img = floor( (size-(kernel_size-1)*(len(hidden)-1)) / window )

# calculate dimension of flattened image
flattened = channels*changed_img*changed_img

# final linear layers and their sizes
hidden_linear = [flattened, 512, 64]

# %%
model = DeepSearch(hidden=hidden, kernel_size=kernel_size,
                   window=window, hidden_linear=hidden_linear).to(device)
#model.load_state_dict(torch.load("./DeepSearch2_15epochs")["model_state_dict"])
print(model)
# Out:
# DeepSearch(
#   (conv_combined): Sequential(
#     (0): DeepSearchConv(
#       (conv): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (1): DeepSearchConv(
#       (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#     (2): DeepSearchConv(
#       (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1))
#       (batch_norm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout2d(p=0.5, inplace=False)
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (linear_combined): Sequential(
#     (0): DeepSearchLinear(
#       (linear): Linear(in_features=23104, out_features=512, bias=True)
#       (batch_norm): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#     (1): DeepSearchLinear(
#       (linear): Linear(in_features=512, out_features=64, bias=True)
#       (batch_norm): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (output): Linear(in_features=64, out_features=2, bias=True)
# )

# %% [markdown]
# ## Training Model

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

# %%
optimizer = create_adam_optimizer(model, lr=0.001)
#optimizer.load_state_dict(torch.load("./DeepSearch2_15epochs")["optimizer_state_dict"])

# %%
# repeat this cell with epochs = 1 for safety, but usually epochs = 3 is a good start

"""
train function params:
device
model - model to train
train_loader - training data loader
val_loader - validation data loader
optimizer - optimizer to use (allows for saving and reloading optimizer state to stop and resume training)
epochs
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)

returns lists of the training loss, training accuracy, validation loss and validation accuracy for plotting curves

"""
tl, ta, vl, va = train(device, model,
                       train_loader, val_loader, 
                       optimizer, epochs = 20)
train_losses+=tl
train_accuracies+=ta
val_losses+=vl
val_accuracies+=va
# Out:
# Epoch 1/20, Batch number: 0, Cumulated accuracy: 0.4609375
# Epoch 1/20, Batch number: 5, Cumulated accuracy: 0.5807291666666666
# Epoch 1/20, Batch number: 10, Cumulated accuracy: 0.61328125
# Epoch 1/20, Batch number: 15, Cumulated accuracy: 0.623779296875
# Epoch 1/20, Batch number: 20, Cumulated accuracy: 0.6346726190476191
# Epoch 1/20, Batch number: 25, Cumulated accuracy: 0.6373197115384616
# Epoch 1/20, Batch number: 30, Cumulated accuracy: 0.643523185483871
# --- Epoch 1/20: Train loss: 0.6561, Train accuracy: 0.6425
# --- Epoch 1/20: Val loss: 0.6281, Val accuracy: 0.6763
# Epoch 2/20, Batch number: 0, Cumulated accuracy: 0.6953125
# Epoch 2/20, Batch number: 5, Cumulated accuracy: 0.703125
# Epoch 2/20, Batch number: 10, Cumulated accuracy: 0.6938920454545454
# Epoch 2/20, Batch number: 15, Cumulated accuracy: 0.693603515625
# Epoch 2/20, Batch number: 20, Cumulated accuracy: 0.6912202380952381
# Epoch 2/20, Batch number: 25, Cumulated accuracy: 0.6891526442307693
# Epoch 2/20, Batch number: 30, Cumulated accuracy: 0.6905241935483871
# --- Epoch 2/20: Train loss: 0.5999, Train accuracy: 0.6923
# --- Epoch 2/20: Val loss: 0.5726, Val accuracy: 0.6966
# Epoch 3/20, Batch number: 0, Cumulated accuracy: 0.72265625
# Epoch 3/20, Batch number: 5, Cumulated accuracy: 0.7252604166666666
# Epoch 3/20, Batch number: 10, Cumulated accuracy: 0.7201704545454546
# Epoch 3/20, Batch number: 15, Cumulated accuracy: 0.718994140625
# Epoch 3/20, Batch number: 20, Cumulated accuracy: 0.7167038690476191
# Epoch 3/20, Batch number: 25, Cumulated accuracy: 0.7137920673076923
# Epoch 3/20, Batch number: 30, Cumulated accuracy: 0.7179939516129032
# --- Epoch 3/20: Train loss: 0.5548, Train accuracy: 0.7202
# --- Epoch 3/20: Val loss: 0.5164, Val accuracy: 0.7739
# Epoch 4/20, Batch number: 0, Cumulated accuracy: 0.765625
# Epoch 4/20, Batch number: 5, Cumulated accuracy: 0.7434895833333334
# Epoch 4/20, Batch number: 10, Cumulated accuracy: 0.7350852272727273
# Epoch 4/20, Batch number: 15, Cumulated accuracy: 0.73876953125
# Epoch 4/20, Batch number: 20, Cumulated accuracy: 0.7321428571428571
# Epoch 4/20, Batch number: 25, Cumulated accuracy: 0.7301682692307693
# Epoch 4/20, Batch number: 30, Cumulated accuracy: 0.7342489919354839
# --- Epoch 4/20: Train loss: 0.5271, Train accuracy: 0.7373
# --- Epoch 4/20: Val loss: 0.4554, Val accuracy: 0.7932
# Epoch 5/20, Batch number: 0, Cumulated accuracy: 0.75
# Epoch 5/20, Batch number: 5, Cumulated accuracy: 0.7552083333333334
# Epoch 5/20, Batch number: 10, Cumulated accuracy: 0.7521306818181818
# Epoch 5/20, Batch number: 15, Cumulated accuracy: 0.75439453125
# Epoch 5/20, Batch number: 20, Cumulated accuracy: 0.7596726190476191
# Epoch 5/20, Batch number: 25, Cumulated accuracy: 0.763671875
# Epoch 5/20, Batch number: 30, Cumulated accuracy: 0.7626008064516129
# --- Epoch 5/20: Train loss: 0.4886, Train accuracy: 0.7614
# --- Epoch 5/20: Val loss: 0.4249, Val accuracy: 0.8164
# Epoch 6/20, Batch number: 0, Cumulated accuracy: 0.7734375
# Epoch 6/20, Batch number: 5, Cumulated accuracy: 0.7610677083333334
# Epoch 6/20, Batch number: 10, Cumulated accuracy: 0.7624289772727273
# Epoch 6/20, Batch number: 15, Cumulated accuracy: 0.7666015625
# Epoch 6/20, Batch number: 20, Cumulated accuracy: 0.7678571428571429
# Epoch 6/20, Batch number: 25, Cumulated accuracy: 0.7696814903846154
# Epoch 6/20, Batch number: 30, Cumulated accuracy: 0.7692792338709677
# --- Epoch 6/20: Train loss: 0.4663, Train accuracy: 0.7697
# --- Epoch 6/20: Val loss: 0.4418, Val accuracy: 0.7981
# Epoch 7/20, Batch number: 0, Cumulated accuracy: 0.80859375
# Epoch 7/20, Batch number: 5, Cumulated accuracy: 0.7825520833333334
# Epoch 7/20, Batch number: 10, Cumulated accuracy: 0.7862215909090909
# Epoch 7/20, Batch number: 15, Cumulated accuracy: 0.787353515625
# Epoch 7/20, Batch number: 20, Cumulated accuracy: 0.7855282738095238
# Epoch 7/20, Batch number: 25, Cumulated accuracy: 0.7880108173076923
# Epoch 7/20, Batch number: 30, Cumulated accuracy: 0.7849042338709677
# --- Epoch 7/20: Train loss: 0.4478, Train accuracy: 0.7849
# --- Epoch 7/20: Val loss: 0.4012, Val accuracy: 0.8193
# Epoch 8/20, Batch number: 0, Cumulated accuracy: 0.77734375
# Epoch 8/20, Batch number: 5, Cumulated accuracy: 0.7994791666666666
# Epoch 8/20, Batch number: 10, Cumulated accuracy: 0.8000710227272727
# Epoch 8/20, Batch number: 15, Cumulated accuracy: 0.798583984375
# Epoch 8/20, Batch number: 20, Cumulated accuracy: 0.7983630952380952
# Epoch 8/20, Batch number: 25, Cumulated accuracy: 0.7983774038461539
# Epoch 8/20, Batch number: 30, Cumulated accuracy: 0.7991431451612904
# --- Epoch 8/20: Train loss: 0.4288, Train accuracy: 0.8001
# --- Epoch 8/20: Val loss: 0.3643, Val accuracy: 0.8386
# Epoch 9/20, Batch number: 0, Cumulated accuracy: 0.79296875
# Epoch 9/20, Batch number: 5, Cumulated accuracy: 0.8098958333333334
# Epoch 9/20, Batch number: 10, Cumulated accuracy: 0.8107244318181818
# Epoch 9/20, Batch number: 15, Cumulated accuracy: 0.817138671875
# Epoch 9/20, Batch number: 20, Cumulated accuracy: 0.8151041666666666
# Epoch 9/20, Batch number: 25, Cumulated accuracy: 0.8137019230769231
# Epoch 9/20, Batch number: 30, Cumulated accuracy: 0.8143901209677419
# --- Epoch 9/20: Train loss: 0.4091, Train accuracy: 0.8139
# --- Epoch 9/20: Val loss: 0.3319, Val accuracy: 0.8531
# Epoch 10/20, Batch number: 0, Cumulated accuracy: 0.85546875
# Epoch 10/20, Batch number: 5, Cumulated accuracy: 0.8059895833333334
# Epoch 10/20, Batch number: 10, Cumulated accuracy: 0.8149857954545454
# Epoch 10/20, Batch number: 15, Cumulated accuracy: 0.816650390625
# Epoch 10/20, Batch number: 20, Cumulated accuracy: 0.8175223214285714
# Epoch 10/20, Batch number: 25, Cumulated accuracy: 0.8143028846153846
# Epoch 10/20, Batch number: 30, Cumulated accuracy: 0.8159022177419355
# --- Epoch 10/20: Train loss: 0.3984, Train accuracy: 0.8164
# --- Epoch 10/20: Val loss: 0.3320, Val accuracy: 0.8599
# Epoch 11/20, Batch number: 0, Cumulated accuracy: 0.87890625
# Epoch 11/20, Batch number: 5, Cumulated accuracy: 0.8372395833333334
# Epoch 11/20, Batch number: 10, Cumulated accuracy: 0.8352272727272727
# Epoch 11/20, Batch number: 15, Cumulated accuracy: 0.834228515625
# Epoch 11/20, Batch number: 20, Cumulated accuracy: 0.8370535714285714
# Epoch 11/20, Batch number: 25, Cumulated accuracy: 0.8348858173076923
# Epoch 11/20, Batch number: 30, Cumulated accuracy: 0.8315272177419355
# --- Epoch 11/20: Train loss: 0.3707, Train accuracy: 0.8333
# --- Epoch 11/20: Val loss: 0.3775, Val accuracy: 0.8464
# Epoch 12/20, Batch number: 0, Cumulated accuracy: 0.84765625
# Epoch 12/20, Batch number: 5, Cumulated accuracy: 0.8294270833333334
# Epoch 12/20, Batch number: 10, Cumulated accuracy: 0.8252840909090909
# Epoch 12/20, Batch number: 15, Cumulated accuracy: 0.825927734375
# Epoch 12/20, Batch number: 20, Cumulated accuracy: 0.8286830357142857
# Epoch 12/20, Batch number: 25, Cumulated accuracy: 0.8297776442307693
# Epoch 12/20, Batch number: 30, Cumulated accuracy: 0.8316532258064516
# --- Epoch 12/20: Train loss: 0.3744, Train accuracy: 0.8303
# --- Epoch 12/20: Val loss: 0.3136, Val accuracy: 0.8628
# Epoch 13/20, Batch number: 0, Cumulated accuracy: 0.8359375
# Epoch 13/20, Batch number: 5, Cumulated accuracy: 0.8463541666666666
# Epoch 13/20, Batch number: 10, Cumulated accuracy: 0.8394886363636364
# Epoch 13/20, Batch number: 15, Cumulated accuracy: 0.83837890625
# Epoch 13/20, Batch number: 20, Cumulated accuracy: 0.8426339285714286
# Epoch 13/20, Batch number: 25, Cumulated accuracy: 0.8422475961538461
# Epoch 13/20, Batch number: 30, Cumulated accuracy: 0.8443800403225806
# --- Epoch 13/20: Train loss: 0.3505, Train accuracy: 0.8443
# --- Epoch 13/20: Val loss: 0.2977, Val accuracy: 0.8734
# Epoch 14/20, Batch number: 0, Cumulated accuracy: 0.83203125
# Epoch 14/20, Batch number: 5, Cumulated accuracy: 0.8404947916666666
# Epoch 14/20, Batch number: 10, Cumulated accuracy: 0.8430397727272727
# Epoch 14/20, Batch number: 15, Cumulated accuracy: 0.8486328125
# Epoch 14/20, Batch number: 20, Cumulated accuracy: 0.8484002976190477
# Epoch 14/20, Batch number: 25, Cumulated accuracy: 0.8484074519230769
# Epoch 14/20, Batch number: 30, Cumulated accuracy: 0.846648185483871
# --- Epoch 14/20: Train loss: 0.3489, Train accuracy: 0.8458
# --- Epoch 14/20: Val loss: 0.2997, Val accuracy: 0.8696
# Epoch 15/20, Batch number: 0, Cumulated accuracy: 0.83203125
# Epoch 15/20, Batch number: 5, Cumulated accuracy: 0.8541666666666666
# Epoch 15/20, Batch number: 10, Cumulated accuracy: 0.8490767045454546
# Epoch 15/20, Batch number: 15, Cumulated accuracy: 0.8525390625
# Epoch 15/20, Batch number: 20, Cumulated accuracy: 0.8497023809523809
# Epoch 15/20, Batch number: 25, Cumulated accuracy: 0.8491586538461539
# Epoch 15/20, Batch number: 30, Cumulated accuracy: 0.8509324596774194
# --- Epoch 15/20: Train loss: 0.3290, Train accuracy: 0.8530
# --- Epoch 15/20: Val loss: 0.2947, Val accuracy: 0.8676
# Epoch 16/20, Batch number: 0, Cumulated accuracy: 0.8515625
# Epoch 16/20, Batch number: 5, Cumulated accuracy: 0.8567708333333334
# Epoch 16/20, Batch number: 10, Cumulated accuracy: 0.8494318181818182
# Epoch 16/20, Batch number: 15, Cumulated accuracy: 0.8515625
# Epoch 16/20, Batch number: 20, Cumulated accuracy: 0.8508184523809523
# Epoch 16/20, Batch number: 25, Cumulated accuracy: 0.8526141826923077
# Epoch 16/20, Batch number: 30, Cumulated accuracy: 0.854460685483871
# --- Epoch 16/20: Train loss: 0.3365, Train accuracy: 0.8525
# --- Epoch 16/20: Val loss: 0.2776, Val accuracy: 0.8889
# Epoch 17/20, Batch number: 0, Cumulated accuracy: 0.87109375
# Epoch 17/20, Batch number: 5, Cumulated accuracy: 0.869140625
# Epoch 17/20, Batch number: 10, Cumulated accuracy: 0.8639914772727273
# Epoch 17/20, Batch number: 15, Cumulated accuracy: 0.865478515625
# Epoch 17/20, Batch number: 20, Cumulated accuracy: 0.8582589285714286
# Epoch 17/20, Batch number: 25, Cumulated accuracy: 0.8572716346153846
# Epoch 17/20, Batch number: 30, Cumulated accuracy: 0.8567288306451613
# --- Epoch 17/20: Train loss: 0.3254, Train accuracy: 0.8558
# --- Epoch 17/20: Val loss: 0.2778, Val accuracy: 0.8860
# Epoch 18/20, Batch number: 0, Cumulated accuracy: 0.890625
# Epoch 18/20, Batch number: 5, Cumulated accuracy: 0.8704427083333334
# Epoch 18/20, Batch number: 10, Cumulated accuracy: 0.8686079545454546
# Epoch 18/20, Batch number: 15, Cumulated accuracy: 0.867919921875
# Epoch 18/20, Batch number: 20, Cumulated accuracy: 0.8662574404761905
# Epoch 18/20, Batch number: 25, Cumulated accuracy: 0.8649338942307693
# Epoch 18/20, Batch number: 30, Cumulated accuracy: 0.8660534274193549
# --- Epoch 18/20: Train loss: 0.3156, Train accuracy: 0.8653
# --- Epoch 18/20: Val loss: 0.2635, Val accuracy: 0.8860
# Epoch 19/20, Batch number: 0, Cumulated accuracy: 0.84375
# Epoch 19/20, Batch number: 5, Cumulated accuracy: 0.8795572916666666
# Epoch 19/20, Batch number: 10, Cumulated accuracy: 0.8831676136363636
# Epoch 19/20, Batch number: 15, Cumulated accuracy: 0.873291015625
# Epoch 19/20, Batch number: 20, Cumulated accuracy: 0.87109375
# Epoch 19/20, Batch number: 25, Cumulated accuracy: 0.869140625
# Epoch 19/20, Batch number: 30, Cumulated accuracy: 0.8678175403225806
# --- Epoch 19/20: Train loss: 0.3049, Train accuracy: 0.8682
# --- Epoch 19/20: Val loss: 0.2672, Val accuracy: 0.8831
# Epoch 20/20, Batch number: 0, Cumulated accuracy: 0.859375
# Epoch 20/20, Batch number: 5, Cumulated accuracy: 0.8580729166666666
# Epoch 20/20, Batch number: 10, Cumulated accuracy: 0.8611505681818182
# Epoch 20/20, Batch number: 15, Cumulated accuracy: 0.863037109375
# Epoch 20/20, Batch number: 20, Cumulated accuracy: 0.8681175595238095
# Epoch 20/20, Batch number: 25, Cumulated accuracy: 0.8685396634615384
# Epoch 20/20, Batch number: 30, Cumulated accuracy: 0.8686995967741935
# --- Epoch 20/20: Train loss: 0.2971, Train accuracy: 0.8693
# --- Epoch 20/20: Val loss: 0.2695, Val accuracy: 0.8937

# %% [markdown]
# ## Testing Model & Performance Curves

# %%
"""
test function params:
device
model - model to train
data_loader - chosen (testing) data loader
criterion - loss function to use (default is cross entropy)
autoencoder - autoencoder to use, if any (default is None)
get_predictions - if True, returns the list of true labels, the list of predictions made by the model, 
                  and values of the test loss and test accuracy (default is False)

by default, returns values of the test loss and test accuracy

"""
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
# Out:
# Test loss: 0.1782, Test accuracy: 0.9140

# %%
show_metrics(true_labels, model_preds)
# Out:
# Precision: 0.9465346534653465
# Recall: 0.8851851851851852
# F1 score: 0.9148325358851674

# %%
model.load_state_dict(torch.load("./DeepSearch_checkpoint")["model_state_dict"])
true_labels, model_preds, test_loss, test_accuracy = test(device, model, test_loader, get_predictions=True)
show_metrics(true_labels, model_preds)
# Out:
# Test loss: 0.1823, Test accuracy: 0.9150
# Precision: 0.9612244897959183
# Recall: 0.8722222222222222
# F1 score: 0.9145631067961165

# %%
plt.plot(train_accuracies, "r--", label='Train accuracy')
plt.plot(val_accuracies, "b--", label='Validation accuracy')
plt.title("Final Test Accuracy: {}".format(test_accuracy))
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(train_losses, "r--", label='Training loss')
plt.plot(val_losses, "b--", label='Validation loss')
plt.title("Final Test Loss: {}".format(test_loss))
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Viewing Model Predictions

# %%
test_loader2 = produce_loader(test_data, 1)

# %%
correct_list, wrong_list, true_labels2, model_preds2 = get_pictures_test(device, model, test_loader2)

# %%
show_metrics(true_labels2, model_preds2)
# Out:
# Precision: 0.959758551307847
# Recall: 0.8833333333333333
# F1 score: 0.9199614271938282

# %%
visualize_data(correct_list, (12,12), 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 visualize_data(correct_list, (12,12), 5)
#
# NameError: name 'correct_list' is not defined

# %%
visualize_data(wrong_list, (12,12), 5)
# Out:
# [71, 82, 39, 48, 43, 41, 26, 80, 47, 62, 64, 61, 18, 34, 68, 53, 44, 67, 39, 25, 50, 1, 53, 25, 8]

# %% [markdown]
# ## Saving Model

# %%
torch.save({'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict()}, 
            './DeepSearch_20epochs')

# %% [markdown]
# model_test = DeepLearn(kernels=kernels, hidden=hidden, kernel_size=kernel_size, window=window,
#                    hidden_linear=hidden_linear, labels=labels).to(device)
# model_test.load_state_dict(torch.load("./latest_16epochs")["model_state_dict"])
